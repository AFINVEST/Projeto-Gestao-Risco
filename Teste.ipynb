# %%
import streamlit as st
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import os
from datetime import date

# %%
def processar_b3_portifolio():
    """
    Exemplo de função que carrega dois dataframes de CSV:
     - df_preco_de_ajuste_atual.csv : preços de fechamento (colunas de datas)
     - df_variacao.csv : variação diária dos ativos (colunas de datas)
    """
    df_b3_fechamento = pd.read_csv("df_preco_de_ajuste_atual.csv")
    # df_b3_fechamento possui colunas: ['Ativo', '17/01/2025', '18/01/2025', ...]

    # df_b3_variacao possui colunas: ['Ativo', '17/01/2025', '18/01/2025', ...]
    # Tirar o pontos das casas de milhar
    df_b3_fechamento = df_b3_fechamento.replace('\.', '', regex=True)

    # Trocar Virgula por Ponto
    df_b3_fechamento = df_b3_fechamento.replace(',', '.', regex=True)

    # Converter para Float menos a primeira coluna
    df_b3_fechamento.iloc[:, 1:] = df_b3_fechamento.iloc[:, 1:].astype(float)

    # Multiplicar a linha da treasury por 1000
    df_b3_fechamento.loc[df_b3_fechamento['Assets'] == 'TREASURY', df_b3_fechamento.columns !=
                         'Assets'] = df_b3_fechamento.loc[df_b3_fechamento['Assets'] == 'TREASURY', df_b3_fechamento.columns != 'Assets'] * 1000
    df_b3_fechamento.loc[df_b3_fechamento['Assets'] == 'WDO1', df_b3_fechamento.columns !=
                         'Assets'] = df_b3_fechamento.loc[df_b3_fechamento['Assets'] == 'WDO1', df_b3_fechamento.columns != 'Assets'] * 10

    return df_b3_fechamento
# Out:
# <>:12: SyntaxWarning: invalid escape sequence '\.'
# <>:12: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\emanuel.cabral\AppData\Local\Temp\ipykernel_3200\2369073865.py:12: SyntaxWarning: invalid escape sequence '\.'
#   df_b3_fechamento = df_b3_fechamento.replace('\.', '', regex=True)

# %%
df_fechamento_b3 = processar_b3_portifolio()
df_fechamento_b3
# Out:
#       Assets 2025-01-02 2025-01-03 2025-01-06 2025-01-07 2025-01-08  \
# 0      DAP25   98420.08   98537.44   98566.96    98606.0   98589.62
# 1      DAP26   88536.62   88708.86   88894.14   88906.74   88985.51
# 2      DAP27    83678.7   83886.14   84166.83   84173.14   84216.02
# 3      DAP28   75982.66   76132.39   76434.84   76381.23    76429.4
# 4      DAP29   72298.68    72349.2   72574.18   72334.21   72471.68
# 5      DAP30   66333.67   66353.05   66578.79   66357.52   66308.42
# 6      DAP32   57412.89   57107.32    57486.7   57181.02   57117.54
# 7      DAP33   54417.48   54181.57   54617.59   54506.96   54522.76
# 8      DAP35   47304.65   47182.63   47468.03   47164.85   47359.26
# 9      DAP40   33461.41   33475.62   33767.22   33504.04   33878.97
# 10     DAP45   23630.53   23641.67   23840.78   23933.04   23768.95
# 11     DAP50   15974.11   16027.96   16238.97   16382.75   16240.48
# 12     DAP55   11422.13   11473.62   11622.86   11807.21   11655.61
# 13     DAP60     7847.2    7906.55    8037.55    8205.85    8047.39
# 14     DI_26   86812.34   86950.54   87057.54   87081.12   87160.83
# 15     DI_27   74824.27   75135.35   75344.87   75317.94   75386.58
# 16     DI_28   64753.44   65159.49   65510.26   65440.86   65418.97
# 17     DI_29   56356.33   56818.25   57270.12   57148.76   57028.06
# 18     DI_30   49138.87   49646.42    50148.6   50006.23   49781.28
# 19     DI_31   42922.79   43406.74   43964.63   43752.62   43501.71
# 20     DI_32   37548.07   38009.88   38570.95   38361.41    38056.8
# 21     DI_33   32856.11   33364.85   33907.77    33680.1   33348.15
# 22     DI_34   28891.53   29402.98   29945.06    29702.5    29368.4
# 23     DI_35    25365.1   25882.86   26437.04   26179.43    25828.5
# 24     DI_36   22304.03   22804.15   23340.63   23089.19   22747.56
# 25     DI_37    19620.1   20100.29   20616.54   20372.87   20042.58
# 26     DI_38   17303.22   17761.73   18255.74   18021.19   17703.95
# 27     DI_39   14926.11   15351.61   15811.02   15591.94   15296.17
# 28     DI_40   13025.91   13423.72   13854.13    13648.0   13370.24
# 29  TREASURY   108812.5   108640.6   108531.2   108171.8   108140.6
# 30      WDO1    61923.0   62130.21   61430.28   61309.18   61463.52
#
#    2025-01-09 2025-01-10 2025-01-13 2025-01-14  ... 2025-01-24 2025-01-27  \
# 0     98605.9   98600.13   98688.39   98728.79  ...    99079.3   99088.91
# 1    88839.95   88774.27   88813.71   88813.96  ...   88897.44   88885.95
# 2    84167.76   84065.34   84090.24   84187.56  ...   84422.13    84393.3
# 3    76426.78   76322.91   76244.76    76368.7  ...    76476.9   76424.83
# 4    72435.19   72283.27   72160.86   72384.21  ...   72327.99   72349.79
# 5    66293.65   66108.37   65890.08   66113.47  ...   65797.71   65817.55
# 6    57174.43   56911.25   56729.12   56984.85  ...   56329.63   56346.71
# 7    54664.93   54428.38   54276.75   54460.07  ...   53633.47   53608.51
# 8    47372.93   47296.15   47129.52   47323.51  ...   46363.42   46267.35
# 9     33814.9   33343.71    33151.4   33208.67  ...   32671.26   32488.49
# 10    23766.7   23471.01   23236.04   23409.39  ...    22747.5   22737.07
# 11   16279.75   16115.57   15926.77   16117.13  ...   15507.14   15497.03
# 12   11649.08   11512.56    11387.3   11519.11  ...   10971.58   10971.71
# 13    8025.83    7889.17    7788.18    7885.87  ...    7464.56    7466.73
# 14   87241.86   87195.29   87335.38   87416.06  ...   87637.39   87675.04
# 15   75577.62   75444.09   75673.29   75821.48  ...   75925.41   76012.82
# 16   65705.64   65422.71   65634.63   65865.49  ...   66049.61   66204.05
# 17   57342.55    56928.6   57083.62   57372.05  ...   57592.59   57810.67
# 18   50064.04   49564.77    49654.3   49991.23  ...   50119.23   50386.43
# 19    43728.6   43179.16   43205.64   43576.12  ...   43571.51   43859.93
# 20   38229.84   37676.43   37643.08   38014.83  ...   37878.47    38175.2
# 21    33484.3   32920.29   32884.16   33262.72  ...   33040.25   33322.75
# 22   29471.48   28908.35   28850.28   29208.99  ...   28875.58   29160.85
# 23   25900.69   25349.94   25278.69   25641.95  ...   25191.34   25490.46
# 24   22816.23   22281.63   22211.42   22561.64  ...   22086.08   22373.62
# 25   20107.65   19592.23   19523.71   19859.36  ...   19307.83   19581.69
# 26    17765.4   17271.58   17205.29   17525.26  ...    16965.1   17225.26
# 27   15352.75   14893.38   14831.31   15127.82  ...   14603.55   14844.21
# 28   13422.73   12992.27   12933.74   13210.55  ...   12716.47   12940.72
# 29   108218.7   107390.6   107234.3   107359.3  ...   108468.7   109156.2
# 30   60796.23   61235.27    61107.7   60707.25  ...   59106.65   59197.84
#
#    2025-01-28 2025-01-29 2025-01-30 2025-01-31 2025-02-03 2025-02-04  \
# 0    99104.08   99167.94   99195.66   99204.47   99266.72   99166.03
# 1    88900.08   88888.93   89309.48   89380.09   89501.38   89299.28
# 2    84453.92   84407.48   85103.32   85100.38   85268.05   84987.56
# 3    76547.98   76508.49   77437.19   77421.54   77748.13   77516.83
# 4    72457.35   72479.11    73436.7   73414.39   73696.85   73471.28
# 5     65904.6   65823.66   66910.07   66775.95   66931.84   66763.88
# 6    56383.39   56341.73   57426.81   57264.14    57420.6   57297.96
# 7     53727.2   53640.68   54818.25   54562.05   54682.43   54489.72
# 8    46347.08    46426.9    47352.9    47008.4   47268.14   47169.94
# 9     32549.3    32441.9   33374.13   32859.55   33010.98   32982.44
# 10   22709.62   22639.76   23222.35   23020.94   23244.41   23207.55
# 11   15483.27   15393.11   15884.65   15773.41   15942.63   15909.62
# 12    10965.7   10941.31    11362.7   11337.35   11471.53   11436.32
# 13    7446.87     7422.2    7760.91    7699.64     7806.3    7777.81
# 14   87734.74    87735.9   88030.03   88039.77   88093.23   88133.44
# 15   76124.19   76054.87   76674.14   76670.74   76828.74   76871.03
# 16   66301.55    66188.1   66956.88   67029.14   67340.77   67460.65
# 17   57895.82   57753.94   58522.03   58675.09   59073.95   59252.05
# 18   50453.02   50275.94   51039.24   51271.46   51708.56   51908.17
# 19   43904.51    43729.5   44466.58   44746.73   45218.18   45449.29
# 20   38200.95   38035.14   38722.44   39032.51   39541.44   39760.15
# 21   33341.18   33186.29   33799.61   34161.06   34623.95   34855.12
# 22   29154.36   29028.81   29577.08    29922.4   30436.52   30582.82
# 23   25465.08   25330.84    25825.8   26170.65   26625.51   26840.02
# 24   22347.81   22216.87   22693.94   23026.46   23466.13   23673.04
# 25   19555.97   19429.74   19872.85   20190.29   20610.99   20808.67
# 26    17199.9   17078.77   17500.54   17802.94   18204.57   18393.07
# 27   14820.12   14707.22   15098.05   15378.53    15751.8    15926.9
# 28   12917.71   12811.74   13176.54    13438.6   13788.05    13951.9
# 29   109031.2   108953.1   109234.3   108843.7   108953.1   109203.1
# 30   58691.96   58726.11   58682.34    58301.0    58301.0    58017.3
#
#    2025-02-05 2025-02-06
# 0    99222.52   99257.87
# 1    89250.03   89314.22
# 2    84922.78   84929.45
# 3    77438.18   77359.88
# 4     73290.3   73326.05
# 5    66596.72   66684.11
# 6    57175.78    57252.3
# 7    54277.27   54417.71
# 8    47005.21   47152.82
# 9    32746.36   32615.01
# 10   22928.99   23051.89
# 11   15686.88   15843.86
# 12   11255.42   11369.45
# 13    7605.76    7711.05
# 14   88149.45   88207.21
# 15   76760.23   76771.27
# 16   67201.83   67167.58
# 17   58910.14   58840.74
# 18   51523.13   51431.05
# 19   45037.98   44917.46
# 20   39340.33   39211.11
# 21   34419.09    34296.2
# 22   30191.91   30063.66
# 23   26405.23   26290.37
# 24   23249.84   23137.19
# 25   20401.34   20292.27
# 26   18002.22   17897.05
# 27   15562.21   15463.77
# 28   13609.17   13516.38
# 29   109750.0   109578.1
# 30   58138.57   57809.32
#
# [31 rows x 27 columns]

# %%
#Acessar dados do Supabase
from supabase import create_client
import pandas as pd
import streamlit as st

# Configuração do Supabase (substitua pelas suas credenciais)
SUPABASE_URL = 'https://obgwfekirteetqzjydry.supabase.co'
SUPABASE_KEY = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6Im9iZ3dmZWtpcnRlZXRxemp5ZHJ5Iiwicm9sZSI6InNlcnZpY2Vfcm9sZSIsImlhdCI6MTczODk2MDc1MCwiZXhwIjoyMDU0NTM2NzUwfQ.k7-Haw1txbCEwb_MzkynOeEuRJpfgt3msePdvQavWAc'
supabase = create_client(SUPABASE_URL, SUPABASE_KEY)

def load_data():
    try:
        response = supabase.table('portfolio_posicoes').select("*").execute()
        print("Resposta do Supabase:", response)  # Depuração
        return response.data
    except Exception as e:
        return []

data = load_data()
if data:
    df = pd.DataFrame(data)
    print(df)
else:
    print("Nenhum dado encontrado. Verifique a tabela ou políticas RLS.")
# Out:
# Resposta do Supabase: data=[{'Ativo': 'WDO1', 'Quantidade': 17, 'Dia de Compra': '2025-01-22', 'Preço de Compra': 60000, 'Preço de Ajuste Atual': 57809.32, 'Rendimento': -37241.56}] count=None
#   Ativo  Quantidade Dia de Compra  Preço de Compra  Preço de Ajuste Atual  \
# 0  WDO1          17    2025-01-22            60000               57809.32
#
#    Rendimento
# 0   -37241.56

# %%
#Adicionar um novo registro no Supabase
def add_data(data):
    try:
        response = supabase.table('portfolio_posicoes').insert(data).execute()
        print("Resposta do Supabase:", response)  # Depuração
        return response.data
    except Exception as e:
        return []

def update_data(data, registro_id):
    try:
        response = supabase.table('portfolio_posicoes').update(data).eq('id', registro_id).execute()
        print("Resposta do Supabase:", response)  
        return response.data
    except Exception as e:
        print(f"Erro detalhado: {e}")
        return None
    
#Adicionar um novo registro no Supabase 'Ativo': 'WDO1', 'Quantidade': 17, 'Dia de Compra': '2025-01-22', 'Preço de Compra': 60000, 'Preço de Ajuste Atual': 57809.32, 'Rendimento': -37241.56
data2 = {'Ativo': 'TREASURY', 'Quantidade': 17, 'Dia de Compra': '2025-01-22', 'Preço de Compra': 60000, 'Preço de Ajuste Atual': 57809.32, 'Rendimento': -37241.56}

add_data(data2)
# Out:
# []

# %%
data3 = { 'id': 1 ,'Ativo': 'TREASURY', 'Quantidade': 17, 'Dia de Compra': '2025-01-23', 'Preço de Compra': 60000, 'Preço de Ajuste Atual': 57809.32, 'Rendimento': -37241.56}
update_data(data3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 data3 = { 'id': 1 ,'Ativo': 'TREASURY', 'Quantidade': 17, 'Dia de Compra': '2025-01-23', 'Preço de Compra': 60000, 'Preço de Ajuste Atual': 57809.32, 'Rendimento': -37241.56}
# ----> 2 update_data(data3)
#
# TypeError: update_data() missing 1 required positional argument: 'registro_id'

# %%
def att_port():

# %%
files = os.listdir('BaseFundos')    
df_b3_fechamento = pd.read_csv("df_preco_de_ajuste_atual.csv")
df_b3_fechamento = df_b3_fechamento.replace('\.', '', regex=True)
df_b3_fechamento = df_b3_fechamento.replace(',', '.', regex=True)
df_b3_fechamento.iloc[:, 1:] = df_b3_fechamento.iloc[:, 1:].astype(float)
df_b3_fechamento.loc[df_b3_fechamento['Assets'] == 'TREASURY', df_b3_fechamento.columns !=
                        'Assets'] = df_b3_fechamento.loc[df_b3_fechamento['Assets'] == 'TREASURY', df_b3_fechamento.columns != 'Assets'] * 1000
df_b3_fechamento.loc[df_b3_fechamento['Assets'] == 'WDO1', df_b3_fechamento.columns !=
                        'Assets'] = df_b3_fechamento.loc[df_b3_fechamento['Assets'] == 'WDO1', df_b3_fechamento.columns != 'Assets'] * 10

df_final = pd.DataFrame()
dia_atual = df_b3_fechamento.columns[-1]
dolar = df_b3_fechamento.loc[df_b3_fechamento['Assets'] == 'WDO1', dia_atual].values[0]

# Supõe-se que `files`, `df_b3_fechamento`, e `dia_atual` estão definidos
for file in files:
    # Lê o arquivo CSV
    df_fundos = pd.read_csv(f'BaseFundos/{file}')
    file = file.split('.')[0]  # Remove a extensão do nome do arquivo

    # Configura o índice para a coluna 'Ativo'
    df_fundos.set_index('Ativo', inplace=True)



    # Itera pelas linhas do DataFrame
    for idx, row in df_fundos.iterrows():
        # DataFrame para armazenar os rendimentos por operação e por dia
        df_rendimentos = pd.DataFrame()
        # Identifica as colunas relacionadas a 'Quantidade' e 'Preço de Compra'
        col_quantidade = [col for col in df_fundos.columns if col.endswith('Quantidade')]

        # Processa cada operação (quantidade/compras de cada dia)
        for col in col_quantidade:
            quantidade = row[col]

            # Ignorar operações com quantidade 0
            if quantidade == 0 or pd.isna(quantidade):
                continue
            
            # Obtém o preço de compra correspondente
            preco_compra = row[col.replace('Quantidade', 'Preco_Compra')]

            #Preco Anterior
            preco_anterior = preco_compra
            # Extrai a data da coluna
            data_operacao = col.split(' ')[0]

            # Itera por cada data no DataFrame de fechamentos (até o dia atual)
            for data_fechamento in df_b3_fechamento.columns[1:]:  # Ignora a coluna de "Assets"
                # Calcula o rendimento apenas se a data de fechamento for posterior à data de operação
                if datetime.datetime.strptime(data_fechamento, '%Y-%m-%d') >= datetime.datetime.strptime(data_operacao, '%Y-%m-%d'):
                    # Preço de fechamento no dia específico
                    preco_fechamento = df_b3_fechamento.loc[
                        df_b3_fechamento["Assets"] == idx, data_fechamento
                    ].values[0]
                    
                    if idx == 'TREASURY':
                    # Calcula o rendimento
                        rendimento = (preco_fechamento - preco_anterior) * quantidade * dolar / 10000
                    else:
                        rendimento = (preco_fechamento - preco_anterior) * quantidade


                    # Adiciona o rendimento ao DataFrame de resultados
                    df_rendimentos.loc[f"{idx} - {data_operacao}", data_fechamento] = rendimento

                    preco_anterior = preco_fechamento

        # Verifica se há dados no DataFrame `df_rendimentos`
        if not df_rendimentos.empty:
            # Adicionar uma linha de total
            df_rendimentos.loc['Total'] = df_rendimentos.sum()

            # Dropar as linhas que não sejam 'Total'
            df_rendimentos_append = df_rendimentos.loc[['Total']].copy()

            # Renomear a linha Total
            df_rendimentos_append.rename(index={'Total': f'{idx} - {file} - P&L'}, inplace=True)

            # Adicionar a nova linha ao DataFrame final
            df_final = pd.concat([df_final, df_rendimentos_append])

df_final['Total'] = df_final.sum(axis=1)
sum_row = df_final.sum(axis=0)
df_final.loc['Total'] = sum_row
df_final
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\.'
# <>:3: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\emanuel.cabral\AppData\Local\Temp\ipykernel_1196\1369429718.py:3: SyntaxWarning: invalid escape sequence '\.'
#   df_b3_fechamento = df_b3_fechamento.replace('\.', '', regex=True)
#                               2025-01-06  2025-01-07  2025-01-08  2025-01-09  \
# DI_28 - BH FIRF INFRA - P&L      2189.26      -69.40      -21.89      286.67
# DAP35 - BH FIRF INFRA - P&L      1268.03     -303.18      194.41       13.67
# DI_33 - BORDEAUX INFRA - P&L      587.77     -227.67     -331.95      136.15
# DI_33 - GLOBAL BONDS - P&L        587.77     -227.67     -331.95      136.15
# DI_33 - HORIZONTE - P&L           587.77     -227.67     -331.95      136.15
# DI_28 - HORIZONTE - P&L          2189.26      -69.40      -21.89      286.67
# DAP35 - HORIZONTE - P&L          1268.03     -303.18      194.41       13.67
# DI_33 - JERA2026 - P&L            587.77     -227.67     -331.95      136.15
# DI_28 - JERA2026 - P&L           6567.78     -208.20      -65.67      860.01
# DAP35 - JERA2026 - P&L           3804.09     -909.54      583.23       41.01
# DI_33 - Total - P&L              2351.08     -910.68    -1327.80      544.60
# DI_28 - Total - P&L             10946.30     -347.00     -109.45     1433.35
# DAP35 - Total - P&L              6340.15    -1515.90      972.05       68.35
# Total                           39275.06    -5547.16     -930.40     4092.60
#
#                               2025-01-10  2025-01-13  2025-01-14  2025-01-15  \
# DI_28 - BH FIRF INFRA - P&L      -282.93      211.92      230.86      484.32
# DAP35 - BH FIRF INFRA - P&L       -76.78     -166.63      193.99       58.88
# DI_33 - BORDEAUX INFRA - P&L     -564.01      -36.13      378.56      749.93
# DI_33 - GLOBAL BONDS - P&L       -564.01      -36.13      378.56      749.93
# DI_33 - HORIZONTE - P&L          -564.01      -36.13      378.56      749.93
# DI_28 - HORIZONTE - P&L          -282.93      211.92      230.86      484.32
# DAP35 - HORIZONTE - P&L           -76.78     -166.63      193.99       58.88
# DI_33 - JERA2026 - P&L           -564.01      -36.13      378.56      749.93
# DI_28 - JERA2026 - P&L           -848.79      635.76      692.58     1452.96
# DAP35 - JERA2026 - P&L           -230.34     -499.89      581.97      176.64
# DI_33 - Total - P&L             -2256.04     -144.52     1514.24     2999.72
# DI_28 - Total - P&L             -1414.65     1059.60     1154.30     2421.60
# DAP35 - Total - P&L              -383.90     -833.15      969.95      294.40
# Total                           -8109.18      163.86     7276.98    11431.44
#
#                               2025-01-16  2025-01-17  2025-01-20  2025-01-21  \
# DI_28 - BH FIRF INFRA - P&L      -290.53     -101.32      273.12      -10.38
# DAP35 - BH FIRF INFRA - P&L      -211.75     -389.08     -164.03     -427.42
# DI_33 - BORDEAUX INFRA - P&L     -586.78     -493.33      339.42      -61.65
# DI_33 - GLOBAL BONDS - P&L       -586.78     -493.33      339.42      -61.65
# DI_33 - HORIZONTE - P&L          -586.78     -493.33      339.42      -61.65
# DI_28 - HORIZONTE - P&L          -290.53     -101.32      273.12      -10.38
# DAP35 - HORIZONTE - P&L          -211.75     -389.08     -164.03     -427.42
# DI_33 - JERA2026 - P&L           -586.78     -493.33      339.42      -61.65
# DI_28 - JERA2026 - P&L           -871.59     -303.96      819.36      -31.14
# DAP35 - JERA2026 - P&L           -635.25    -1167.24     -492.09    -1282.26
# DI_33 - Total - P&L             -2347.12    -1973.32     1357.68     -246.60
# DI_28 - Total - P&L             -1452.65     -506.60     1365.60      -51.90
# DAP35 - Total - P&L             -1058.75    -1945.40     -820.15    -2137.10
# Total                           -9717.04    -8850.64     3806.26    -4871.20
#
#                               2025-01-22  2025-01-23  2025-01-24  2025-01-27  \
# DI_28 - BH FIRF INFRA - P&L       117.94     -257.51      -31.52      154.44
# DAP35 - BH FIRF INFRA - P&L       145.68     -205.71      233.34      -96.07
# DI_33 - BORDEAUX INFRA - P&L      270.65     -468.17       27.46      282.50
# DI_33 - GLOBAL BONDS - P&L        270.65     -468.17       27.46      282.50
# DI_33 - HORIZONTE - P&L           270.65     -468.17       27.46      282.50
# DI_28 - HORIZONTE - P&L           117.94     -257.51      -31.52      154.44
# DAP35 - HORIZONTE - P&L           145.68     -205.71      233.34      -96.07
# DI_33 - JERA2026 - P&L            270.65     -468.17       27.46      282.50
# DI_28 - JERA2026 - P&L            353.82     -772.53      -94.56      463.32
# DAP35 - JERA2026 - P&L            437.04     -617.13      700.02     -288.21
# DI_33 - Total - P&L              1082.60    -1872.68      109.84     1130.00
# DI_28 - Total - P&L               589.70    -1287.55     -157.60      772.20
# DAP35 - Total - P&L               728.40    -1028.55     1166.70     -480.35
# Total                            4801.40    -8377.56     2237.88     2843.70
#
#                                  Total
# DI_28 - BH FIRF INFRA - P&L    2883.05
# DAP35 - BH FIRF INFRA - P&L      67.35
# DI_33 - BORDEAUX INFRA - P&L      2.75
# DI_33 - GLOBAL BONDS - P&L        2.75
# DI_33 - HORIZONTE - P&L           2.75
# DI_28 - HORIZONTE - P&L        2883.05
# DAP35 - HORIZONTE - P&L          67.35
# DI_33 - JERA2026 - P&L            2.75
# DI_28 - JERA2026 - P&L         8649.15
# DAP35 - JERA2026 - P&L          202.05
# DI_33 - Total - P&L              11.00
# DI_28 - Total - P&L           14415.25
# DAP35 - Total - P&L             336.75
# Total                         29526.00

# %%
#Ler arquivos da pasta BaseFundos e monbta um dataframe com os dados
files = os.listdir('BaseFundos')
df_fundos = pd.DataFrame()
lista_files = []
for file in files:
    df_fundos = pd.concat([df_fundos, pd.read_csv(f'BaseFundos/{file}')])
    #Adiciona o nome do arquivo como uma linha da coluna Fundo
    contagem = df_fundos['Ativo'].unique()
    contagem = len(contagem)
    for i in range(contagem):
        lista_files.append(file.split('.')[0])
#Pegar a quantidade de ativos unicos
df_fundos['Fundo'] = lista_files 
df_fundos = df_fundos.reset_index(drop=True)
#Dropar todas as colunas que não terminem com quantidade
df_fundos_tirar = df_fundos[df_fundos.columns.drop(list(df_fundos.filter(regex='Quantidade')))]
df_fundos_tirar.drop('Fundo', axis=1, inplace=True)
df_fundos_tirar

df_fundos = df_fundos.drop(df_fundos_tirar, axis=1)
#Dropar fundos == Total
df_fundos = df_fundos[df_fundos['Fundo'] != 'Total']
df_fundos
dict_pesos = {}
fundos = df_fundos['Fundo'].unique()
# Selecionar todas as colunas que representam quantidades
colunas_quantidade = [col for col in df_fundos.columns if 'Quantidade' in col]
for fundo in fundos:
    for col in colunas_quantidade:
        dict_pesos[fundo] =+ abs(df_fundos[df_fundos['Fundo'] == fundo][col]).sum()

dict_pesos
# Out:
#        Ativo  Preco_Fechamento_Atual  2025-01-03 - PL  \
# 0   TREASURY               109156.20     1.172564e+07
# 1       WDO1                59197.84     1.172564e+07
# 2      DI_35                25490.46     1.172564e+07
# 3   TREASURY               109156.20     1.179062e+08
# 4       WDO1                59197.84     1.179062e+08
# 5      DI_35                25490.46     1.179062e+08
# 6   TREASURY               109156.20     4.548444e+07
# 7       WDO1                59197.84     4.548444e+07
# 8      DI_35                25490.46     4.548444e+07
# 9   TREASURY               109156.20     2.962062e+07
# 10      WDO1                59197.84     2.962062e+07
# 11     DI_35                25490.46     2.962062e+07
# 12  TREASURY               109156.20     2.411537e+08
# 13      WDO1                59197.84     2.411537e+08
# 14     DI_35                25490.46     2.411537e+08
# 15  TREASURY               109156.20     1.920447e+08
# 16      WDO1                59197.84     1.920447e+08
# 17     DI_35                25490.46     1.920447e+08
# 18  TREASURY               109156.20     4.054879e+07
# 19      WDO1                59197.84     4.054879e+07
# 20     DI_35                25490.46     4.054879e+07
# 21  TREASURY               109156.20     3.655494e+07
# 22      WDO1                59197.84     3.655494e+07
# 23     DI_35                25490.46     3.655494e+07
# 24  TREASURY               109156.20     3.071105e+07
# 25      WDO1                59197.84     3.071105e+07
# 26     DI_35                25490.46     3.071105e+07
# 27  TREASURY               109156.20     2.120149e+09
# 28      WDO1                59197.84     2.120149e+09
# 29     DI_35                25490.46     2.120149e+09
#
#     2025-01-03 - Preco_Fechamento  2025-01-03 - Preco_Compra  \
# 0                       108640.60                   108900.0
# 1                        62130.21                    60000.0
# 2                        25882.86                    25890.0
# 3                       108640.60                   108900.0
# 4                        62130.21                    60000.0
# 5                        25882.86                    25890.0
# 6                       108640.60                   108900.0
# 7                        62130.21                    60000.0
# 8                        25882.86                    25890.0
# 9                       108640.60                   108900.0
# 10                       62130.21                    60000.0
# 11                       25882.86                    25890.0
# 12                      108640.60                   108900.0
# 13                       62130.21                    60000.0
# 14                       25882.86                    25890.0
# 15                      108640.60                   108900.0
# 16                       62130.21                    60000.0
# 17                       25882.86                    25890.0
# 18                      108640.60                   108900.0
# 19                       62130.21                    60000.0
# 20                       25882.86                    25890.0
# 21                      108640.60                   108900.0
# 22                       62130.21                    60000.0
# 23                       25882.86                    25890.0
# 24                      108640.60                   108900.0
# 25                       62130.21                    60000.0
# 26                       25882.86                    25890.0
# 27                      108640.60                   108900.0
# 28                       62130.21                    60000.0
# 29                       25882.86                    25890.0
#
#     2025-01-03 - Quantidade  2025-01-03 - Rendimento                Fundo
# 0                       0.0                -0.000000  AF DEB INCENTIVADAS
# 1                       0.0                 0.000000  AF DEB INCENTIVADAS
# 2                       0.0                -0.000000  AF DEB INCENTIVADAS
# 3                       0.0                -0.000000        BH FIRF INFRA
# 4                       0.0                 0.000000        BH FIRF INFRA
# 5                       0.0                -0.000000        BH FIRF INFRA
# 6                       0.0                -0.000000       BORDEAUX INFRA
# 7                       0.0                 0.000000       BORDEAUX INFRA
# 8                       0.0                -0.000000       BORDEAUX INFRA
# 9                       0.0                -0.000000         GLOBAL BONDS
# 10                      0.0                 0.000000         GLOBAL BONDS
# 11                      0.0                -0.000000         GLOBAL BONDS
# 12                     -1.0              1535.591970            HORIZONTE
# 13                      1.0              2130.210000            HORIZONTE
# 14                     -1.0                 7.140000            HORIZONTE
# 15                     -1.0              1535.591970             JERA2026
# 16                      1.0              2130.210000             JERA2026
# 17                     -1.0                 7.140000             JERA2026
# 18                      0.0                -0.000000    MANACA INFRA FIRF
# 19                      0.0                 0.000000    MANACA INFRA FIRF
# 20                      0.0                -0.000000    MANACA INFRA FIRF
# 21                      0.0                -0.000000             REAL FIM
# 22                      0.0                 0.000000             REAL FIM
# 23                      0.0                -0.000000             REAL FIM
# 24                      0.0                -0.000000        TOPAZIO INFRA
# 25                      0.0                 0.000000        TOPAZIO INFRA
# 26                      0.0                -0.000000        TOPAZIO INFRA
# 27                     -2.0              3071.183939                Total
# 28                      2.0              4260.420000                Total
# 29                     -2.0                14.280000                Total

# %%
#Dropar todas as colunas que não terminem com quantidade
df_fundos_tirar = df_fundos[df_fundos.columns.drop(list(df_fundos.filter(regex='Quantidade')))]
df_fundos_tirar.drop('Fundo', axis=1, inplace=True)
df_fundos_tirar

df_fundos = df_fundos.drop(df_fundos_tirar, axis=1)
#Dropar fundos == Total
df_fundos = df_fundos[df_fundos['Fundo'] != 'Total']
df_fundos
dict_pesos = {}
fundos = df_fundos['Fundo'].unique()
# Selecionar todas as colunas que representam quantidades
colunas_quantidade = [col for col in df_fundos.columns if 'Quantidade' in col]
for fundo in fundos:
    for col in colunas_quantidade:
        dict_pesos[fundo] =+ abs(df_fundos[df_fundos['Fundo'] == fundo][col]).sum()

dict_pesos
# Out:
# C:\Users\emanuel.cabral\AppData\Local\Temp\ipykernel_1196\1196308845.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fundos_tirar.drop('Fundo', axis=1, inplace=True)
#     2025-01-03 - Quantidade                Fundo
# 0                       0.0  AF DEB INCENTIVADAS
# 1                       0.0  AF DEB INCENTIVADAS
# 2                       0.0  AF DEB INCENTIVADAS
# 3                       0.0        BH FIRF INFRA
# 4                       0.0        BH FIRF INFRA
# 5                       0.0        BH FIRF INFRA
# 6                       0.0       BORDEAUX INFRA
# 7                       0.0       BORDEAUX INFRA
# 8                       0.0       BORDEAUX INFRA
# 9                       0.0         GLOBAL BONDS
# 10                      0.0         GLOBAL BONDS
# 11                      0.0         GLOBAL BONDS
# 12                     -1.0            HORIZONTE
# 13                      1.0            HORIZONTE
# 14                     -1.0            HORIZONTE
# 15                     -1.0             JERA2026
# 16                      1.0             JERA2026
# 17                     -1.0             JERA2026
# 18                      0.0    MANACA INFRA FIRF
# 19                      0.0    MANACA INFRA FIRF
# 20                      0.0    MANACA INFRA FIRF
# 21                      0.0             REAL FIM
# 22                      0.0             REAL FIM
# 23                      0.0             REAL FIM
# 24                      0.0        TOPAZIO INFRA
# 25                      0.0        TOPAZIO INFRA
# 26                      0.0        TOPAZIO INFRA
# 27                     -2.0                Total
# 28                      2.0                Total
# 29                     -2.0                Total

# %%
#Dropar fundos == Total
df_fundos = df_fundos[df_fundos['Fundo'] != 'Total']
df_fundos
dict_pesos = {}
fundos = df_fundos['Fundo'].unique()
# Selecionar todas as colunas que representam quantidades
colunas_quantidade = [col for col in df_fundos.columns if 'Quantidade' in col]
for fundo in fundos:
    for col in colunas_quantidade:
        dict_pesos[fundo] =+ abs(df_fundos[df_fundos['Fundo'] == fundo][col]).sum()

dict_pesos
    # Selecionar todas as
# Out:
# {'AF DEB INCENTIVADAS': 0.0,
#  'BH FIRF INFRA': 0.0,
#  'BORDEAUX INFRA': 0.0,
#  'GLOBAL BONDS': 0.0,
#  'HORIZONTE': 3.0,
#  'JERA2026': 3.0,
#  'MANACA INFRA FIRF': 0.0,
#  'REAL FIM': 0.0,
#  'TOPAZIO INFRA': 0.0}

# %%
files = os.listdir('BaseFundos')    
df_b3_fechamento = pd.read_csv("df_preco_de_ajuste_atual.csv")
df_b3_fechamento = df_b3_fechamento.replace('\.', '', regex=True)
df_b3_fechamento = df_b3_fechamento.replace(',', '.', regex=True)
df_b3_fechamento.iloc[:, 1:] = df_b3_fechamento.iloc[:, 1:].astype(float)
df_b3_fechamento.loc[df_b3_fechamento['Assets'] == 'TREASURY', df_b3_fechamento.columns !=
                        'Assets'] = df_b3_fechamento.loc[df_b3_fechamento['Assets'] == 'TREASURY', df_b3_fechamento.columns != 'Assets'] * 1000

#multiplicar dolar por 10
df_b3_fechamento.loc[df_b3_fechamento['Assets'] == 'WDO1', df_b3_fechamento.columns !=
                     'Assets'] = df_b3_fechamento.loc[df_b3_fechamento['Assets'] == 'WDO1', df_b3_fechamento.columns != 'Assets'] * 10
df_b3_fechamento
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\.'
# <>:3: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\emanuel.cabral\AppData\Local\Temp\ipykernel_7156\346421930.py:3: SyntaxWarning: invalid escape sequence '\.'
#   df_b3_fechamento = df_b3_fechamento.replace('\.', '', regex=True)
#       Assets 2025-01-02 2025-01-03 2025-01-06 2025-01-07 2025-01-08  \
# 0      DAP25   98420.08   98537.44   98566.96    98606.0   98589.62
# 1      DAP26   88536.62   88708.86   88894.14   88906.74   88985.51
# 2      DAP27    83678.7   83886.14   84166.83   84173.14   84216.02
# 3      DAP28   75982.66   76132.39   76434.84   76381.23    76429.4
# 4      DAP29   72298.68    72349.2   72574.18   72334.21   72471.68
# 5      DAP30   66333.67   66353.05   66578.79   66357.52   66308.42
# 6      DAP32   57412.89   57107.32    57486.7   57181.02   57117.54
# 7      DAP33   54417.48   54181.57   54617.59   54506.96   54522.76
# 8      DAP35   47304.65   47182.63   47468.03   47164.85   47359.26
# 9      DAP40   33461.41   33475.62   33767.22   33504.04   33878.97
# 10     DAP45   23630.53   23641.67   23840.78   23933.04   23768.95
# 11     DAP50   15974.11   16027.96   16238.97   16382.75   16240.48
# 12     DAP55   11422.13   11473.62   11622.86   11807.21   11655.61
# 13     DAP60     7847.2    7906.55    8037.55    8205.85    8047.39
# 14     DI_26   86812.34   86950.54   87057.54   87081.12   87160.83
# 15     DI_27   74824.27   75135.35   75344.87   75317.94   75386.58
# 16     DI_28   64753.44   65159.49   65510.26   65440.86   65418.97
# 17     DI_29   56356.33   56818.25   57270.12   57148.76   57028.06
# 18     DI_30   49138.87   49646.42    50148.6   50006.23   49781.28
# 19     DI_31   42922.79   43406.74   43964.63   43752.62   43501.71
# 20     DI_32   37548.07   38009.88   38570.95   38361.41    38056.8
# 21     DI_33   32856.11   33364.85   33907.77    33680.1   33348.15
# 22     DI_34   28891.53   29402.98   29945.06    29702.5    29368.4
# 23     DI_35    25365.1   25882.86   26437.04   26179.43    25828.5
# 24     DI_36   22304.03   22804.15   23340.63   23089.19   22747.56
# 25     DI_37    19620.1   20100.29   20616.54   20372.87   20042.58
# 26     DI_38   17303.22   17761.73   18255.74   18021.19   17703.95
# 27     DI_39   14926.11   15351.61   15811.02   15591.94   15296.17
# 28     DI_40   13025.91   13423.72   13854.13    13648.0   13370.24
# 29  TREASURY   108812.5   108640.6   108531.2   108171.8   108140.6
# 30      WDO1    61923.0   62130.21   61430.28   61309.18   61463.52
#
#    2025-01-09 2025-01-10 2025-01-13 2025-01-14 2025-01-15 2025-01-16  \
# 0     98605.9   98600.13   98688.39   98728.79   98701.51   98711.42
# 1    88839.95   88774.27   88813.71   88813.96   88814.33   88827.83
# 2    84167.76   84065.34   84090.24   84187.56   84302.89   84345.68
# 3    76426.78   76322.91   76244.76    76368.7   76593.88   76566.03
# 4    72435.19   72283.27   72160.86   72384.21   72636.96   72600.59
# 5    66293.65   66108.37   65890.08   66113.47   66303.31   66220.66
# 6    57174.43   56911.25   56729.12   56984.85   57241.62   57058.48
# 7    54664.93   54428.38   54276.75   54460.07    54686.0   54408.02
# 8    47372.93   47296.15   47129.52   47323.51   47382.39   47170.64
# 9     33814.9   33343.71    33151.4   33208.67   33376.65   33203.46
# 10    23766.7   23471.01   23236.04   23409.39   23664.03   23449.18
# 11   16279.75   16115.57   15926.77   16117.13   16348.44   16156.86
# 12   11649.08   11512.56    11387.3   11519.11   11734.52   11593.78
# 13    8025.83    7889.17    7788.18    7885.87    8090.69    7955.57
# 14   87241.86   87195.29   87335.38   87416.06   87518.61   87508.82
# 15   75577.62   75444.09   75673.29   75821.48   76108.95   75941.34
# 16   65705.64   65422.71   65634.63   65865.49   66349.81   66059.28
# 17   57342.55    56928.6   57083.62   57372.05   58047.73   57656.34
# 18   50064.04   49564.77    49654.3   49991.23   50750.32   50287.21
# 19    43728.6   43179.16   43205.64   43576.12   44361.94   43811.31
# 20   38229.84   37676.43   37643.08   38014.83   38792.97   38199.22
# 21    33484.3   32920.29   32884.16   33262.72   34012.65   33425.87
# 22   29471.48   28908.35   28850.28   29208.99   29961.55   29350.19
# 23   25900.69   25349.94   25278.69   25641.95   26336.55   25734.23
# 24   22816.23   22281.63   22211.42   22561.64   23233.84   22648.41
# 25   20107.65   19592.23   19523.71   19859.36   20505.92   19940.72
# 26    17765.4   17271.58   17205.29   17525.26   18143.64   17601.41
# 27   15352.75   14893.38   14831.31   15127.82   15702.54   15197.44
# 28   13422.73   12992.27   12933.74   13210.55   13748.65    13274.7
# 29   108218.7   107390.6   107234.3   107359.3   108328.1   108609.3
# 30   60796.23   61235.27    61107.7   60707.25   60437.67   60815.68
#
#    2025-01-17 2025-01-20 2025-01-21 2025-01-22 2025-01-23 2025-01-24  \
# 0    98733.37   98761.04   98762.34   98812.66   98898.98    99079.3
# 1    88880.25   88842.11   88714.33   88754.11   88717.13   88897.44
# 2    84388.43   84413.08   84221.86   84210.99   84200.25   84422.13
# 3    76513.09   76510.75   76332.54    76355.6   76253.53    76476.9
# 4    72477.85   72441.89   72205.36   72341.71   72220.42   72327.99
# 5    66002.64   65988.47   65670.98    65825.4   65710.67   65797.71
# 6    56836.49   56655.28   56317.66   56334.71   56234.19   56329.63
# 7    54007.32   53899.03    53585.3   53560.31    53494.4   53633.47
# 8    46781.56   46617.53   46190.11   46335.79   46130.08   46363.42
# 9    32874.55   32704.37    32362.4   32325.22   32399.76   32671.26
# 10   23149.31   22939.57   22676.53   22772.67   22634.51    22747.5
# 11   16062.37   15930.77   15526.56   15571.47    15444.2   15507.14
# 12   11327.06   11178.92   11017.39   11063.87   10946.92   10971.58
# 13    7743.43    7619.35    7492.41     7524.2    7430.59    7464.56
# 14   87515.57   87587.23   87624.76   87699.87   87660.72   87637.39
# 15   75912.13   76071.37   76076.82   76159.07    75991.5   75925.41
# 16   65957.96   66231.08    66220.7   66338.64   66081.13   66049.61
# 17   57452.87   57828.83   57780.16   57908.74   57616.98   57592.59
# 18   49970.51   50358.09   50304.44   50487.08   50116.73   50119.23
# 19   43420.81   43814.78   43746.88   43969.31   43585.07   43571.51
# 20   37759.16   38101.49   38051.73   38313.58   37882.26   37878.47
# 21   32932.54   33271.96   33210.31   33480.96   33012.79   33040.25
# 22   28831.35   29114.55   29065.18   29316.45   28846.19   28875.58
# 23   25180.07    25470.9   25390.75    25659.6   25192.53   25191.34
# 24   22110.91   22390.87   22312.02   22570.91   22117.77   22086.08
# 25   19422.93   19690.86   19553.18   19800.23   19365.13   19307.83
# 26   17105.73    17360.8   17228.42   17463.66   17047.23    16965.1
# 27   14736.72   14972.82    14849.4    15067.2   14680.23   14603.55
# 28   12843.34    13063.5   12947.61   13150.76   12788.56   12716.47
# 29   108546.8   108546.8   108734.3   108562.5   108375.0   108468.7
# 30   60740.69   60563.88   60373.75    59411.4   59132.57   59106.65
#
#    2025-01-27
# 0    99088.91
# 1    88885.95
# 2     84393.3
# 3    76424.83
# 4    72349.79
# 5    65817.55
# 6    56346.71
# 7    53608.51
# 8    46267.35
# 9    32488.49
# 10   22737.07
# 11   15497.03
# 12   10971.71
# 13    7466.73
# 14   87675.04
# 15   76012.82
# 16   66204.05
# 17   57810.67
# 18   50386.43
# 19   43859.93
# 20    38175.2
# 21   33322.75
# 22   29160.85
# 23   25490.46
# 24   22373.62
# 25   19581.69
# 26   17225.26
# 27   14844.21
# 28   12940.72
# 29   109156.2
# 30   59197.84

# %%
df_pl_processado_input = pd.read_csv("df_pl_processado_input.csv")
#Ficar com as colunas Fundos/Carteiras Adm	PL	Weights	PL_atualizado	Adm	Max Contratos DI_35	Max Contratos TREASURY	Max Contratos WDO1	Contratos DI_35	Contratos TREASURY	Contratos WDO1
df_pl_processado_input = df_pl_processado_input[['Fundos/Carteiras Adm', 'PL', 'Weights', 'PL_atualizado', 'Adm', 'Max Contratos DI_35', 'Max Contratos TREASURY', 'Max Contratos WDO1', 'Contratos DI_35', 'Contratos TREASURY', 'Contratos WDO1']]
df_pl_processado_input
# Out:
#   Fundos/Carteiras Adm           PL  Weights  PL_atualizado        Adm  \
# 0         GLOBAL BONDS   29796115.0      4.0    119184460.0  SANTANDER
# 1            HORIZONTE  240930319.0      1.0    240930319.0        BTG
# 2             JERA2026  191147694.0      2.0    382295388.0  SANTANDER
# 3             REAL FIM   36463215.0      2.0     72926430.0  SANTANDER
# 4        BH FIRF INFRA   77314727.0      2.0    154629454.0        BTG
# 5       BORDEAUX INFRA   45417246.0      2.0     90834492.0        BTG
# 6        TOPAZIO INFRA   30777380.0      2.0     61554760.0        BTG
# 7    MANACA INFRA FIRF   40334603.0      2.0     80669206.0        BTG
# 8  AF DEB INCENTIVADAS   11563897.0      3.0     34691691.0        BTG
#
#    Max Contratos DI_35  Max Contratos TREASURY  Max Contratos WDO1  \
# 0            19.740240                2.407346           13.673727
# 1            39.904718                4.866429           27.641317
# 2            63.318679                7.721790           43.859768
# 3            12.078632                1.473004            8.366662
# 4            25.610910                3.123282           17.740240
# 5            15.044702                1.834720           10.421208
# 6            10.195169                1.243313            7.062019
# 7            13.361049                1.629396            9.254971
# 8             5.745903                0.700720            3.980089
#
#    Contratos DI_35  Contratos TREASURY  Contratos WDO1
# 0        -0.192588           -0.192588        0.192588
# 1        -0.389314           -0.389314        0.389314
# 2        -0.617743           -0.617743        0.617743
# 3        -0.117840           -0.117840        0.117840
# 4        -0.249863           -0.249863        0.249863
# 5        -0.146778           -0.146778        0.146778
# 6        -0.099465           -0.099465        0.099465
# 7        -0.130352           -0.130352        0.130352
# 8        -0.056058           -0.056058        0.056058

# %%
def calculate_contracts_per_fund_input(df_pl, df_precos):
    for i in range(len(df_precos)):
        df_pl[f'Contratos {df_precos.index[i]}'] = (
            df_pl['PL_atualizado'] /
            df_pl['PL_atualizado'].sum()
        ) * df_precos.iloc[i]['Quantidade']

        # df_pl[f'Contratos {df_precos.index[i]}'] = df_pl[f'Contratos {df_precos.index[i]}'].apply(
        #    lambda x: round(x, 0))
    return df_pl

# %%
def read_atual_contratos():
        files = os.listdir('BaseFundos')
        df_fundos = pd.DataFrame()
        lista_files = []
        for file in files:
            df_fundos = pd.concat([df_fundos, pd.read_csv(f'BaseFundos/{file}')])
            #Adiciona o nome do arquivo como uma linha da coluna Fundo
            contagem = df_fundos['Ativo'].unique()
            contagem = len(contagem)
            for i in range(contagem):
                lista_files.append(file.split('.')[0])
        #Pegar a quantidade de ativos unicos
        df_fundos['Fundo'] = lista_files 
        df_fundos = df_fundos.reset_index(drop=True)
        contratos = []

        for fundo in df_fundos['Fundo'].unique():
            ativos = df_fundos[df_fundos['Fundo'] == fundo]
            col_quantidade = [col for col in ativos.columns if col.endswith('Quantidade')]
            
            # Agrupar por ativo e somar as quantidades
            agrupados = ativos.groupby('Ativo')[col_quantidade].sum().reset_index()
            
            for idx, row in agrupados.iterrows():
                quantidade = row[col_quantidade].sum()  # Soma total das colunas 'Quantidade'
                contratos.append([fundo, row['Ativo'], quantidade])

        #DF_CONTRATOS TEM O FUNDO COMO INDEX, ATIVO COMO COLUNA E A QUANTIDADE DE CONTRATOS COMO VALOR
        df_contratos = pd.DataFrame(contratos, columns=['Fundo', 'Ativo', 'Quantidade'])
        df_contratos = df_contratos.pivot(index='Fundo', columns='Ativo', values='Quantidade')
        df_contratos = df_contratos.fillna(0)
        return df_contratos

# %%
df_pl_processado = pd.read_csv("df_pl_processado.csv")
#Ficar somente com colunas Fundos/Carteiras Adm	PL	Weights	PL_atualizado	Adm	Max Contratos DI_35	Max Contratos TREASURY	Max Contratos WDO1
df_pl_processado = df_pl_processado[['Fundos/Carteiras Adm', 'PL', 'Weights', 'PL_atualizado', 'Adm', 'Max Contratos DI_35', 'Max Contratos TREASURY', 'Max Contratos WDO1']]
df_precos_ajustados = pd.read_csv("df_precos_ajustados.csv")
#Mudar o nome da primeira coluna para Assets
df_precos_ajustados = df_precos_ajustados.rename(columns={'Unnamed: 0': 'Assets'})
#Colocar como index
df_precos_ajustados = df_precos_ajustados.set_index('Assets')
df_precos_ajustados
# Out:
#          Valor Fechamento Valor Fechamento Ajustado pelo Var  Santander  BTG  \
# Assets
# DI_35            R$25,890                              R$603         95  110
# TREASURY        R$659,986                            R$4,945         12   13
# WDO1             R$60,775                              R$874         66   76
#
#           Valor Total  Quantidade
# Assets
# DI_35             205          -2
# TREASURY           25          -2
# WDO1              142           2

# %%
df_pl_processado
# Out:
#   Fundos/Carteiras Adm           PL  Weights  PL_atualizado        Adm  \
# 0         GLOBAL BONDS   29796115.0      4.0    119184460.0  SANTANDER
# 1            HORIZONTE  240930319.0      1.0    240930319.0        BTG
# 2             JERA2026  191147694.0      2.0    382295388.0  SANTANDER
# 3             REAL FIM   36463215.0      2.0     72926430.0  SANTANDER
# 4        BH FIRF INFRA   77314727.0      2.0    154629454.0        BTG
# 5       BORDEAUX INFRA   45417246.0      2.0     90834492.0        BTG
# 6        TOPAZIO INFRA   30777380.0      2.0     61554760.0        BTG
# 7    MANACA INFRA FIRF   40334603.0      2.0     80669206.0        BTG
# 8  AF DEB INCENTIVADAS   11563897.0      3.0     34691691.0        BTG
#
#    Max Contratos DI_35  Max Contratos TREASURY  Max Contratos WDO1
# 0            19.740240                2.407346           13.673727
# 1            39.904718                4.866429           27.641317
# 2            63.318679                7.721790           43.859768
# 3            12.078632                1.473004            8.366662
# 4            25.610910                3.123282           17.740240
# 5            15.044702                1.834720           10.421208
# 6            10.195169                1.243313            7.062019
# 7            13.361049                1.629396            9.254971
# 8             5.745903                0.700720            3.980089

# %%
quantidade_nomes = {'DI_35'	: -2, 'TREASURY':-2	, 'WDO1':2 }
assets = ['DI_35', 'TREASURY', 'WDO1']

# %%
filtered_df = df_pl_processado_input.copy()

for asset in assets:
    # Verifica se a soma dos contratos arredondados está correta
    soma_atual = filtered_df[f'Contratos {asset}'].apply(
        lambda x: round(x)).sum()

    if soma_atual == quantidade_nomes[asset]:
        continue
    else:
        # Calcula o número de contratos que faltam ou excedem
        diferencas = quantidade_nomes[asset] - soma_atual

        # Calcula o peso relativo e os resíduos
        filtered_df['Peso Relativo'] = (
            filtered_df[f'Contratos {asset}'] /
            filtered_df[f'Contratos {asset}'].sum()
        )
        filtered_df['Contratos Proporcionais'] = (
            filtered_df['Peso Relativo'] * quantidade_nomes[asset]
        )
        filtered_df['Contratos Inteiros'] = filtered_df['Contratos Proporcionais'].apply(
            np.floor).astype(int)
        filtered_df['Resíduo'] = filtered_df['Contratos Proporcionais'] - \
            filtered_df['Contratos Inteiros']

        # Ajusta contratos restantes com base nos pesos e resíduos
        contratos_restantes = quantidade_nomes[asset] - \
            filtered_df['Contratos Inteiros'].sum()

        if contratos_restantes != 0:
            # Ordena para priorizar maior resíduo e maior peso relativo
            ordem_ajuste = filtered_df.sort_values(
                by=['Resíduo', 'Peso Relativo'], ascending=[False, False]).index if contratos_restantes > 0 else \
                filtered_df.sort_values(
                    by=['Resíduo', 'Peso Relativo'], ascending=[True, True]).index

            for i in range(abs(contratos_restantes)):
                idx_to_adjust = ordem_ajuste[i]
                filtered_df.at[idx_to_adjust,
                                'Contratos Inteiros'] += 1 if contratos_restantes > 0 else -1

        # Atualiza a coluna final com os contratos ajustados
        filtered_df[f'Contratos {asset}'] = filtered_df['Contratos Inteiros']

        # Remove colunas auxiliares
        filtered_df.drop(columns=[
            'Peso Relativo', 'Contratos Proporcionais', 'Contratos Inteiros', 'Resíduo'], inplace=True)
filtered_df
# Out:
#   Fundos/Carteiras Adm           PL  Weights  PL_atualizado        Adm  \
# 0         GLOBAL BONDS   29796115.0      4.0    119184460.0  SANTANDER
# 1            HORIZONTE  240930319.0      1.0    240930319.0        BTG
# 2             JERA2026  191147694.0      2.0    382295388.0  SANTANDER
# 3             REAL FIM   36463215.0      2.0     72926430.0  SANTANDER
# 4        BH FIRF INFRA   77314727.0      2.0    154629454.0        BTG
# 5       BORDEAUX INFRA   45417246.0      2.0     90834492.0        BTG
# 6        TOPAZIO INFRA   30777380.0      2.0     61554760.0        BTG
# 7    MANACA INFRA FIRF   40334603.0      2.0     80669206.0        BTG
# 8  AF DEB INCENTIVADAS   11563897.0      3.0     34691691.0        BTG
#
#    Max Contratos DI_35  Max Contratos TREASURY  Max Contratos WDO1  \
# 0            19.740240                2.407346           13.673727
# 1            39.904718                4.866429           27.641317
# 2            63.318679                7.721790           43.859768
# 3            12.078632                1.473004            8.366662
# 4            25.610910                3.123282           17.740240
# 5            15.044702                1.834720           10.421208
# 6            10.195169                1.243313            7.062019
# 7            13.361049                1.629396            9.254971
# 8             5.745903                0.700720            3.980089
#
#    Contratos DI_35  Contratos TREASURY  Contratos WDO1
# 0                0                   0               0
# 1               -1                  -1               1
# 2               -1                  -1               1
# 3                0                   0               0
# 4                0                   0               0
# 5                0                   0               0
# 6                0                   0               0
# 7                0                   0               0
# 8                0                   0               0

# %%
dia_atual = '2025-01-24'

# %%
import pandas as pd
import datetime

df_final = pd.DataFrame()

# Supõe-se que `files`, `df_b3_fechamento`, e `dia_atual` estão definidos
for file in files:
    # Lê o arquivo CSV
    df_fundos = pd.read_csv(f'BaseFundos/{file}')
    file = file.split('.')[0]  # Remove a extensão do nome do arquivo

    # Configura o índice para a coluna 'Ativo'
    df_fundos.set_index('Ativo', inplace=True)

    # DataFrame para armazenar os rendimentos por operação e por dia
    df_rendimentos = pd.DataFrame()

    # Itera pelas linhas do DataFrame
    for idx, row in df_fundos.iterrows():
        # Identifica as colunas relacionadas a 'Quantidade' e 'Preço de Compra'
        col_quantidade = [col for col in df_fundos.columns if col.endswith('Quantidade')]
        col_preco_compra = [col.replace('Quantidade', 'Preco_Compra') for col in col_quantidade]

        # Cria uma variável para rastrear a posição acumulada
        posicao_acumulada = 0
        preco_medio_acumulado = 0

        # Processa cada operação (quantidade/compras de cada dia)
        for col, col_preco in zip(col_quantidade, col_preco_compra):
            quantidade = row[col]

            # Ignorar operações com quantidade 0
            if pd.isna(quantidade) or quantidade == 0:
                continue
            
            # Atualiza posição acumulada e preço médio
            preco_compra = row[col_preco]
            posicao_acumulada += quantidade
            if posicao_acumulada > 0:
                preco_medio_acumulado = (
                    (preco_medio_acumulado * (posicao_acumulada - quantidade) + preco_compra * quantidade) 
                    / posicao_acumulada
                )

            # Extrai a data da coluna
            data_operacao = col.split(' ')[0]

            # Itera por cada data no DataFrame de fechamentos (até o dia atual)
            for data_fechamento in df_b3_fechamento.columns[1:]:  # Ignora a coluna de "Assets"
                # Calcula o rendimento apenas se a data de fechamento for posterior à data de operação
                if datetime.datetime.strptime(data_fechamento, '%Y-%m-%d') >= datetime.datetime.strptime(data_operacao, '%Y-%m-%d'):
                    # Preço de fechamento no dia específico
                    preco_fechamento = df_b3_fechamento.loc[
                        df_b3_fechamento["Assets"] == idx, data_fechamento
                    ].values[0]

                    # Calcula o rendimento apenas se houver posição acumulada
                    if posicao_acumulada > 0:
                        rendimento = (preco_fechamento - preco_medio_acumulado) * posicao_acumulada
                    else:
                        rendimento = 0

                    # Adiciona o rendimento ao DataFrame de resultados
                    df_rendimentos.loc[f"{idx} - {data_operacao}", data_fechamento] = rendimento

        # Verifica se há dados no DataFrame `df_rendimentos`
        if not df_rendimentos.empty:
            # Adicionar uma linha de total
            df_rendimentos.loc['Total'] = df_rendimentos.sum()

            # Dropar as linhas que não sejam 'Total'
            df_rendimentos_append = df_rendimentos.loc[['Total']].copy()

            # Renomear a linha Total
            df_rendimentos_append.rename(index={'Total': f'{idx} - {file} - Total Rendimentos'}, inplace=True)

            # Adicionar a nova linha ao DataFrame final
            df_final = pd.concat([df_final, df_rendimentos_append])

df_final
# Out:
#                                           2025-01-03  2025-01-06  2025-01-07  \
# TREASURY - HORIZONTE - Total Rendimentos        0.00        0.00        0.00
# WDO1 - HORIZONTE - Total Rendimentos         2130.21     1430.28     1309.18
# DI_35 - HORIZONTE - Total Rendimentos        4260.42     2860.56     2618.36
# TREASURY - JERA2026 - Total Rendimentos         0.00        0.00        0.00
# WDO1 - JERA2026 - Total Rendimentos          2130.21     1430.28     1309.18
# DI_35 - JERA2026 - Total Rendimentos         4260.42     2860.56     2618.36
# TREASURY - Total - Total Rendimentos            0.00        0.00        0.00
# WDO1 - Total - Total Rendimentos             4260.42     2860.56     2618.36
# DI_35 - Total - Total Rendimentos            8520.84     5721.12     5236.72
#
#                                           2025-01-08  2025-01-09  2025-01-10  \
# TREASURY - HORIZONTE - Total Rendimentos        0.00        0.00        0.00
# WDO1 - HORIZONTE - Total Rendimentos         1463.52      796.23     1235.27
# DI_35 - HORIZONTE - Total Rendimentos        2927.04     1592.46     2470.54
# TREASURY - JERA2026 - Total Rendimentos         0.00        0.00        0.00
# WDO1 - JERA2026 - Total Rendimentos          1463.52      796.23     1235.27
# DI_35 - JERA2026 - Total Rendimentos         2927.04     1592.46     2470.54
# TREASURY - Total - Total Rendimentos            0.00        0.00        0.00
# WDO1 - Total - Total Rendimentos             2927.04     1592.46     2470.54
# DI_35 - Total - Total Rendimentos            5854.08     3184.92     4941.08
#
#                                           2025-01-13  2025-01-14  2025-01-15  \
# TREASURY - HORIZONTE - Total Rendimentos         0.0        0.00        0.00
# WDO1 - HORIZONTE - Total Rendimentos          1107.7      707.25      437.67
# DI_35 - HORIZONTE - Total Rendimentos         2215.4     1414.50      875.34
# TREASURY - JERA2026 - Total Rendimentos          0.0        0.00        0.00
# WDO1 - JERA2026 - Total Rendimentos           1107.7      707.25      437.67
# DI_35 - JERA2026 - Total Rendimentos          2215.4     1414.50      875.34
# TREASURY - Total - Total Rendimentos             0.0        0.00        0.00
# WDO1 - Total - Total Rendimentos              2215.4     1414.50      875.34
# DI_35 - Total - Total Rendimentos             4430.8     2829.00     1750.68
#
#                                           2025-01-16  2025-01-17  2025-01-20  \
# TREASURY - HORIZONTE - Total Rendimentos        0.00        0.00        0.00
# WDO1 - HORIZONTE - Total Rendimentos          815.68      740.69      563.88
# DI_35 - HORIZONTE - Total Rendimentos        1631.36     1481.38     1127.76
# TREASURY - JERA2026 - Total Rendimentos         0.00        0.00        0.00
# WDO1 - JERA2026 - Total Rendimentos           815.68      740.69      563.88
# DI_35 - JERA2026 - Total Rendimentos         1631.36     1481.38     1127.76
# TREASURY - Total - Total Rendimentos            0.00        0.00        0.00
# WDO1 - Total - Total Rendimentos             1631.36     1481.38     1127.76
# DI_35 - Total - Total Rendimentos            3262.72     2962.76     2255.52
#
#                                           2025-01-21  2025-01-22  2025-01-23  \
# TREASURY - HORIZONTE - Total Rendimentos        0.00         0.0        0.00
# WDO1 - HORIZONTE - Total Rendimentos          373.75      -588.6     -867.43
# DI_35 - HORIZONTE - Total Rendimentos         747.50     -1177.2    -1734.86
# TREASURY - JERA2026 - Total Rendimentos         0.00         0.0        0.00
# WDO1 - JERA2026 - Total Rendimentos           373.75      -588.6     -867.43
# DI_35 - JERA2026 - Total Rendimentos          747.50     -1177.2    -1734.86
# TREASURY - Total - Total Rendimentos            0.00         0.0        0.00
# WDO1 - Total - Total Rendimentos              747.50     -1177.2    -1734.86
# DI_35 - Total - Total Rendimentos            1495.00     -2354.4    -3469.72
#
#                                           2025-01-24  2025-01-27
# TREASURY - HORIZONTE - Total Rendimentos        0.00        0.00
# WDO1 - HORIZONTE - Total Rendimentos         -893.35     -802.16
# DI_35 - HORIZONTE - Total Rendimentos       -1786.70    -1604.32
# TREASURY - JERA2026 - Total Rendimentos         0.00        0.00
# WDO1 - JERA2026 - Total Rendimentos          -893.35     -802.16
# DI_35 - JERA2026 - Total Rendimentos        -1786.70    -1604.32
# TREASURY - Total - Total Rendimentos            0.00        0.00
# WDO1 - Total - Total Rendimentos            -1786.70    -1604.32
# DI_35 - Total - Total Rendimentos           -3573.40    -3208.64

# %%
import pandas as pd
import datetime

df_final = pd.DataFrame()

# Supõe-se que `files`, `df_b3_fechamento`, e `dia_atual` estão definidos
for file in files:
    # Lê o arquivo CSV
    df_fundos = pd.read_csv(f'BaseFundos/{file}')
    file = file.split('.')[0]  # Remove a extensão do nome do arquivo

    # Configura o índice para a coluna 'Ativo'
    df_fundos.set_index('Ativo', inplace=True)

    # DataFrame para armazenar os rendimentos por operação e por dia
    df_rendimentos = pd.DataFrame()

    # Itera pelas linhas do DataFrame
    for idx, row in df_fundos.iterrows():
        # Identifica as colunas relacionadas a 'Quantidade' e 'Preço de Compra'
        col_quantidade = [col for col in df_fundos.columns if col.endswith('Quantidade')]

        # Processa cada operação (quantidade/compras de cada dia)
        for col in col_quantidade:
            quantidade = row[col]

            # Ignorar operações com quantidade 0
            if quantidade == 0 or pd.isna(quantidade):
                continue
            
            # Obtém o preço de compra correspondente
            preco_compra = row[col.replace('Quantidade', 'Preco_Compra')]

            # Extrai a data da coluna
            data_operacao = col.split(' ')[0]

            # Itera por cada data no DataFrame de fechamentos (até o dia atual)
            for data_fechamento in df_b3_fechamento.columns[1:]:  # Ignora a coluna de "Assets"
                # Calcula o rendimento apenas se a data de fechamento for posterior à data de operação
                if datetime.datetime.strptime(data_fechamento, '%Y-%m-%d') >= datetime.datetime.strptime(data_operacao, '%Y-%m-%d'):
                    # Preço de fechamento no dia específico
                    preco_fechamento = df_b3_fechamento.loc[
                        df_b3_fechamento["Assets"] == idx, data_fechamento
                    ].values[0]
                    
                    # Calcula o rendimento
                    rendimento = (preco_fechamento - preco_compra) * quantidade

                    # Adiciona o rendimento ao DataFrame de resultados
                    df_rendimentos.loc[f"{idx} - {data_operacao}", data_fechamento] = rendimento

        # Verifica se há dados no DataFrame `df_rendimentos`
        if not df_rendimentos.empty:
            # Adicionar uma linha de total
            df_rendimentos.loc['Total'] = df_rendimentos.sum()

            # Dropar as linhas que não sejam 'Total'
            df_rendimentos_append = df_rendimentos.loc[['Total']].copy()

            # Renomear a linha Total
            df_rendimentos_append.rename(index={'Total': f'{idx} - {file} - Total Rendimentos'}, inplace=True)

            # Adicionar a nova linha ao DataFrame final
            df_final = pd.concat([df_final, df_rendimentos_append])

df_final
# Out:
#                                           2025-01-03  2025-01-06  2025-01-07  \
# TREASURY - HORIZONTE - Total Rendimentos      259.40      368.80      728.20
# WDO1 - HORIZONTE - Total Rendimentos         2649.01     2167.88     2765.58
# DI_35 - HORIZONTE - Total Rendimentos        5045.76     3419.92     4513.53
# TREASURY - JERA2026 - Total Rendimentos       259.40      368.80      728.20
# WDO1 - JERA2026 - Total Rendimentos          2649.01     2167.88     2765.58
# DI_35 - JERA2026 - Total Rendimentos         5045.76     3419.92     4513.53
# TREASURY - Total - Total Rendimentos          518.80      737.60     1456.40
# WDO1 - Total - Total Rendimentos             5298.02     4335.76     5531.16
# DI_35 - Total - Total Rendimentos           10091.52     6839.84     9027.06
#
#                                           2025-01-08  2025-01-09  2025-01-10  \
# TREASURY - HORIZONTE - Total Rendimentos      759.40      681.30     1509.40
# WDO1 - HORIZONTE - Total Rendimentos         2982.32     2158.83     4254.07
# DI_35 - HORIZONTE - Total Rendimentos        5266.74     3625.67     7538.80
# TREASURY - JERA2026 - Total Rendimentos       759.40      681.30     1509.40
# WDO1 - JERA2026 - Total Rendimentos          2982.32     2158.83     4254.07
# DI_35 - JERA2026 - Total Rendimentos         5266.74     3625.67     7538.80
# TREASURY - Total - Total Rendimentos         1518.80     1362.60     3018.80
# WDO1 - Total - Total Rendimentos             5964.64     4317.66     8508.14
# DI_35 - Total - Total Rendimentos           10533.48     7251.34    15077.60
#
#                                           2025-01-13  2025-01-14  2025-01-15  \
# TREASURY - HORIZONTE - Total Rendimentos     1665.70     1540.70      571.90
# WDO1 - HORIZONTE - Total Rendimentos         4439.10     3788.65     1581.47
# DI_35 - HORIZONTE - Total Rendimentos        7823.81     6284.65     2144.49
# TREASURY - JERA2026 - Total Rendimentos      1665.70     1540.70      571.90
# WDO1 - JERA2026 - Total Rendimentos          4439.10     3788.65     1581.47
# DI_35 - JERA2026 - Total Rendimentos         7823.81     6284.65     2144.49
# TREASURY - Total - Total Rendimentos         3331.40     3081.40     1143.80
# WDO1 - Total - Total Rendimentos             8878.20     7577.30     3162.94
# DI_35 - Total - Total Rendimentos           15647.62    12569.30     4288.98
#
#                                           2025-01-16  2025-01-17  2025-01-20  \
# TREASURY - HORIZONTE - Total Rendimentos      290.70      353.20      353.20
# WDO1 - HORIZONTE - Total Rendimentos         1397.08     1447.09     1270.28
# DI_35 - HORIZONTE - Total Rendimentos        2659.23     3250.91     2606.46
# TREASURY - JERA2026 - Total Rendimentos       290.70      353.20      353.20
# WDO1 - JERA2026 - Total Rendimentos          1397.08     1447.09     1270.28
# DI_35 - JERA2026 - Total Rendimentos         2659.23     3250.91     2606.46
# TREASURY - Total - Total Rendimentos          581.40      706.40      706.40
# WDO1 - Total - Total Rendimentos             2794.16     2894.18     2540.56
# DI_35 - Total - Total Rendimentos            5318.46     6501.82     5212.92
#
#                                           2025-01-21  2025-01-22  2025-01-23  \
# TREASURY - HORIZONTE - Total Rendimentos      165.70       337.5      525.00
# WDO1 - HORIZONTE - Total Rendimentos          705.15        86.4      182.57
# DI_35 - HORIZONTE - Total Rendimentos        1743.85        65.7      537.61
# TREASURY - JERA2026 - Total Rendimentos       165.70       337.5      525.00
# WDO1 - JERA2026 - Total Rendimentos           705.15        86.4      182.57
# DI_35 - JERA2026 - Total Rendimentos         1743.85        65.7      537.61
# TREASURY - Total - Total Rendimentos          331.40       675.0     1050.00
# WDO1 - Total - Total Rendimentos             1410.30       172.8      365.14
# DI_35 - Total - Total Rendimentos            3487.70       131.4     1075.22
#
#                                           2025-01-24  2025-01-27
# TREASURY - HORIZONTE - Total Rendimentos      431.30     -256.20
# WDO1 - HORIZONTE - Total Rendimentos          -30.75    -1314.56
# DI_35 - HORIZONTE - Total Rendimentos         205.86    -1973.38
# TREASURY - JERA2026 - Total Rendimentos       431.30     -256.20
# WDO1 - JERA2026 - Total Rendimentos           -30.75    -1314.56
# DI_35 - JERA2026 - Total Rendimentos          205.86    -1973.38
# TREASURY - Total - Total Rendimentos          862.60     -512.40
# WDO1 - Total - Total Rendimentos              -61.50    -2629.12
# DI_35 - Total - Total Rendimentos             411.72    -3946.76

# %%
import pandas as pd
import datetime

df_final = pd.DataFrame()

# Supõe-se que `files`, `df_b3_fechamento`, e `dia_atual` estão definidos
for file in files:
    # Lê o arquivo CSV
    df_fundos = pd.read_csv(f'BaseFundos/{file}')
    file = file.split('.')[0]  # Remove a extensão do nome do arquivo

    # Configura o índice para a coluna 'Ativo'
    df_fundos.set_index('Ativo', inplace=True)



    # Itera pelas linhas do DataFrame
    for idx, row in df_fundos.iterrows():
        # DataFrame para armazenar os rendimentos por operação e por dia
        df_rendimentos = pd.DataFrame()
        # Identifica as colunas relacionadas a 'Quantidade' e 'Preço de Compra'
        col_quantidade = [col for col in df_fundos.columns if col.endswith('Quantidade')]

        # Processa cada operação (quantidade/compras de cada dia)
        for col in col_quantidade:
            quantidade = row[col]

            # Ignorar operações com quantidade 0
            if quantidade == 0 or pd.isna(quantidade):
                continue
            
            # Obtém o preço de compra correspondente
            preco_compra = row[col.replace('Quantidade', 'Preco_Compra')]

            # Extrai a data da coluna
            data_operacao = col.split(' ')[0]

            # Itera por cada data no DataFrame de fechamentos (até o dia atual)
            for data_fechamento in df_b3_fechamento.columns[1:]:  # Ignora a coluna de "Assets"
                # Calcula o rendimento apenas se a data de fechamento for posterior à data de operação
                if datetime.datetime.strptime(data_fechamento, '%Y-%m-%d') >= datetime.datetime.strptime(data_operacao, '%Y-%m-%d'):
                    # Preço de fechamento no dia específico
                    preco_fechamento = df_b3_fechamento.loc[
                        df_b3_fechamento["Assets"] == idx, data_fechamento
                    ].values[0]
                    
                    # Calcula o rendimento
                    rendimento = (preco_fechamento - preco_compra) * quantidade

                    # Adiciona o rendimento ao DataFrame de resultados
                    df_rendimentos.loc[f"{idx} - {data_operacao}", data_fechamento] = rendimento

        # Verifica se há dados no DataFrame `df_rendimentos`
        if not df_rendimentos.empty:
            # Adicionar uma linha de total
            df_rendimentos.loc['Total'] = df_rendimentos.sum()

            # Dropar as linhas que não sejam 'Total'
            df_rendimentos_append = df_rendimentos.loc[['Total']].copy()

            # Renomear a linha Total
            df_rendimentos_append.rename(index={'Total': f'{idx} - {file} - Total Rendimentos'}, inplace=True)

            # Adicionar a nova linha ao DataFrame final
            df_final = pd.concat([df_final, df_rendimentos_append])

df_final
# Out:
#                                           2025-01-03  2025-01-06  2025-01-07  \
# TREASURY - HORIZONTE - Total Rendimentos      259.40      368.80      728.20
# WDO1 - HORIZONTE - Total Rendimentos         2130.21     1430.28     1309.18
# DI_35 - HORIZONTE - Total Rendimentos           7.14     -547.04     -289.43
# TREASURY - JERA2026 - Total Rendimentos       259.40      368.80      728.20
# WDO1 - JERA2026 - Total Rendimentos          2130.21     1430.28     1309.18
# DI_35 - JERA2026 - Total Rendimentos            7.14     -547.04     -289.43
# TREASURY - Total - Total Rendimentos          518.80      737.60     1456.40
# WDO1 - Total - Total Rendimentos             4260.42     2860.56     2618.36
# DI_35 - Total - Total Rendimentos              14.28    -1094.08     -578.86
#
#                                           2025-01-08  2025-01-09  2025-01-10  \
# TREASURY - HORIZONTE - Total Rendimentos      759.40      681.30     1509.40
# WDO1 - HORIZONTE - Total Rendimentos         1463.52      796.23     1235.27
# DI_35 - HORIZONTE - Total Rendimentos          61.50      -10.69      540.06
# TREASURY - JERA2026 - Total Rendimentos       759.40      681.30     1509.40
# WDO1 - JERA2026 - Total Rendimentos          1463.52      796.23     1235.27
# DI_35 - JERA2026 - Total Rendimentos           61.50      -10.69      540.06
# TREASURY - Total - Total Rendimentos         1518.80     1362.60     3018.80
# WDO1 - Total - Total Rendimentos             2927.04     1592.46     2470.54
# DI_35 - Total - Total Rendimentos             123.00      -21.38     1080.12
#
#                                           2025-01-13  2025-01-14  2025-01-15  \
# TREASURY - HORIZONTE - Total Rendimentos     1665.70     1540.70      571.90
# WDO1 - HORIZONTE - Total Rendimentos         1107.70      707.25      437.67
# DI_35 - HORIZONTE - Total Rendimentos         611.31      248.05     -446.55
# TREASURY - JERA2026 - Total Rendimentos      1665.70     1540.70      571.90
# WDO1 - JERA2026 - Total Rendimentos          1107.70      707.25      437.67
# DI_35 - JERA2026 - Total Rendimentos          611.31      248.05     -446.55
# TREASURY - Total - Total Rendimentos         3331.40     3081.40     1143.80
# WDO1 - Total - Total Rendimentos             2215.40     1414.50      875.34
# DI_35 - Total - Total Rendimentos            1222.62      496.10     -893.10
#
#                                           2025-01-16  2025-01-17  2025-01-20  \
# TREASURY - HORIZONTE - Total Rendimentos      290.70      353.20      353.20
# WDO1 - HORIZONTE - Total Rendimentos          815.68      740.69      563.88
# DI_35 - HORIZONTE - Total Rendimentos         155.77      709.93      419.10
# TREASURY - JERA2026 - Total Rendimentos       290.70      353.20      353.20
# WDO1 - JERA2026 - Total Rendimentos           815.68      740.69      563.88
# DI_35 - JERA2026 - Total Rendimentos          155.77      709.93      419.10
# TREASURY - Total - Total Rendimentos          581.40      706.40      706.40
# WDO1 - Total - Total Rendimentos             1631.36     1481.38     1127.76
# DI_35 - Total - Total Rendimentos             311.54     1419.86      838.20
#
#                                           2025-01-21  2025-01-22  2025-01-23  \
# TREASURY - HORIZONTE - Total Rendimentos      165.70       337.5      525.00
# WDO1 - HORIZONTE - Total Rendimentos          373.75      -588.6     -867.43
# DI_35 - HORIZONTE - Total Rendimentos         499.25       230.4      697.47
# TREASURY - JERA2026 - Total Rendimentos       165.70       337.5      525.00
# WDO1 - JERA2026 - Total Rendimentos           373.75      -588.6     -867.43
# DI_35 - JERA2026 - Total Rendimentos          499.25       230.4      697.47
# TREASURY - Total - Total Rendimentos          331.40       675.0     1050.00
# WDO1 - Total - Total Rendimentos              747.50     -1177.2    -1734.86
# DI_35 - Total - Total Rendimentos             998.50       460.8     1394.94
#
#                                           2025-01-24  2025-01-27
# TREASURY - HORIZONTE - Total Rendimentos      431.30     -256.20
# WDO1 - HORIZONTE - Total Rendimentos         -893.35     -802.16
# DI_35 - HORIZONTE - Total Rendimentos         698.66      399.54
# TREASURY - JERA2026 - Total Rendimentos       431.30     -256.20
# WDO1 - JERA2026 - Total Rendimentos          -893.35     -802.16
# DI_35 - JERA2026 - Total Rendimentos          698.66      399.54
# TREASURY - Total - Total Rendimentos          862.60     -512.40
# WDO1 - Total - Total Rendimentos            -1786.70    -1604.32
# DI_35 - Total - Total Rendimentos            1397.32      799.08

# %%
import pandas as pd
import datetime

df_final_pl = pd.DataFrame()

# Supõe-se que `files`, `df_b3_fechamento`, e `dia_atual` estão definidos
for file in files:
    # Lê o arquivo CSV
    df_fundos = pd.read_csv(f'BaseFundos/{file}')
    file = file.split('.')[0]  # Remove a extensão do nome do arquivo

    # Configura o índice para a coluna 'Ativo'
    df_fundos.set_index('Ativo', inplace=True)



    # Itera pelas linhas do DataFrame
    for idx, row in df_fundos.iterrows():
        # DataFrame para armazenar os rendimentos por operação e por dia
        df_rendimentos = pd.DataFrame()
        # Identifica as colunas relacionadas a 'Quantidade' e 'Preço de Compra'
        col_quantidade = [col for col in df_fundos.columns if col.endswith('Quantidade')]

        # Processa cada operação (quantidade/compras de cada dia)
        for col in col_quantidade:
            quantidade = row[col]

            # Ignorar operações com quantidade 0
            if quantidade == 0 or pd.isna(quantidade):
                continue
            
            # Obtém o preço de compra correspondente
            preco_compra = row[col.replace('Quantidade', 'Preco_Compra')]
            soma_pl = row[col.replace('Quantidade', 'PL')]
            # Extrai a data da coluna
            data_operacao = col.split(' ')[0]

            # Itera por cada data no DataFrame de fechamentos (até o dia atual)
            for data_fechamento in df_b3_fechamento.columns[1:]:  # Ignora a coluna de "Assets"
                # Calcula o rendimento apenas se a data de fechamento for posterior à data de operação
                if datetime.datetime.strptime(data_fechamento, '%Y-%m-%d') >= datetime.datetime.strptime(data_operacao, '%Y-%m-%d'):
                    # Preço de fechamento no dia específico
                    preco_fechamento = df_b3_fechamento.loc[
                        df_b3_fechamento["Assets"] == idx, data_fechamento
                    ].values[0]
                    
                    # Calcula o rendimento
                    rendimento = (preco_fechamento - preco_compra) * quantidade

                    rendimento = (rendimento / soma_pl ) * 10000

                    # Adiciona o rendimento ao DataFrame de resultados
                    df_rendimentos.loc[f"{idx}  EM BIPS - {data_operacao}", data_fechamento] = rendimento

        # Verifica se há dados no DataFrame `df_rendimentos`
        if not df_rendimentos.empty:
            # Adicionar uma linha de total
            df_rendimentos.loc['Total'] = df_rendimentos.sum()

            # Dropar as linhas que não sejam 'Total'
            df_rendimentos_append = df_rendimentos.loc[['Total']].copy()

            # Renomear a linha Total
            df_rendimentos_append.rename(index={'Total': f'{idx} - {file} - Total Rendimentos'}, inplace=True)

            # Adicionar a nova linha ao DataFrame final
            df_final_pl = pd.concat([df_final_pl, df_rendimentos_append])

df_final_pl
# Out:
#                                           2025-01-03  2025-01-06  2025-01-07  \
# TREASURY - HORIZONTE - Total Rendimentos    0.010757    0.015293    0.030197
# WDO1 - HORIZONTE - Total Rendimentos        0.088334    0.059310    0.054288
# DI_35 - HORIZONTE - Total Rendimentos       0.000296   -0.022684   -0.012002
# TREASURY - JERA2026 - Total Rendimentos     0.013507    0.019204    0.037918
# WDO1 - JERA2026 - Total Rendimentos         0.110923    0.074476    0.068171
# DI_35 - JERA2026 - Total Rendimentos        0.000372   -0.028485   -0.015071
# TREASURY - Total - Total Rendimentos        0.002447    0.003479    0.006869
# WDO1 - Total - Total Rendimentos            0.020095    0.013492    0.012350
# DI_35 - Total - Total Rendimentos           0.000067   -0.005160   -0.002730
#
#                                           2025-01-08  2025-01-09  2025-01-10  \
# TREASURY - HORIZONTE - Total Rendimentos    0.031490    0.028252    0.062591
# WDO1 - HORIZONTE - Total Rendimentos        0.060688    0.033018    0.051223
# DI_35 - HORIZONTE - Total Rendimentos       0.002550   -0.000443    0.022395
# TREASURY - JERA2026 - Total Rendimentos     0.039543    0.035476    0.078596
# WDO1 - JERA2026 - Total Rendimentos         0.076207    0.041461    0.064322
# DI_35 - JERA2026 - Total Rendimentos        0.003202   -0.000557    0.028122
# TREASURY - Total - Total Rendimentos        0.007164    0.006427    0.014239
# WDO1 - Total - Total Rendimentos            0.013806    0.007511    0.011653
# DI_35 - Total - Total Rendimentos           0.000580   -0.000101    0.005095
#
#                                           2025-01-13  2025-01-14  2025-01-15  \
# TREASURY - HORIZONTE - Total Rendimentos    0.069072    0.063889    0.023715
# WDO1 - HORIZONTE - Total Rendimentos        0.045933    0.029328    0.018149
# DI_35 - HORIZONTE - Total Rendimentos       0.025349    0.010286   -0.018517
# TREASURY - JERA2026 - Total Rendimentos     0.086735    0.080226    0.029780
# WDO1 - JERA2026 - Total Rendimentos         0.057679    0.036827    0.022790
# DI_35 - JERA2026 - Total Rendimentos        0.031832    0.012916   -0.023252
# TREASURY - Total - Total Rendimentos        0.015713    0.014534    0.005395
# WDO1 - Total - Total Rendimentos            0.010449    0.006672    0.004129
# DI_35 - Total - Total Rendimentos           0.005767    0.002340   -0.004212
#
#                                           2025-01-16  2025-01-17  2025-01-20  \
# TREASURY - HORIZONTE - Total Rendimentos    0.012055    0.014646    0.014646
# WDO1 - HORIZONTE - Total Rendimentos        0.033824    0.030714    0.023383
# DI_35 - HORIZONTE - Total Rendimentos       0.006459    0.029439    0.017379
# TREASURY - JERA2026 - Total Rendimentos     0.015137    0.018392    0.018392
# WDO1 - JERA2026 - Total Rendimentos         0.042473    0.038569    0.029362
# DI_35 - JERA2026 - Total Rendimentos        0.008111    0.036967    0.021823
# TREASURY - Total - Total Rendimentos        0.002742    0.003332    0.003332
# WDO1 - Total - Total Rendimentos            0.007695    0.006987    0.005319
# DI_35 - Total - Total Rendimentos           0.001469    0.006697    0.003953
#
#                                           2025-01-21  2025-01-22  2025-01-23  \
# TREASURY - HORIZONTE - Total Rendimentos    0.006871    0.013995    0.021770
# WDO1 - HORIZONTE - Total Rendimentos        0.015498   -0.024408   -0.035970
# DI_35 - HORIZONTE - Total Rendimentos       0.020703    0.009554    0.028922
# TREASURY - JERA2026 - Total Rendimentos     0.008628    0.017574    0.027337
# WDO1 - JERA2026 - Total Rendimentos         0.019462   -0.030649   -0.045168
# DI_35 - JERA2026 - Total Rendimentos        0.025997    0.011997    0.036318
# TREASURY - Total - Total Rendimentos        0.001563    0.003184    0.004952
# WDO1 - Total - Total Rendimentos            0.003526   -0.005552   -0.008183
# DI_35 - Total - Total Rendimentos           0.004710    0.002173    0.006579
#
#                                           2025-01-24  2025-01-27
# TREASURY - HORIZONTE - Total Rendimentos    0.017885   -0.010624
# WDO1 - HORIZONTE - Total Rendimentos       -0.037045   -0.033263
# DI_35 - HORIZONTE - Total Rendimentos       0.028972    0.016568
# TREASURY - JERA2026 - Total Rendimentos     0.022458   -0.013341
# WDO1 - JERA2026 - Total Rendimentos        -0.046518   -0.041769
# DI_35 - JERA2026 - Total Rendimentos        0.036380    0.020805
# TREASURY - Total - Total Rendimentos        0.004069   -0.002417
# WDO1 - Total - Total Rendimentos           -0.008427   -0.007567
# DI_35 - Total - Total Rendimentos           0.006591    0.003769

# %%
lista_ativos = df_final.index
lista_ativos = lista_ativos.tolist()
lista_ativos = [i.split(' - ')[0] for i in lista_ativos]
lista_ativos = list(set(lista_ativos))

# %%
import pandas as pd
import datetime
df_final = pd.DataFrame()

# Supõe-se que `files`, `df_b3_fechamento`, e `dia_atual` estão definidos
for file in files:
    # Lê o arquivo CSV
    df_fundos = pd.read_csv(f'BaseFundos/{file}')
    
    # Configura o índice para a coluna 'Ativo'
    df_fundos.set_index('Ativo', inplace=True)
    
    # DataFrame para armazenar os rendimentos por operação e por dia
    df_rendimentos = pd.DataFrame()

    # Itera pelas linhas do DataFrame
    for idx, row in df_fundos.iterrows():
        # Identifica as colunas relacionadas a 'Quantidade' e 'Preço de Compra'
        col_quantidade = [col for col in df_fundos.columns if col.endswith('Quantidade')]

        # Processa cada operação (quantidade/compras de cada dia)
        for col in col_quantidade:
            quantidade = row[col]

            # Ignorar operações com quantidade 0
            if quantidade == 0 or pd.isna(quantidade):
                continue
            
            # Obtém o preço de compra correspondente
            preco_compra = row[col.replace('Quantidade', 'Preco_Compra')]

            # Extrai a data da operação
            data_operacao = col.split(' ')[0]

            # Variável para armazenar o rendimento acumulado do dia anterior
            rendimento_acumulado_anterior = 0

            # Itera por cada data no DataFrame de fechamentos (até o dia atual)
            for data_fechamento in df_b3_fechamento.columns[1:]:  # Ignora a coluna de "Assets"
                # Calcula o rendimento apenas se a data de fechamento for posterior ou igual à data da operação
                if datetime.datetime.strptime(data_fechamento, '%Y-%m-%d') >= datetime.datetime.strptime(data_operacao, '%Y-%m-%d'):
                    # Preço de fechamento no dia específico
                    preco_fechamento = df_b3_fechamento.loc[
                        df_b3_fechamento["Assets"] == idx, data_fechamento
                    ].values[0]
                    
                    # Calcula o rendimento acumulado até o dia atual
                    rendimento_acumulado = (preco_fechamento - preco_compra) * quantidade
                    
                    # Calcula a diferença de rendimento (variação diária)
                    rendimento_diario = rendimento_acumulado - rendimento_acumulado_anterior
                    
                    # Atualiza o rendimento acumulado anterior para o próximo cálculo
                    rendimento_acumulado_anterior = rendimento_acumulado

                    # Salva o rendimento diário no DataFrame
                    df_rendimentos.loc[f"{idx} - {data_operacao}", data_fechamento] = rendimento_diario

    df_rendimentos['Total'] = df_rendimentos.sum(axis=1)
    #Adicionar uma linha de total
    df_rendimentos.loc['Total'] = df_rendimentos.sum()

    #Salvar a series de rendimentos totais diarios
    df_final = pd.concat([df_final, df_rendimentos.loc['Total']])

df_final
    # Adiciona o DataFrame de rendimentos ao DataFrame fina
# Out:
#               Total
# Total          0.00
# Total          0.00
# Total          0.00
# Total          0.00
# 2025-01-03  2396.75
# ...             ...
# 2025-01-22 -2118.80
# 2025-01-23   751.48
# 2025-01-24  -236.86
# 2025-01-27 -1790.86
# Total      -1317.64
#
# [61 rows x 1 columns]

# %%
df_final = pd.DataFrame()
for file in files:
    # Lê o arquivo CSV
    df_fundos = pd.read_csv(f'BaseFundos/{file}')
    
    # Configura o índice para a coluna 'Ativo'
    df_fundos.set_index('Ativo', inplace=True)
    quantidade = 0

    # Itera pelas linhas do DataFrame
    for idx, row in df_fundos.iterrows():
        # Identifica as colunas relacionadas a 'Quantidade' e 'Preço de Compra'
        col_quantidade = [col for col in df_fundos.columns if col.endswith('Quantidade')]
        for col in col_quantidade:
            quantidade += row[col]
        
    df_fundos['Fundo'] = file.split('.')[0]
    df_fundo = 
    df_final = pd.concat([df_final, df_fundos])

df_fundos = df_final

#Pegar a quantidade de contratos de cada fundo por ativo
contratos = []
for fundo in df_fundos['Fundo'].unique():
    ativos = df_fundos[df_fundos['Fundo'] == fundo]
    col_quantidade = [col for col in ativos.columns if col.endswith('Quantidade')]
    
    # Agrupar por ativo e somar as quantidades
    agrupados = ativos.groupby('Ativo')[col_quantidade].sum().reset_index()
    
    for idx, row in agrupados.iterrows():
        quantidade = row[col_quantidade].sum()  # Soma total das colunas 'Quantidade'
        contratos.append([fundo, row['Ativo'], quantidade])

#DF_CONTRATOS TEM O FUNDO COMO INDEX, ATIVO COMO COLUNA E A QUANTIDADE DE CONTRATOS COMO VALOR
df_contratos = pd.DataFrame(contratos, columns=['Fundo', 'Ativo', 'Quantidade'])
df_contratos
# Out:
#                   Fundo     Ativo  Quantidade
# 0   AF DEB INCENTIVADAS     DI_35         0.0
# 1   AF DEB INCENTIVADAS  TREASURY         0.0
# 2   AF DEB INCENTIVADAS      WDO1         0.0
# 3         BH FIRF INFRA     DI_35         0.0
# 4         BH FIRF INFRA  TREASURY         0.0
# 5         BH FIRF INFRA      WDO1         0.0
# 6        BORDEAUX INFRA     DI_35         0.0
# 7        BORDEAUX INFRA  TREASURY         0.0
# 8        BORDEAUX INFRA      WDO1         0.0
# 9          GLOBAL BONDS     DI_35         0.0
# 10         GLOBAL BONDS  TREASURY         0.0
# 11         GLOBAL BONDS      WDO1         0.0
# 12            HORIZONTE     DI_35        -3.0
# 13            HORIZONTE  TREASURY        -3.0
# 14            HORIZONTE      WDO1         3.0
# 15             JERA2026     DI_35        -3.0
# 16             JERA2026  TREASURY        -3.0
# 17             JERA2026      WDO1         3.0
# 18    MANACA INFRA FIRF     DI_35         0.0
# 19    MANACA INFRA FIRF  TREASURY         0.0
# 20    MANACA INFRA FIRF      WDO1         0.0
# 21             REAL FIM     DI_35         0.0
# 22             REAL FIM  TREASURY         0.0
# 23             REAL FIM      WDO1         0.0
# 24        TOPAZIO INFRA     DI_35         0.0
# 25        TOPAZIO INFRA  TREASURY         0.0
# 26        TOPAZIO INFRA      WDO1         0.0
# 27                Total     DI_35        -6.0
# 28                Total  TREASURY        -6.0
# 29                Total      WDO1         6.0

# %%
lista_fundos = df_fundos['Fundo'].unique()
fundos_específicos = st.sidebar.multiselect('Selecione os Fundos', lista_fundos, lista_fundos)
df_fundos = df_fundos[df_fundos['Fundo'].isin(fundos_específicos)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\emanuel.cabral\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Fundo'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 lista_fundos = df_fundos['Fundo'].unique()
#       2 fundos_específicos = st.sidebar.multiselect('Selecione os Fundos', lista_fundos, lista_fundos)
#       3 df_fundos = df_fundos[df_fundos['Fundo'].isin(fundos_específicos)]
#
# File c:\Users\emanuel.cabral\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\emanuel.cabral\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Fundo'

# %%
#Pegar a quantidade de contratos de cada fundo por ativo
contratos = []
for fundo in df_fundos['Fundo'].unique():
    ativos = df_fundos[df_fundos['Fundo'] == fundo]
    col_quantidade = [col for col in ativos.columns if col.endswith('Quantidade')]
    
    # Agrupar por ativo e somar as quantidades
    agrupados = ativos.groupby('Ativo')[col_quantidade].sum().reset_index()
    
    for idx, row in agrupados.iterrows():
        quantidade = row[col_quantidade].sum()  # Soma total das colunas 'Quantidade'
        contratos.append([fundo, row['Ativo'], quantidade])

#DF_CONTRATOS TEM O FUNDO COMO INDEX, ATIVO COMO COLUNA E A QUANTIDADE DE CONTRATOS COMO VALOR
df_contratos = pd.DataFrame(contratos, columns=['Fundo', 'Ativo', 'Quantidade'])
df_contratos
# Out:
#                   Fundo     Ativo  Quantidade
# 0   AF DEB INCENTIVADAS     DAP27         0.0
# 1   AF DEB INCENTIVADAS     DI_28         0.0
# 2   AF DEB INCENTIVADAS  TREASURY         0.0
# 3   AF DEB INCENTIVADAS      WDO1         0.0
# 4         BH FIRF INFRA     DAP27         1.0
# 5         BH FIRF INFRA     DI_28         1.0
# 6         BH FIRF INFRA  TREASURY         1.0
# 7         BH FIRF INFRA      WDO1         1.0
# 8        BORDEAUX INFRA     DAP27         1.0
# 9        BORDEAUX INFRA     DI_28         1.0
# 10       BORDEAUX INFRA  TREASURY         1.0
# 11       BORDEAUX INFRA      WDO1         1.0
# 12         GLOBAL BONDS     DAP27         1.0
# 13         GLOBAL BONDS     DI_28         1.0
# 14         GLOBAL BONDS  TREASURY         1.0
# 15         GLOBAL BONDS      WDO1         1.0
# 16            HORIZONTE     DAP27         2.0
# 17            HORIZONTE     DI_28         2.0
# 18            HORIZONTE  TREASURY         2.0
# 19            HORIZONTE      WDO1         2.0
# 20             JERA2026     DAP27         3.0
# 21             JERA2026     DI_28         3.0
# 22             JERA2026  TREASURY         3.0
# 23             JERA2026      WDO1         3.0
# 24    MANACA INFRA FIRF     DAP27         1.0
# 25    MANACA INFRA FIRF     DI_28         1.0
# 26    MANACA INFRA FIRF  TREASURY         1.0
# 27    MANACA INFRA FIRF      WDO1         1.0
# 28             REAL FIM     DAP27         1.0
# 29             REAL FIM     DI_28         1.0
# 30             REAL FIM  TREASURY         1.0
# 31             REAL FIM      WDO1         1.0
# 32        TOPAZIO INFRA     DAP27         0.0
# 33        TOPAZIO INFRA     DI_28         0.0
# 34        TOPAZIO INFRA  TREASURY         0.0
# 35        TOPAZIO INFRA      WDO1         0.0
# 36                Total     DAP27        10.0
# 37                Total     DI_28        10.0
# 38                Total  TREASURY        10.0
# 39                Total      WDO1        10.0

# %%
df_contratos = df_contratos.pivot(index='Fundo', columns='Ativo', values='Quantidade')
df_contratos = df_contratos.fillna(0)
df_contratos
# Out:
# Ativo                DAP27  DI_28  TREASURY  WDO1
# Fundo
# AF DEB INCENTIVADAS    0.0    0.0       0.0   0.0
# BH FIRF INFRA          1.0    1.0       1.0   1.0
# BORDEAUX INFRA         1.0    1.0       1.0   1.0
# GLOBAL BONDS           1.0    1.0       1.0   1.0
# HORIZONTE              2.0    2.0       2.0   2.0
# JERA2026               3.0    3.0       3.0   3.0
# MANACA INFRA FIRF      1.0    1.0       1.0   1.0
# REAL FIM               1.0    1.0       1.0   1.0
# TOPAZIO INFRA          0.0    0.0       0.0   0.0
# Total                 10.0   10.0      10.0  10.0

# %%
df_contratos['DAP27']
# Out:
# Fundo
# AF DEB INCENTIVADAS     0.0
# BH FIRF INFRA           1.0
# BORDEAUX INFRA          1.0
# GLOBAL BONDS            1.0
# HORIZONTE               2.0
# JERA2026                3.0
# MANACA INFRA FIRF       1.0
# REAL FIM                1.0
# TOPAZIO INFRA           0.0
# Total                  10.0
# Name: DAP27, dtype: float64

# %%
#Montar resumo dos dados
df_fundos = df_fundos.T
df_fundos.columns = df_fundos.loc['Fundo']
df_fundos = df_fundos.drop('Fundo')
df_fundos
# Out:
# Fundo                         AF DEB INCENTIVADAS AF DEB INCENTIVADAS  \
# Ativo                                    TREASURY               DI_28
# Preco_Fechamento_Atual                   108562.5            66338.64
# 2025-01-21 - PL                        11563897.0                 NaN
# 2025-01-21 - Preco_Fechamento            108734.3                 NaN
# 2025-01-21 - Preco_Compra                100000.0                 NaN
# 2025-01-21 - Quantidade                       0.0                 NaN
# 2025-01-21 - Rendimento                       0.0                 NaN
# 2025-01-22 - PL                        11563897.0                 NaN
# 2025-01-22 - Preco_Fechamento            108562.5                 NaN
# 2025-01-22 - Preco_Compra                100000.0                 NaN
# 2025-01-22 - Quantidade                       5.0                 NaN
# 2025-01-22 - Rendimento                   42812.5                 NaN
# 2025-01-20 - PL                        11563897.0          11563897.0
# 2025-01-20 - Preco_Fechamento            108546.8            66231.08
# 2025-01-20 - Preco_Compra                100000.0             34330.0
# 2025-01-20 - Quantidade                      41.0                 4.0
# 2025-01-20 - Rendimento                  351062.5           128034.56
#
# Fundo                         BH FIRF INFRA BH FIRF INFRA BORDEAUX INFRA  \
# Ativo                              TREASURY         DI_28       TREASURY
# Preco_Fechamento_Atual             108562.5      66338.64       108562.5
# 2025-01-21 - PL                  77314727.0           NaN     45417246.0
# 2025-01-21 - Preco_Fechamento      108734.3           NaN       108734.3
# 2025-01-21 - Preco_Compra          100000.0           NaN       100000.0
# 2025-01-21 - Quantidade                26.0           NaN           15.0
# 2025-01-21 - Rendimento            222625.0           NaN       128437.5
# 2025-01-22 - PL                  77314727.0           NaN     45417246.0
# 2025-01-22 - Preco_Fechamento      108562.5           NaN       108562.5
# 2025-01-22 - Preco_Compra          100000.0           NaN       100000.0
# 2025-01-22 - Quantidade                25.0           NaN           15.0
# 2025-01-22 - Rendimento            214062.5           NaN       128437.5
# 2025-01-20 - PL                  77314727.0    77314727.0     45417246.0
# 2025-01-20 - Preco_Fechamento      108546.8      66231.08       108546.8
# 2025-01-20 - Preco_Compra          100000.0       34330.0       100000.0
# 2025-01-20 - Quantidade               181.0          18.0          106.0
# 2025-01-20 - Rendimento           1549812.5     576155.52       907625.0
#
# Fundo                         BORDEAUX INFRA GLOBAL BONDS GLOBAL BONDS  \
# Ativo                                  DI_28     TREASURY        DI_28
# Preco_Fechamento_Atual              66338.64     108562.5     66338.64
# 2025-01-21 - PL                          NaN   29796115.0          NaN
# 2025-01-21 - Preco_Fechamento            NaN     108734.3          NaN
# 2025-01-21 - Preco_Compra                NaN     100000.0          NaN
# 2025-01-21 - Quantidade                  NaN         20.0          NaN
# 2025-01-21 - Rendimento                  NaN     171250.0          NaN
# 2025-01-22 - PL                          NaN   29796115.0          NaN
# 2025-01-22 - Preco_Fechamento            NaN     108562.5          NaN
# 2025-01-22 - Preco_Compra                NaN     100000.0          NaN
# 2025-01-22 - Quantidade                  NaN         19.0          NaN
# 2025-01-22 - Rendimento                  NaN     162687.5          NaN
# 2025-01-20 - PL                   45417246.0   29796115.0   29796115.0
# 2025-01-20 - Preco_Fechamento       66231.08     108546.8     66231.08
# 2025-01-20 - Preco_Compra            34330.0     100000.0      34330.0
# 2025-01-20 - Quantidade                 11.0        139.0         14.0
# 2025-01-20 - Rendimento            352095.04    1190187.5    448120.96
#
# Fundo                            HORIZONTE    HORIZONTE     JERA2026  \
# Ativo                             TREASURY        DI_28     TREASURY
# Preco_Fechamento_Atual            108562.5     66338.64     108562.5
# 2025-01-21 - PL                240930319.0          NaN  191147694.0
# 2025-01-21 - Preco_Fechamento     108734.3          NaN     108734.3
# 2025-01-21 - Preco_Compra         100000.0          NaN     100000.0
# 2025-01-21 - Quantidade               40.0          NaN         64.0
# 2025-01-21 - Rendimento           342500.0          NaN     548000.0
# 2025-01-22 - PL                240930319.0          NaN  191147694.0
# 2025-01-22 - Preco_Fechamento     108562.5          NaN     108562.5
# 2025-01-22 - Preco_Compra         100000.0          NaN     100000.0
# 2025-01-22 - Quantidade               39.0          NaN         62.0
# 2025-01-22 - Rendimento           333937.5          NaN     530875.0
# 2025-01-20 - PL                240930319.0  240930319.0  191147694.0
# 2025-01-20 - Preco_Fechamento     108546.8     66231.08     108546.8
# 2025-01-20 - Preco_Compra         100000.0      34330.0     100000.0
# 2025-01-20 - Quantidade              282.0         28.0          0.0
# 2025-01-20 - Rendimento          2414625.0    896241.92          0.0
#
# Fundo                             JERA2026 MANACA INFRA FIRF  \
# Ativo                                DI_28          TREASURY
# Preco_Fechamento_Atual            66338.64          108562.5
# 2025-01-21 - PL                        NaN        40334603.0
# 2025-01-21 - Preco_Fechamento          NaN          108734.3
# 2025-01-21 - Preco_Compra              NaN          100000.0
# 2025-01-21 - Quantidade                NaN              13.0
# 2025-01-21 - Rendimento                NaN          111312.5
# 2025-01-22 - PL                        NaN        40334603.0
# 2025-01-22 - Preco_Fechamento          NaN          108562.5
# 2025-01-22 - Preco_Compra              NaN          100000.0
# 2025-01-22 - Quantidade                NaN              13.0
# 2025-01-22 - Rendimento                NaN          111312.5
# 2025-01-20 - PL                191147694.0        40334603.0
# 2025-01-20 - Preco_Fechamento     66231.08          108546.8
# 2025-01-20 - Preco_Compra          34330.0          100000.0
# 2025-01-20 - Quantidade                0.0              94.0
# 2025-01-20 - Rendimento                0.0          804875.0
#
# Fundo                         MANACA INFRA FIRF    REAL FIM    REAL FIM  \
# Ativo                                     DI_28    TREASURY       DI_28
# Preco_Fechamento_Atual                 66338.64    108562.5    66338.64
# 2025-01-21 - PL                             NaN  36463215.0         NaN
# 2025-01-21 - Preco_Fechamento               NaN    108734.3         NaN
# 2025-01-21 - Preco_Compra                   NaN    100000.0         NaN
# 2025-01-21 - Quantidade                     NaN        12.0         NaN
# 2025-01-21 - Rendimento                     NaN    102750.0         NaN
# 2025-01-22 - PL                             NaN  36463215.0         NaN
# 2025-01-22 - Preco_Fechamento               NaN    108562.5         NaN
# 2025-01-22 - Preco_Compra                   NaN    100000.0         NaN
# 2025-01-22 - Quantidade                     NaN        12.0         NaN
# 2025-01-22 - Rendimento                     NaN    102750.0         NaN
# 2025-01-20 - PL                      40334603.0  36463215.0  36463215.0
# 2025-01-20 - Preco_Fechamento          66231.08    108546.8    66231.08
# 2025-01-20 - Preco_Compra               34330.0    100000.0     34330.0
# 2025-01-20 - Quantidade                     9.0        85.0         9.0
# 2025-01-20 - Rendimento               288077.76    727812.5   288077.76
#
# Fundo                         TOPAZIO INFRA TOPAZIO INFRA        Total  \
# Ativo                              TREASURY         DI_28     TREASURY
# Preco_Fechamento_Atual             108562.5      66338.64     108562.5
# 2025-01-21 - PL                  30777380.0           NaN  703745196.0
# 2025-01-21 - Preco_Fechamento      108734.3           NaN     108734.3
# 2025-01-21 - Preco_Compra          100000.0           NaN     100000.0
# 2025-01-21 - Quantidade                10.0           NaN        200.0
# 2025-01-21 - Rendimento             85625.0           NaN    1712500.0
# 2025-01-22 - PL                  30777380.0           NaN  703745196.0
# 2025-01-22 - Preco_Fechamento      108562.5           NaN     108562.5
# 2025-01-22 - Preco_Compra          100000.0           NaN     100000.0
# 2025-01-22 - Quantidade                10.0           NaN        200.0
# 2025-01-22 - Rendimento             85625.0           NaN    1712500.0
# 2025-01-20 - PL                  30777380.0    30777380.0  703745196.0
# 2025-01-20 - Preco_Fechamento      108546.8      66231.08     108546.8
# 2025-01-20 - Preco_Compra          100000.0       34330.0     100000.0
# 2025-01-20 - Quantidade                72.0           7.0       1000.0
# 2025-01-20 - Rendimento            616500.0     224060.48    8562500.0
#
# Fundo                                Total
# Ativo                                DI_28
# Preco_Fechamento_Atual            66338.64
# 2025-01-21 - PL                        NaN
# 2025-01-21 - Preco_Fechamento          NaN
# 2025-01-21 - Preco_Compra              NaN
# 2025-01-21 - Quantidade                NaN
# 2025-01-21 - Rendimento                NaN
# 2025-01-22 - PL                        NaN
# 2025-01-22 - Preco_Fechamento          NaN
# 2025-01-22 - Preco_Compra              NaN
# 2025-01-22 - Quantidade                NaN
# 2025-01-22 - Rendimento                NaN
# 2025-01-20 - PL                703745196.0
# 2025-01-20 - Preco_Fechamento     66231.08
# 2025-01-20 - Preco_Compra          34330.0
# 2025-01-20 - Quantidade              100.0
# 2025-01-20 - Rendimento          3200864.0

# %%
lista_estrategias = {
                'DI': 'Juros Nominais Brasil',
                'DAP': 'Juros Reais Brasil',
                'TREASURY': 'Juros US',
                'WDO1': 'Moedas'
            }
lista_ativos = [
                'DI_26', 'DI_27', 'DI_28', 'DI_29', 'DI_30',
                'DI_31', 'DI_32', 'DI_33', 'DI_35', 'DAP25', 'DAP26', 'DAP27',
                'DAP28', 'DAP30', 'DAP32', 'DAP35', 'DAP40', 'WDO1', 'TREASURY'
            ]

# %%
data_inicial = '2025-01-14'
data_final = '2025-01-22'

# %%
dt_ini = datetime.datetime.strptime(data_inicial, "%Y-%m-%d").date()
dt_fim = datetime.datetime.strptime(data_final,   "%Y-%m-%d").date()

def mapear_estrategia(ativo):
    for prefixo, nome_estrategia in lista_estrategias.items():
        if prefixo in ativo:  # substring "DI", "DAP", "WDO1", etc.
            return nome_estrategia
    return "Estratégia Desconhecida"

pasta_fundos = "BaseFundos"
if not os.path.isdir(pasta_fundos):
    raise FileNotFoundError(f"Pasta '{pasta_fundos}' não encontrada.")

arquivos = [arq for arq in os.listdir(
    pasta_fundos) if arq.endswith(".csv")]

registros = []
# Cada elemento em 'registros' será um dict:
# { "date": dt_col, "fundo": nome_fundo, "Ativo": ativo, "Rendimento_diario": rend_val }

for arquivo_csv in arquivos:
    caminho_csv = os.path.join(pasta_fundos, arquivo_csv)
    nome_fundo = arquivo_csv.replace(".csv", "")

    df_fundo = pd.read_csv(caminho_csv)
    if "Ativo" not in df_fundo.columns:
        continue  # ignora se não tiver coluna 'Ativo'

    # Todas as colunas do tipo "YYYY-MM-DD - Rendimento"
    colunas_rendimento = [
        c for c in df_fundo.columns if c.endswith(" - Rendimento")]

    for _, row_ in df_fundo.iterrows():
        ativo = row_["Ativo"]
        print(f'{_} - Index')
        print(f'{row_} - Row')
# Out:
# 0 - Index
# Ativo                              WDO1
# Preco_Fechamento_Atual         6037.375
# 2025-01-14 - PL              11563897.0
# 2025-01-14 - Preco_Compra        6000.0
# 2025-01-14 - Quantidade             0.0
# 2025-01-14 - Rendimento             0.0
# 2025-01-16 - PL              11563897.0
# 2025-01-16 - Preco_Compra        6000.0
# 2025-01-16 - Quantidade             0.0
# 2025-01-16 - Rendimento             0.0
# 2025-01-22 - PL              11563897.0
# 2025-01-22 - Preco_Compra        6500.0
# 2025-01-22 - Quantidade             1.0
# 2025-01-22 - Rendimento        -462.625
# Name: 0, dtype: object - Row
# 1 - Index
# Ativo                             DI_33
# Preco_Fechamento_Atual         33210.31
# 2025-01-14 - PL                     NaN
# 2025-01-14 - Preco_Compra           NaN
# 2025-01-14 - Quantidade             NaN
# 2025-01-14 - Rendimento             NaN
# 2025-01-16 - PL                     NaN
# 2025-01-16 - Preco_Compra           NaN
# 2025-01-16 - Quantidade             NaN
# 2025-01-16 - Rendimento             NaN
# 2025-01-22 - PL              11563897.0
# 2025-01-22 - Preco_Compra       33400.0
# 2025-01-22 - Quantidade             0.0
# 2025-01-22 - Rendimento            -0.0
# Name: 1, dtype: object - Row
# 0 - Index
# Ativo                              WDO1
# Preco_Fechamento_Atual         6037.375
# 2025-01-14 - PL              77314727.0
# 2025-01-14 - Preco_Compra        6000.0
# 2025-01-14 - Quantidade             2.0
# 2025-01-14 - Rendimento           74.75
# 2025-01-16 - PL              77314727.0
# 2025-01-16 - Preco_Compra        6000.0
# 2025-01-16 - Quantidade             2.0
# 2025-01-16 - Rendimento           74.75
# 2025-01-22 - PL              77314727.0
# 2025-01-22 - Preco_Compra        6500.0
# 2025-01-22 - Quantidade             3.0
# 2025-01-22 - Rendimento       -1387.875
# Name: 0, dtype: object - Row
# 1 - Index
# Ativo                             DI_33
# Preco_Fechamento_Atual         33210.31
# 2025-01-14 - PL                     NaN
# 2025-01-14 - Preco_Compra           NaN
# 2025-01-14 - Quantidade             NaN
# 2025-01-14 - Rendimento             NaN
# 2025-01-16 - PL                     NaN
# 2025-01-16 - Preco_Compra           NaN
# 2025-01-16 - Quantidade             NaN
# 2025-01-16 - Rendimento             NaN
# 2025-01-22 - PL              77314727.0
# 2025-01-22 - Preco_Compra       33400.0
# 2025-01-22 - Quantidade             1.0
# 2025-01-22 - Rendimento         -189.69
# Name: 1, dtype: object - Row
# 0 - Index
# Ativo                              WDO1
# Preco_Fechamento_Atual         6037.375
# 2025-01-14 - PL              45417246.0
# 2025-01-14 - Preco_Compra        6000.0
# 2025-01-14 - Quantidade             1.0
# 2025-01-14 - Rendimento          37.375
# 2025-01-16 - PL              45417246.0
# 2025-01-16 - Preco_Compra        6000.0
# 2025-01-16 - Quantidade             1.0
# 2025-01-16 - Rendimento          37.375
# 2025-01-22 - PL              45417246.0
# 2025-01-22 - Preco_Compra        6500.0
# 2025-01-22 - Quantidade             2.0
# 2025-01-22 - Rendimento         -925.25
# Name: 0, dtype: object - Row
# 1 - Index
# Ativo                             DI_33
# Preco_Fechamento_Atual         33210.31
# 2025-01-14 - PL                     NaN
# 2025-01-14 - Preco_Compra           NaN
# 2025-01-14 - Quantidade             NaN
# 2025-01-14 - Rendimento             NaN
# 2025-01-16 - PL                     NaN
# 2025-01-16 - Preco_Compra           NaN
# 2025-01-16 - Quantidade             NaN
# 2025-01-16 - Rendimento             NaN
# 2025-01-22 - PL              45417246.0
# 2025-01-22 - Preco_Compra       33400.0
# 2025-01-22 - Quantidade             1.0
# 2025-01-22 - Rendimento         -189.69
# Name: 1, dtype: object - Row
# 0 - Index
# Ativo                              WDO1
# Preco_Fechamento_Atual         6037.375
# 2025-01-14 - PL              29796115.0
# 2025-01-14 - Preco_Compra        6000.0
# 2025-01-14 - Quantidade             1.0
# 2025-01-14 - Rendimento          37.375
# 2025-01-16 - PL              29796115.0
# 2025-01-16 - Preco_Compra        6000.0
# 2025-01-16 - Quantidade             1.0
# 2025-01-16 - Rendimento          37.375
# 2025-01-22 - PL              29796115.0
# 2025-01-22 - Preco_Compra        6500.0
# 2025-01-22 - Quantidade             3.0
# 2025-01-22 - Rendimento       -1387.875
# Name: 0, dtype: object - Row
# 1 - Index
# Ativo                             DI_33
# Preco_Fechamento_Atual         33210.31
# 2025-01-14 - PL                     NaN
# 2025-01-14 - Preco_Compra           NaN
# 2025-01-14 - Quantidade             NaN
# 2025-01-14 - Rendimento             NaN
# 2025-01-16 - PL                     NaN
# 2025-01-16 - Preco_Compra           NaN
# 2025-01-16 - Quantidade             NaN
# 2025-01-16 - Rendimento             NaN
# 2025-01-22 - PL              29796115.0
# 2025-01-22 - Preco_Compra       33400.0
# 2025-01-22 - Quantidade             1.0
# 2025-01-22 - Rendimento         -189.69
# Name: 1, dtype: object - Row
# 0 - Index
# Ativo                               WDO1
# Preco_Fechamento_Atual          6037.375
# 2025-01-14 - PL              240930319.0
# 2025-01-14 - Preco_Compra         6000.0
# 2025-01-14 - Quantidade              3.0
# 2025-01-14 - Rendimento          112.125
# 2025-01-16 - PL              240930319.0
# 2025-01-16 - Preco_Compra         6000.0
# 2025-01-16 - Quantidade              3.0
# 2025-01-16 - Rendimento          112.125
# 2025-01-22 - PL              240930319.0
# 2025-01-22 - Preco_Compra         6500.0
# 2025-01-22 - Quantidade              5.0
# 2025-01-22 - Rendimento        -2313.125
# Name: 0, dtype: object - Row
# 1 - Index
# Ativo                              DI_33
# Preco_Fechamento_Atual          33210.31
# 2025-01-14 - PL                      NaN
# 2025-01-14 - Preco_Compra            NaN
# 2025-01-14 - Quantidade              NaN
# 2025-01-14 - Rendimento              NaN
# 2025-01-16 - PL                      NaN
# 2025-01-16 - Preco_Compra            NaN
# 2025-01-16 - Quantidade              NaN
# 2025-01-16 - Rendimento              NaN
# 2025-01-22 - PL              240930319.0
# 2025-01-22 - Preco_Compra        33400.0
# 2025-01-22 - Quantidade              2.0
# 2025-01-22 - Rendimento          -379.38
# Name: 1, dtype: object - Row
# 0 - Index
# Ativo                               WDO1
# Preco_Fechamento_Atual          6037.375
# 2025-01-14 - PL              191147694.0
# 2025-01-14 - Preco_Compra         6000.0
# 2025-01-14 - Quantidade              4.0
# 2025-01-14 - Rendimento            149.5
# 2025-01-16 - PL              191147694.0
# 2025-01-16 - Preco_Compra         6000.0
# 2025-01-16 - Quantidade              4.0
# 2025-01-16 - Rendimento            149.5
# 2025-01-22 - PL              191147694.0
# 2025-01-22 - Preco_Compra         6500.0
# 2025-01-22 - Quantidade              9.0
# 2025-01-22 - Rendimento        -4163.625
# Name: 0, dtype: object - Row
# 1 - Index
# Ativo                              DI_33
# Preco_Fechamento_Atual          33210.31
# 2025-01-14 - PL                      NaN
# 2025-01-14 - Preco_Compra            NaN
# 2025-01-14 - Quantidade              NaN
# 2025-01-14 - Rendimento              NaN
# 2025-01-16 - PL                      NaN
# 2025-01-16 - Preco_Compra            NaN
# 2025-01-16 - Quantidade              NaN
# 2025-01-16 - Rendimento              NaN
# 2025-01-22 - PL              191147694.0
# 2025-01-22 - Preco_Compra        33400.0
# 2025-01-22 - Quantidade              3.0
# 2025-01-22 - Rendimento          -569.07
# Name: 1, dtype: object - Row
# 0 - Index
# Ativo                              WDO1
# Preco_Fechamento_Atual         6037.375
# 2025-01-14 - PL              40334603.0
# 2025-01-14 - Preco_Compra        6000.0
# 2025-01-14 - Quantidade             1.0
# 2025-01-14 - Rendimento          37.375
# 2025-01-16 - PL              40334603.0
# 2025-01-16 - Preco_Compra        6000.0
# 2025-01-16 - Quantidade             1.0
# 2025-01-16 - Rendimento          37.375
# 2025-01-22 - PL              40334603.0
# 2025-01-22 - Preco_Compra        6500.0
# 2025-01-22 - Quantidade             2.0
# 2025-01-22 - Rendimento         -925.25
# Name: 0, dtype: object - Row
# 1 - Index
# Ativo                             DI_33
# Preco_Fechamento_Atual         33210.31
# 2025-01-14 - PL                     NaN
# 2025-01-14 - Preco_Compra           NaN
# 2025-01-14 - Quantidade             NaN
# 2025-01-14 - Rendimento             NaN
# 2025-01-16 - PL                     NaN
# 2025-01-16 - Preco_Compra           NaN
# 2025-01-16 - Quantidade             NaN
# 2025-01-16 - Rendimento             NaN
# 2025-01-22 - PL              40334603.0
# 2025-01-22 - Preco_Compra       33400.0
# 2025-01-22 - Quantidade             1.0
# 2025-01-22 - Rendimento         -189.69
# Name: 1, dtype: object - Row
# 0 - Index
# Ativo                              WDO1
# Preco_Fechamento_Atual         6037.375
# 2025-01-14 - PL              36463215.0
# 2025-01-14 - Preco_Compra        6000.0
# 2025-01-14 - Quantidade             1.0
# 2025-01-14 - Rendimento          37.375
# 2025-01-16 - PL              36463215.0
# 2025-01-16 - Preco_Compra        6000.0
# 2025-01-16 - Quantidade             1.0
# 2025-01-16 - Rendimento          37.375
# 2025-01-22 - PL              36463215.0
# 2025-01-22 - Preco_Compra        6500.0
# 2025-01-22 - Quantidade             2.0
# 2025-01-22 - Rendimento         -925.25
# Name: 0, dtype: object - Row
# 1 - Index
# Ativo                             DI_33
# Preco_Fechamento_Atual         33210.31
# 2025-01-14 - PL                     NaN
# 2025-01-14 - Preco_Compra           NaN
# 2025-01-14 - Quantidade             NaN
# 2025-01-14 - Rendimento             NaN
# 2025-01-16 - PL                     NaN
# 2025-01-16 - Preco_Compra           NaN
# 2025-01-16 - Quantidade             NaN
# 2025-01-16 - Rendimento             NaN
# 2025-01-22 - PL              36463215.0
# 2025-01-22 - Preco_Compra       33400.0
# 2025-01-22 - Quantidade             1.0
# 2025-01-22 - Rendimento         -189.69
# Name: 1, dtype: object - Row
# 0 - Index
# Ativo                              WDO1
# Preco_Fechamento_Atual         6037.375
# 2025-01-14 - PL              30777380.0
# 2025-01-14 - Preco_Compra        6000.0
# 2025-01-14 - Quantidade             1.0
# 2025-01-14 - Rendimento          37.375
# 2025-01-16 - PL              30777380.0
# 2025-01-16 - Preco_Compra        6000.0
# 2025-01-16 - Quantidade             1.0
# 2025-01-16 - Rendimento          37.375
# 2025-01-22 - PL              30777380.0
# 2025-01-22 - Preco_Compra        6500.0
# 2025-01-22 - Quantidade             1.0
# 2025-01-22 - Rendimento        -462.625
# Name: 0, dtype: object - Row
# 1 - Index
# Ativo                             DI_33
# Preco_Fechamento_Atual         33210.31
# 2025-01-14 - PL                     NaN
# 2025-01-14 - Preco_Compra           NaN
# 2025-01-14 - Quantidade             NaN
# 2025-01-14 - Rendimento             NaN
# 2025-01-16 - PL                     NaN
# 2025-01-16 - Preco_Compra           NaN
# 2025-01-16 - Quantidade             NaN
# 2025-01-16 - Rendimento             NaN
# 2025-01-22 - PL              30777380.0
# 2025-01-22 - Preco_Compra       33400.0
# 2025-01-22 - Quantidade             0.0
# 2025-01-22 - Rendimento            -0.0
# Name: 1, dtype: object - Row
# 0 - Index
# Ativo                               WDO1
# Preco_Fechamento_Atual          6037.375
# 2025-01-14 - PL              703745196.0
# 2025-01-14 - Preco_Compra         6000.0
# 2025-01-14 - Quantidade             14.0
# 2025-01-14 - Rendimento           523.25
# 2025-01-16 - PL              703745196.0
# 2025-01-16 - Preco_Compra         6000.0
# 2025-01-16 - Quantidade             14.0
# 2025-01-16 - Rendimento           523.25
# 2025-01-22 - PL              703745196.0
# 2025-01-22 - Preco_Compra         6500.0
# 2025-01-22 - Quantidade             28.0
# 2025-01-22 - Rendimento         -12953.5
# Name: 0, dtype: object - Row
# 1 - Index
# Ativo                              DI_33
# Preco_Fechamento_Atual          33210.31
# 2025-01-14 - PL                      NaN
# 2025-01-14 - Preco_Compra            NaN
# 2025-01-14 - Quantidade              NaN
# 2025-01-14 - Rendimento              NaN
# 2025-01-16 - PL                      NaN
# 2025-01-16 - Preco_Compra            NaN
# 2025-01-16 - Quantidade              NaN
# 2025-01-16 - Rendimento              NaN
# 2025-01-22 - PL              703745196.0
# 2025-01-22 - Preco_Compra        33400.0
# 2025-01-22 - Quantidade             10.0
# 2025-01-22 - Rendimento          -1896.9
# Name: 1, dtype: object - Row

# %%
#Tenho que fazer um loop

dt_ini = datetime.datetime.strptime(data_inicial, "%Y-%m-%d").date()
dt_fim = datetime.datetime.strptime(data_final,   "%Y-%m-%d").date()

def mapear_estrategia(ativo):
    for prefixo, nome_estrategia in lista_estrategias.items():
        if prefixo in ativo:  # substring "DI", "DAP", "WDO1", etc.
            return nome_estrategia
    return "Estratégia Desconhecida"

pasta_fundos = "BaseFundos"
if not os.path.isdir(pasta_fundos):
    raise FileNotFoundError(f"Pasta '{pasta_fundos}' não encontrada.")

arquivos = [arq for arq in os.listdir(
    pasta_fundos) if arq.endswith(".csv")]

registros = []
# Cada elemento em 'registros' será um dict:
# { "date": dt_col, "fundo": nome_fundo, "Ativo": ativo, "Rendimento_diario": rend_val }

for arquivo_csv in arquivos:
    caminho_csv = os.path.join(pasta_fundos, arquivo_csv)
    nome_fundo = arquivo_csv.replace(".csv", "")

    df_fundo = pd.read_csv(caminho_csv)
    if "Ativo" not in df_fundo.columns:
        continue  # ignora se não tiver coluna 'Ativo'

    # Todas as colunas do tipo "YYYY-MM-DD - Rendimento"
    colunas_rendimento = [
        c for c in df_fundo.columns if c.endswith(" - Rendimento")]

    for _, row_ in df_fundo.iterrows():
        ativo = row_["Ativo"]


        for col_rend in colunas_rendimento:
            try:
                data_str = col_rend.replace(" - Rendimento", "").strip()
                dt_col = datetime.datetime.strptime(
                    data_str, "%Y-%m-%d").date()
            except:
                continue  # erro de formato de data

            if dt_ini <= dt_col <= dt_fim:
                rend_val = row_[col_rend]
                if pd.isna(rend_val):
                    rend_val = 0.0
                registros.append({
                    "date": dt_col,
                    "fundo": nome_fundo,
                    "Ativo": ativo,
                    "Rendimento_diario": rend_val
                })

if len(registros) == 0:
    # Nada encontrado no período
    df_diario_fundo_ativo = pd.DataFrame(
        columns=["date", "fundo", "Ativo", "Rendimento_diario", "Estratégia"])
    df_diario_fundo_estrategia = pd.DataFrame(
        columns=["date", "fundo", "Estratégia", "Rendimento_diario"])
    df_diario_fundo_total = pd.DataFrame(
        columns=["date", "fundo", "Rendimento_diario"])
    df_diario_fundo_ativo
    df_diario_fundo_estrategia
    df_diario_fundo_total

# Monta DataFrame consolidado
df_all = pd.DataFrame(registros)
df_all["Estratégia"] = df_all["Ativo"].apply(mapear_estrategia)

# 1) Performance diária por Fundo x Ativo
df_diario_fundo_ativo = df_all[[
    "date", "fundo", "Ativo", "Rendimento_diario", "Estratégia"]].copy()
df_diario_fundo_ativo.sort_values(["fundo", "date", "Ativo"], inplace=True)

# 2) Performance diária por Fundo x Estratégia
df_diario_fundo_estrategia = (
    df_all
    .groupby(["date", "fundo", "Estratégia"], as_index=False)["Rendimento_diario"]
    .sum()
    .sort_values(["fundo", "date", "Estratégia"])
)

# 3) Performance diária agregada do Fundo (somando todos os ativos)
df_diario_fundo_total = (
    df_all
    .groupby(["date", "fundo"], as_index=False)["Rendimento_diario"]
    .sum()
    .sort_values(["fundo", "date"])
)

df_diario_fundo_ativo
# Out:
#           date                fundo     Ativo  Rendimento_diario  \
# 8   2025-01-20  AF DEB INCENTIVADAS     DI_33           66961.92
# 5   2025-01-20  AF DEB INCENTIVADAS  TREASURY          217125.00
# 2   2025-01-20  AF DEB INCENTIVADAS      WDO1           11882.28
# 6   2025-01-21  AF DEB INCENTIVADAS     DI_33               0.00
# 3   2025-01-21  AF DEB INCENTIVADAS  TREASURY               0.00
# ..         ...                  ...       ...                ...
# 84  2025-01-21                Total  TREASURY           87343.00
# 81  2025-01-21                Total      WDO1             373.75
# 88  2025-01-22                Total     DI_33          669619.20
# 85  2025-01-22                Total  TREASURY         2171250.00
# 82  2025-01-22                Total      WDO1          118822.80
#
#                Estratégia
# 8   Juros Nominais Brasil
# 5                Juros US
# 2                  Moedas
# 6   Juros Nominais Brasil
# 3                Juros US
# ..                    ...
# 84               Juros US
# 81                 Moedas
# 88  Juros Nominais Brasil
# 85               Juros US
# 82                 Moedas
#
# [90 rows x 5 columns]

# %%
df_teste_fundos =df_diario_fundo_ativo[df_diario_fundo_ativo['fundo'] != 'Total']
df_teste = df_diario_fundo_ativo[df_diario_fundo_ativo['fundo'] == 'Total']
#Agrupar por dia
df_teste_dia = df_teste.groupby(['date']).sum().reset_index()
df_teste_dia.drop(columns=['fundo','Ativo','Estratégia'], inplace=True)
df_teste_dia
# Out:
#          date  Rendimento_diario
# 0  2025-01-20           -1523.15
# 1  2025-01-21           -1523.15

# %%
#Ficar somente com a coluna de estratégia e rendimento diário
df_teste_estrategia = df_teste[['Estratégia','Rendimento_diario']]
df_teste_estrategia = df_teste_estrategia.groupby(['Estratégia']).sum().reset_index()
# Out:
#               Estratégia  Rendimento_diario
# 0  Juros Nominais Brasil            -3793.8
# 1                 Moedas              747.5

# %%
df_teste_estrategia_data = df_teste.groupby(['date','Estratégia']).sum().reset_index()
df_teste_estrategia_data.drop(columns=['fundo','Ativo'], inplace=True)
df_teste_estrategia_data
# Out:
#          date             Estratégia  Rendimento_diario
# 0  2025-01-20  Juros Nominais Brasil           -1896.90
# 1  2025-01-20                 Moedas             373.75
# 2  2025-01-21  Juros Nominais Brasil           -1896.90
# 3  2025-01-21                 Moedas             373.75

# %%
df_teste_fundos_estrategia = df_teste_fundos[['Estratégia','Rendimento_diario','fundo','date']]
#Dropar zeros
df_teste_fundos_estrategia = df_teste_fundos_estrategia[df_teste_fundos_estrategia['Rendimento_diario'] != 0]

df_teste_fundos_estrategia
# Out:
#                Estratégia  Rendimento_diario              fundo        date
# 7   Juros Nominais Brasil           -189.690      BH FIRF INFRA  2025-01-20
# 5                  Moedas             37.375      BH FIRF INFRA  2025-01-20
# 6   Juros Nominais Brasil           -189.690      BH FIRF INFRA  2025-01-21
# 4                  Moedas             37.375      BH FIRF INFRA  2025-01-21
# 11  Juros Nominais Brasil           -189.690     BORDEAUX INFRA  2025-01-20
# 9                  Moedas             37.375     BORDEAUX INFRA  2025-01-20
# 10  Juros Nominais Brasil           -189.690     BORDEAUX INFRA  2025-01-21
# 8                  Moedas             37.375     BORDEAUX INFRA  2025-01-21
# 15  Juros Nominais Brasil           -189.690       GLOBAL BONDS  2025-01-20
# 13                 Moedas             37.375       GLOBAL BONDS  2025-01-20
# 14  Juros Nominais Brasil           -189.690       GLOBAL BONDS  2025-01-21
# 12                 Moedas             37.375       GLOBAL BONDS  2025-01-21
# 19  Juros Nominais Brasil           -379.380          HORIZONTE  2025-01-20
# 17                 Moedas             74.750          HORIZONTE  2025-01-20
# 18  Juros Nominais Brasil           -379.380          HORIZONTE  2025-01-21
# 16                 Moedas             74.750          HORIZONTE  2025-01-21
# 23  Juros Nominais Brasil           -569.070           JERA2026  2025-01-20
# 21                 Moedas            112.125           JERA2026  2025-01-20
# 22  Juros Nominais Brasil           -569.070           JERA2026  2025-01-21
# 20                 Moedas            112.125           JERA2026  2025-01-21
# 27  Juros Nominais Brasil           -189.690  MANACA INFRA FIRF  2025-01-20
# 25                 Moedas             37.375  MANACA INFRA FIRF  2025-01-20
# 26  Juros Nominais Brasil           -189.690  MANACA INFRA FIRF  2025-01-21
# 24                 Moedas             37.375  MANACA INFRA FIRF  2025-01-21
# 31  Juros Nominais Brasil           -189.690           REAL FIM  2025-01-20
# 29                 Moedas             37.375           REAL FIM  2025-01-20
# 30  Juros Nominais Brasil           -189.690           REAL FIM  2025-01-21
# 28                 Moedas             37.375           REAL FIM  2025-01-21

# %%
                # --------------------------------------------------------------------
                # Exibir apenas a visão escolhida:
                # --------------------------------------------------------------------
                if tipo_visao == "Ativo":
                    st.subheader("Rendimento Diário - Fundo x Ativo")
                    st.dataframe(df_ativo)

                    # Exemplo de gráfico: escolher 1 fundo e plotar linha ao longo das datas
                    # pivot index=date, columns=Ativo, values=Rendimento_diario
                    fundos_unicos = df_ativo["fundo"].unique()
                    if len(fundos_unicos) > 0:
                        fundo_escolhido = st.selectbox(
                            "Escolha o Fundo para Gráfico:", fundos_unicos)
                        df_plot = df_ativo[df_ativo["fundo"]
                                           == fundo_escolhido].copy()
                        # pivot
                        df_plot_pivot = df_plot.pivot(index="date",
                                                      columns="Ativo",
                                                      values="Rendimento_diario").fillna(0.0)
                        # Ordenar index (date)
                        df_plot_pivot.sort_index(inplace=True)
                        st.line_chart(df_plot_pivot)

                elif tipo_visao == "Estratégia":
                    st.subheader("Rendimento Diário - Fundo x Estratégia")
                    st.dataframe(df_estr)

                    # Exemplo de gráfico: pivot index=date, columns=Estratégia
                    fundos_unicos = df_estr["fundo"].unique()
                    if len(fundos_unicos) > 0:
                        fundo_escolhido = st.selectbox(
                            "Escolha o Fundo para Gráfico:", fundos_unicos)
                        df_plot = df_estr[df_estr["fundo"]
                                          == fundo_escolhido].copy()
                        df_plot_pivot = df_plot.pivot(index="date",
                                                      columns="Estratégia",
                                                      values="Rendimento_diario").fillna(0.0)
                        df_plot_pivot.sort_index(inplace=True)
                        st.line_chart(df_plot_pivot)

                else:  # tipo_visao == "Fundo"
                    st.subheader("Rendimento Diário - Fundo (Total)")
                    st.dataframe(df_fundo)

                    # Exemplo de gráfico: pivot index=date, columns=fundo
                    df_plot_pivot = df_fundo.pivot(index="date",
                                                   columns="fundo",
                                                   values="Rendimento_diario").fillna(0.0)
                    df_plot_pivot.sort_index(inplace=True)
                    st.line_chart(df_plot_pivot)

# %%
df_teste['Rendimento_diario'].sum()
# Out:
# -3046.3000000000475

# %%
#Criar visualizações por tipo de estratégia
# 1) Performance diário do tipo de estratégia
df_diario_estrategia = (
    df_all
    .groupby(["date", "Estratégia"], as_index=False)["Rendimento_diario"]
    .sum()
    .sort_values(["date", "Estratégia"])
)
df_diario_estrategia
# Out:
#          date             Estratégia  Rendimento_diario
# 0  2025-01-14  Juros Nominais Brasil                0.0
# 1  2025-01-14                 Moedas             1046.5
# 2  2025-01-16  Juros Nominais Brasil                0.0
# 3  2025-01-16                 Moedas             1046.5
# 4  2025-01-22  Juros Nominais Brasil            -3793.8
# 5  2025-01-22                 Moedas           -25907.0

# %%
df = pd.read_excel('BBG - ECO DASH.xlsx', sheet_name='BZ RATES',
                    skiprows=1, thousands='.', decimal=',')
df.drop(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2',
        'Unnamed: 3', 'Unnamed: 26'], axis=1, inplace=True)
df.columns.values[0] = 'Date'
df = df.drop([0])  # Remove a primeira linha
df['Date'] = pd.to_datetime(df['Date'], format='%d/%m/%Y')
df.drop(['WSP1 Index'], axis=1, inplace=True)
df.columns = [
    'Date', 'DI_26', 'DI_27', 'DI_28', 'DI_29', 'DI_30',
    'DI_31', 'DI_32', 'DI_33', 'DI_35', 'DAP25', 'DAP26', 'DAP27',
    'DAP28', 'DAP30', 'DAP32', 'DAP35', 'DAP40', 'WDO1', 'TREASURY', 'IBOV',
    'TREASURY_AJUSTADA', 'S&P'
]
df.drop(['IBOV', 'S&P', 'TREASURY_AJUSTADA'], axis=1, inplace=True)
df
# Out:
#            Date     DI_26     DI_27     DI_28     DI_29     DI_30     DI_31  \
# 1    2020-02-12  70209.18  65409.99  60887.36  56672.47  52886.54  49070.25
# 2    2020-02-13  70032.54  65215.85  60701.18  56499.54  52778.63  49033.37
# 3    2020-02-14   70495.1  65695.35  61165.11  56936.56  53182.18  49395.12
# 4    2020-02-15       NaN       NaN       NaN       NaN       NaN       NaN
# 5    2020-02-16       NaN       NaN       NaN       NaN       NaN       NaN
# ...         ...       ...       ...       ...       ...       ...       ...
# 1797 2025-01-12       NaN       NaN       NaN       NaN       NaN       NaN
# 1798 2025-01-13  87335.38  75673.29  65634.63  57083.62   49654.3  43205.64
# 1799 2025-01-14  87416.06  75821.48  65865.49  57372.05  49991.23  43576.12
# 1800 2025-01-15  87518.61  76108.95  66349.81  58047.73  50750.32  44361.94
# 1801 2025-01-16  87513.21  75974.75  66120.14  57748.96     50397  43942.31
#
#          DI_32     DI_33     DI_35          DAP25          DAP26  \
# 1          NaN  42041.12  36075.15  117846.938474  112830.702256
# 2          NaN  42002.06  36035.21  117748.692419   112781.36182
# 3          NaN  42367.11  36395.26  118251.523925  113374.137398
# 4          NaN       NaN       NaN            NaN            NaN
# 5          NaN       NaN       NaN            NaN            NaN
# ...        ...       ...       ...            ...            ...
# 1797       NaN       NaN       NaN            NaN            NaN
# 1798  37643.08  32884.16  25278.69  175093.441657  157573.733897
# 1799  38014.83  33262.72  25641.95  175210.529487  157615.019623
# 1800  38792.97  34012.65  26336.55  175207.521107  157656.546353
# 1801  38379.02  33578.33  25890.18  175201.382291  157430.035588
#
#               DAP27          DAP28          DAP30          DAP32  \
# 1               NaN  104438.895434   96391.504572            NaN
# 2               NaN   104460.42694    96120.07331            NaN
# 3               NaN  105344.387896   96823.954574            NaN
# 4               NaN            NaN            NaN            NaN
# 5               NaN            NaN            NaN            NaN
# ...             ...            ...            ...            ...
# 1797            NaN            NaN            NaN            NaN
# 1798  149193.327941  135273.841563  116902.514573  100649.081997
# 1799  149404.722158  135528.865681  117329.254359  101129.024881
# 1800  149648.165452  135963.705698  117696.668882  101611.038157
# 1801   149373.89921  135602.858696  117733.310329  101287.639467
#
#              DAP35         DAP40      WDO1       TREASURY
# 1     79672.767913           NaN  43476.18       130687.5
# 2     79341.319733           NaN  43450.14       130765.6
# 3     80177.406713           NaN  43061.45       130984.3
# 4              NaN           NaN       NaN            NaN
# 5              NaN           NaN       NaN            NaN
# ...            ...           ...       ...            ...
# 1797           NaN           NaN       NaN            NaN
# 1798   83617.43126  58817.381714   61107.7       107234.3
# 1799  83983.381445  58934.271066  60707.25       107359.3
# 1800  84109.659544  59247.733966  60437.67       108328.1
# 1801  83815.060669           NaN     60775  108595.001221
#
# [1801 rows x 20 columns]

# %%
df_retorno = df.copy()
df_retorno.drop(['Date'], axis=1, inplace=True)
df_retorno.dropna(inplace=True)
df_retorno = df_retorno.astype(float)
df_retorno = df_retorno.tail(252*3).reset_index(drop=True)
df_retorno = np.log(df_retorno / df_retorno.shift(1)) 
df_retorno
# Out:
#         DI_26     DI_27     DI_28     DI_29     DI_30     DI_31     DI_32  \
# 0         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1    0.003754  0.005701  0.006776  0.008454  0.009608  0.010777  0.011946
# 2    0.002871  0.001074 -0.000114 -0.000817 -0.002052 -0.003562 -0.005341
# 3   -0.008011 -0.011669 -0.016497 -0.018074 -0.021431 -0.025008 -0.028318
# 4    0.004621  0.005906  0.006759  0.005970  0.006063  0.005986  0.006614
# ..        ...       ...       ...       ...       ...       ...       ...
# 733  0.000929  0.002531  0.004372  0.005500  0.005664  0.005202  0.004537
# 734 -0.000534 -0.001768 -0.004315 -0.007245 -0.010023 -0.012644 -0.014582
# 735  0.001605  0.003033  0.003234  0.002719  0.001805  0.000613 -0.000886
# 736  0.000923  0.001956  0.003511  0.005040  0.006763  0.008538  0.009827
# 737  0.001172  0.003784  0.007326  0.011708  0.015070  0.017873  0.020263
#
#         DI_33     DI_35     DAP25     DAP26     DAP27     DAP28     DAP30  \
# 0         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1    0.013115  0.015426  0.003561  0.002606  0.002457  0.005407  0.004491
# 2   -0.007389 -0.008809  0.006657  0.007766  0.008454  0.006644  0.008524
# 3   -0.031718 -0.037569 -0.002025 -0.002560 -0.003546 -0.005110 -0.009217
# 4    0.007241  0.008482  0.001691  0.001739  0.001451  0.002927  0.002875
# ..        ...       ...       ...       ...       ...       ...       ...
# 733  0.004074  0.002791  0.000434 -0.001368 -0.000304  0.000235  0.000047
# 734 -0.016987 -0.021493  0.000211 -0.000470 -0.000948 -0.001091 -0.002530
# 735 -0.001098 -0.002815  0.000985  0.000534  0.000386 -0.000934 -0.003217
# 736  0.011446  0.014268  0.000668  0.000262  0.001416  0.001883  0.003644
# 737  0.022295  0.026728 -0.000017  0.000263  0.001628  0.003203  0.003127
#
#         DAP32     DAP35     DAP40      WDO1  TREASURY
# 0         NaN       NaN       NaN       NaN       NaN
# 1    0.006438  0.009244  0.009224  0.001506  0.001953
# 2    0.007434  0.009246  0.016239  0.002128 -0.003788
# 3   -0.007506 -0.015842 -0.010060  0.004959 -0.006879
# 4    0.001456  0.005476  0.002211 -0.011314  0.001109
# ..        ...       ...       ...       ...       ...
# 733  0.001265  0.000558 -0.001624 -0.010916  0.000722
# 734 -0.004345 -0.001353 -0.013763  0.007196 -0.007682
# 735 -0.003115 -0.003439 -0.005694 -0.002085 -0.001456
# 736  0.004757  0.004367  0.001985 -0.006575  0.001165
# 737  0.004755  0.001502  0.005305 -0.004451  0.008983
#
# [738 rows x 19 columns]

# %%
var_Ativos = df_retorno.quantile(0.05)
var_Ativos
# Out:
# DI_26      -0.005381
# DI_27      -0.007642
# DI_28      -0.009781
# DI_29      -0.011466
# DI_30      -0.012828
# DI_31      -0.015058
# DI_32      -0.016941
# DI_33      -0.019156
# DI_35      -0.023063
# DAP25      -0.002068
# DAP26      -0.003684
# DAP27      -0.004393
# DAP28      -0.005310
# DAP30      -0.006876
# DAP32      -0.008394
# DAP35      -0.010445
# DAP40      -0.013195
# WDO1       -0.014193
# TREASURY   -0.007563
# Name: 0.05, dtype: float64

# %%
#pegar a pior variação de cada coluna
pior_variacao = df_retorno.min()
pior_variacao
# Out:
# DI_26      -0.006172
# DI_27      -0.011773
# DI_28      -0.015508
# DI_29      -0.019312
# DI_30      -0.022282
# DI_31      -0.026605
# DI_32      -0.032094
# DI_33      -0.035736
# DI_35      -0.046268
# DAP25      -0.001618
# DAP26      -0.007389
# DAP27      -0.008206
# DAP28      -0.009786
# DAP30      -0.020728
# DAP32      -0.028363
# DAP35      -0.046468
# DAP40      -0.054657
# WDO1       -0.020577
# TREASURY   -0.013198
# dtype: float64

# %%
#Piores varicões da coluna TREASURY
pior_variacao_treasury = df_retorno['TREASURY'].min()
pior_variacao_treasury
# Out:
# -0.013111019093292042

# %%
# DataFrame do dia atual (1 linha por Fundo)
df_current = pd.read_csv("df_current.csv")
# Exemplo: "2025-01-20"
dia_operacao = "2025-01-15"
# DF de transações: [Ativo, Quantidade, Dia de Compra, Preço de Compra, ...]
df_info = pd.read_csv("df_info.csv")
# DF de preços de fechamento B3: colunas ["Assets", <data1>, <data2>, ...]

# %%
df_fechamento_b3 = pd.read_csv("df_fechamento_b3.csv")
df_fechamento_b3 = df_fechamento_b3.replace('\.', '', regex=True)
df_fechamento_b3 = df_fechamento_b3.replace({',': '.'}, regex=True)
#Converter para float todas as colunas menos a primeira
df_fechamento_b3.iloc[:, 2:] = df_fechamento_b3.iloc[:, 2:].astype(float)
df_fechamento_b3
# Out:
#     Unnamed: 0    Assets 2025-01-02 2025-01-03 2025-01-06 2025-01-07  \
# 0            0     DAP25   98420.08   98537.44   98566.96    98606.0
# 1            1     DAP26   88536.62   88708.86   88894.14   88906.74
# 2            2     DAP27    83678.7   83886.14   84166.83   84173.14
# 3            3     DAP28   75982.66   76132.39   76434.84   76381.23
# 4            4     DAP29   72298.68    72349.2   72574.18   72334.21
# 5            5     DAP30   66333.67   66353.05   66578.79   66357.52
# 6            6     DAP32   57412.89   57107.32    57486.7   57181.02
# 7            7     DAP33   54417.48   54181.57   54617.59   54506.96
# 8            8     DAP35   47304.65   47182.63   47468.03   47164.85
# 9            9     DAP40   33461.41   33475.62   33767.22   33504.04
# 10          10     DAP45   23630.53   23641.67   23840.78   23933.04
# 11          11     DAP50   15974.11   16027.96   16238.97   16382.75
# 12          12     DAP55   11422.13   11473.62   11622.86   11807.21
# 13          13     DAP60     7847.2    7906.55    8037.55    8205.85
# 14          14     DI_26   86812.34   86950.54   87057.54   87081.12
# 15          15     DI_27   74824.27   75135.35   75344.87   75317.94
# 16          16     DI_28   64753.44   65159.49   65510.26   65440.86
# 17          17     DI_29   56356.33   56818.25   57270.12   57148.76
# 18          18     DI_30   49138.87   49646.42    50148.6   50006.23
# 19          19     DI_31   42922.79   43406.74   43964.63   43752.62
# 20          20     DI_32   37548.07   38009.88   38570.95   38361.41
# 21          21     DI_33   32856.11   33364.85   33907.77    33680.1
# 22          22     DI_34   28891.53   29402.98   29945.06    29702.5
# 23          23     DI_35    25365.1   25882.86   26437.04   26179.43
# 24          24     DI_36   22304.03   22804.15   23340.63   23089.19
# 25          25     DI_37    19620.1   20100.29   20616.54   20372.87
# 26          26     DI_38   17303.22   17761.73   18255.74   18021.19
# 27          27     DI_39   14926.11   15351.61   15811.02   15591.94
# 28          28     DI_40   13025.91   13423.72   13854.13    13648.0
# 29          29  TREASURY   108.8125   108.6406   108.5312   108.1718
# 30          30      WDO1     6192.3   6213.021   6143.028   6130.918
#
#    2025-01-08 2025-01-09 2025-01-10 2025-01-13 2025-01-14 2025-01-15  \
# 0    98589.62    98605.9   98600.13   98688.39   98728.79   98701.51
# 1    88985.51   88839.95   88774.27   88813.71   88813.96   88814.33
# 2    84216.02   84167.76   84065.34   84090.24   84187.56   84302.89
# 3     76429.4   76426.78   76322.91   76244.76    76368.7   76593.88
# 4    72471.68   72435.19   72283.27   72160.86   72384.21   72636.96
# 5    66308.42   66293.65   66108.37   65890.08   66113.47   66303.31
# 6    57117.54   57174.43   56911.25   56729.12   56984.85   57241.62
# 7    54522.76   54664.93   54428.38   54276.75   54460.07    54686.0
# 8    47359.26   47372.93   47296.15   47129.52   47323.51   47382.39
# 9    33878.97    33814.9   33343.71    33151.4   33208.67   33376.65
# 10   23768.95    23766.7   23471.01   23236.04   23409.39   23664.03
# 11   16240.48   16279.75   16115.57   15926.77   16117.13   16348.44
# 12   11655.61   11649.08   11512.56    11387.3   11519.11   11734.52
# 13    8047.39    8025.83    7889.17    7788.18    7885.87    8090.69
# 14   87160.83   87241.86   87195.29   87335.38   87416.06   87518.61
# 15   75386.58   75577.62   75444.09   75673.29   75821.48   76108.95
# 16   65418.97   65705.64   65422.71   65634.63   65865.49   66349.81
# 17   57028.06   57342.55    56928.6   57083.62   57372.05   58047.73
# 18   49781.28   50064.04   49564.77    49654.3   49991.23   50750.32
# 19   43501.71    43728.6   43179.16   43205.64   43576.12   44361.94
# 20    38056.8   38229.84   37676.43   37643.08   38014.83   38792.97
# 21   33348.15    33484.3   32920.29   32884.16   33262.72   34012.65
# 22    29368.4   29471.48   28908.35   28850.28   29208.99   29961.55
# 23    25828.5   25900.69   25349.94   25278.69   25641.95   26336.55
# 24   22747.56   22816.23   22281.63   22211.42   22561.64   23233.84
# 25   20042.58   20107.65   19592.23   19523.71   19859.36   20505.92
# 26   17703.95    17765.4   17271.58   17205.29   17525.26   18143.64
# 27   15296.17   15352.75   14893.38   14831.31   15127.82   15702.54
# 28   13370.24   13422.73   12992.27   12933.74   13210.55   13748.65
# 29   108.1406   108.2187   107.3906   107.2343   107.3593   108.3281
# 30   6146.352   6079.623   6123.527    6110.77   6070.725   6043.767
#
#    2025-01-16 2025-01-17 2025-01-20 2025-01-21
# 0    98711.42   98733.37   98761.04   98762.34
# 1    88827.83   88880.25   88842.11   88714.33
# 2    84345.68   84388.43   84413.08   84221.86
# 3    76566.03   76513.09   76510.75   76332.54
# 4    72600.59   72477.85   72441.89   72205.36
# 5    66220.66   66002.64   65988.47   65670.98
# 6    57058.48   56836.49   56655.28   56317.66
# 7    54408.02   54007.32   53899.03    53585.3
# 8    47170.64   46781.56   46617.53   46190.11
# 9    33203.46   32874.55   32704.37    32362.4
# 10   23449.18   23149.31   22939.57   22676.53
# 11   16156.86   16062.37   15930.77   15526.56
# 12   11593.78   11327.06   11178.92   11017.39
# 13    7955.57    7743.43    7619.35    7492.41
# 14   87508.82   87515.57   87587.23   87624.76
# 15   75941.34   75912.13   76071.37   76076.82
# 16   66059.28   65957.96   66231.08    66220.7
# 17   57656.34   57452.87   57828.83   57780.16
# 18   50287.21   49970.51   50358.09   50304.44
# 19   43811.31   43420.81   43814.78   43746.88
# 20   38199.22   37759.16   38101.49   38051.73
# 21   33425.87   32932.54   33271.96   33210.31
# 22   29350.19   28831.35   29114.55   29065.18
# 23   25734.23   25180.07    25470.9   25390.75
# 24   22648.41   22110.91   22390.87   22312.02
# 25   19940.72   19422.93   19690.86   19553.18
# 26   17601.41   17105.73    17360.8   17228.42
# 27   15197.44   14736.72   14972.82    14849.4
# 28    13274.7   12843.34    13063.5   12947.61
# 29   108.6093   108.5468   108.5468   108.7343
# 30   6081.568   6074.069   6056.388   6037.375

# %%
#Preciso pegar o dia de fechamento mais atual
ultimo_fechamento = df_fechamento_b3.columns[-1]

ultimo_fechamento
# Out:
# '2025-01-21'

# %%
df_current.set_index("Fundos/Carteiras Adm", inplace=True)

# %%
df_current.drop(columns=["Fundos/Carteiras Adm.1"], inplace=True)
df_current
# Out:
#                                PL  Weights    PL_atualizado        Adm  \
# Fundos/Carteiras Adm
# GLOBAL BONDS           29796115.0      4.0    R$119,184,460  SANTANDER
# HORIZONTE             240930319.0      1.0    R$240,930,319        BTG
# JERA2026              191147694.0      2.0    R$382,295,388  SANTANDER
# REAL FIM               36463215.0      2.0     R$72,926,430  SANTANDER
# BH FIRF INFRA          77314727.0      2.0    R$154,629,454        BTG
# BORDEAUX INFRA         45417246.0      2.0     R$90,834,492        BTG
# TOPAZIO INFRA          30777380.0      2.0     R$61,554,760        BTG
# MANACA INFRA FIRF      40334603.0      2.0     R$80,669,206        BTG
# AF DEB INCENTIVADAS    11563897.0      3.0     R$34,691,691        BTG
# Total                 703745196.0     20.0  R$1,237,716,200        NaN
#
#                       Max Contratos DI_33  Max Contratos WDO1  \
# Fundos/Carteiras Adm
# GLOBAL BONDS                    18.681007           17.718069
# HORIZONTE                       37.763489           35.816917
# JERA2026                        59.921091           56.832375
# REAL FIM                        11.430510           10.841308
# BH FIRF INFRA                   24.236666           22.987353
# BORDEAUX INFRA                  14.237425           13.503537
# TOPAZIO INFRA                    9.648111            9.150786
# MANACA INFRA FIRF               12.644115           11.992356
# AF DEB INCENTIVADAS              5.437586            5.157298
# Total                          194.000000          184.000000
#
#                       Contratos DI_33  Contratos WDO1
# Fundos/Carteiras Adm
# GLOBAL BONDS                       -6               5
# HORIZONTE                         -12              10
# JERA2026                          -18              17
# REAL FIM                           -4               3
# BH FIRF INFRA                      -7               7
# BORDEAUX INFRA                     -4               4
# TOPAZIO INFRA                      -3               3
# MANACA INFRA FIRF                  -4               4
# AF DEB INCENTIVADAS                -2               1
# Total                             -60              54

# %%
df_info
# Out:
#    Unnamed: 0  Ativo  Quantidade Dia de Compra  Preço de Compra  \
# 0           0   WDO1           8    2025-01-14           6000.0
# 1           1  DI_33         -10    2025-01-14          33300.0
# 2           2  DI_33         -10    2025-01-15          33300.0
# 3           3   WDO1          10    2025-01-15           6000.0
# 4           4  DI_33         -60    2025-01-21              0.0
# 5           5   WDO1          54    2025-01-21              0.0
#
#    Preço de Ajuste Atual   Rendimento
# 0               6056.388      451.104
# 1              33271.960      280.400
# 2              33271.960      280.400
# 3               6056.388      563.880
# 4              33271.960 -1996317.600
# 5               6056.388   327044.952

# %%
for fundo, row_fundo in df_current.iterrows():
    # Caminho do CSV do Fundo
    nome_arquivo_csv = os.path.join("BaseFundos", f"{fundo}.csv")

    # 2.1) Carregar (ou criar) o DataFrame histórico do Fundo (df_fundo)
    if os.path.exists(nome_arquivo_csv):
        df_fundo = pd.read_csv(nome_arquivo_csv, index_col=None)
        #Conferir se já existem dados para o dia de operação
        if df_fundo.columns.str.startswith(dia_operacao).any():
            df_fundo = df_fundo.drop(columns=df_fundo.columns[df_fundo.columns.str.startswith(dia_operacao)])
        # 2.2) Garante que "Ativo" seja índice (mas mantendo a coluna)
        if "Ativo" in df_fundo.columns:
            df_fundo.set_index("Ativo", inplace=True, drop=False)
    else:
        df_fundo = pd.DataFrame(columns=["Ativo",
                                        "Preco_Fechamento_Atual"])
        # 2.2) Garante que "Ativo" seja índice (mas mantendo a coluna)
        if "Ativo" in df_fundo.columns:
            df_fundo.set_index("Ativo", inplace=True, drop=False)
    subset = df_info[df_info["Dia de Compra"] == dia_operacao]
    lista_assets = subset["Ativo"].unique()
    for asset in lista_assets:
    # Se o ativo ainda não existe no df_fundo, cria a linha
        print(df_fundo.index)
        if asset not in df_fundo.index:
            df_fundo.loc[asset, "Ativo"] = asset
            df_fundo.loc[asset, f"{dia_operacao} - PL"] = row_fundo["PL"]
            df_fundo.loc[asset, "Preco_Fechamento_Atual"] = df_fechamento_b3.loc[df_fechamento_b3["Assets"] == asset, ultimo_fechamento].values[0]
            df_fundo.loc[asset, f"{dia_operacao} - Preco_Compra"] = df_info.loc[(df_info["Ativo"] == asset) & (df_info["Dia de Compra"] == dia_operacao), "Preço de Compra"].values[0]
            df_fundo.loc[asset, f'{dia_operacao} - Quantidade'] = row_fundo[f'Contratos {asset}']
            rendimento = (df_fundo.loc[df_fundo["Ativo"] == asset, "Preco_Fechamento_Atual"].values[0] - df_fundo.loc[df_fundo["Ativo"] == asset, f'{dia_operacao} - Preco_Compra'].values[0])
            df_fundo.loc[asset, f'{dia_operacao} - Rendimento'] = df_fundo.loc[df_fundo["Ativo"] == asset, f'{dia_operacao} - Quantidade'].values[0] * rendimento
        else:
            df_fundo.loc[asset, f"{dia_operacao} - PL"] = row_fundo["PL"]
            df_fundo.loc[asset, "Preco_Fechamento_Atual"] = df_fechamento_b3.loc[df_fechamento_b3["Assets"] == asset, ultimo_fechamento].values[0]
            df_fundo.loc[asset, f"{dia_operacao} - Preco_Compra"] = df_info.loc[(df_info["Ativo"] == asset) & (df_info["Dia de Compra"] == dia_operacao), "Preço de Compra"].values[0]
            df_fundo.loc[asset, f'{dia_operacao} - Quantidade'] = row_fundo[f'Contratos {asset}']
            rendimento = (df_fundo.loc[df_fundo["Ativo"] == asset, "Preco_Fechamento_Atual"].values[0] - df_fundo.loc[df_fundo["Ativo"] == asset, f'{dia_operacao} - Preco_Compra'].values[0])
            df_fundo.loc[asset, f'{dia_operacao} - Rendimento'] = df_fundo.loc[df_fundo["Ativo"] == asset, f'{dia_operacao} - Quantidade'].values[0] * rendimento
       
        #Pegar o Preco de compra de cada ativo

    df_fundo.reset_index(drop=True, inplace=True)
    df_fundo.to_csv(nome_arquivo_csv, index=False, encoding="utf-8")

    print(f"[{fundo}] -> CSV atualizado: {nome_arquivo_csv}")
# Out:
# Index(['DI_33', 'WDO1'], dtype='object', name='Ativo')
# Index(['DI_33', 'WDO1'], dtype='object', name='Ativo')
# [GLOBAL BONDS] -> CSV atualizado: BaseFundos/GLOBAL BONDS.csv
# Index(['DI_33', 'WDO1'], dtype='object', name='Ativo')
# Index(['DI_33', 'WDO1'], dtype='object', name='Ativo')
# [HORIZONTE] -> CSV atualizado: BaseFundos/HORIZONTE.csv
# Index(['DI_33', 'WDO1'], dtype='object', name='Ativo')
# Index(['DI_33', 'WDO1'], dtype='object', name='Ativo')
# [JERA2026] -> CSV atualizado: BaseFundos/JERA2026.csv
# Index(['DI_33', 'WDO1'], dtype='object', name='Ativo')
# Index(['DI_33', 'WDO1'], dtype='object', name='Ativo')
# [REAL FIM] -> CSV atualizado: BaseFundos/REAL FIM.csv
# Index(['DI_33', 'WDO1'], dtype='object', name='Ativo')
# Index(['DI_33', 'WDO1'], dtype='object', name='Ativo')
# [BH FIRF INFRA] -> CSV atualizado: BaseFundos/BH FIRF INFRA.csv
# Index(['DI_33', 'WDO1'], dtype='object', name='Ativo')
# Index(['DI_33', 'WDO1'], dtype='object', name='Ativo')
# [BORDEAUX INFRA] -> CSV atualizado: BaseFundos/BORDEAUX INFRA.csv
# Index(['DI_33', 'WDO1'], dtype='object', name='Ativo')
# Index(['DI_33', 'WDO1'], dtype='object', name='Ativo')
# [TOPAZIO INFRA] -> CSV atualizado: BaseFundos/TOPAZIO INFRA.csv
# Index(['DI_33', 'WDO1'], dtype='object', name='Ativo')
# Index(['DI_33', 'WDO1'], dtype='object', name='Ativo')
# [MANACA INFRA FIRF] -> CSV atualizado: BaseFundos/MANACA INFRA FIRF.csv
# Index(['DI_33', 'WDO1'], dtype='object', name='Ativo')
# Index(['DI_33', 'WDO1'], dtype='object', name='Ativo')
# [AF DEB INCENTIVADAS] -> CSV atualizado: BaseFundos/AF DEB INCENTIVADAS.csv
# Index(['DI_33', 'WDO1'], dtype='object', name='Ativo')
# Index(['DI_33', 'WDO1'], dtype='object', name='Ativo')
# [Total] -> CSV atualizado: BaseFundos/Total.csv

# %%
"""
- O CSV final de cada fundo terá linhas = cada ativo (ou "PL"),
e colunas básicas = ["Ativo","Preco_Compra","Preco_Fechamento_Atual", ...],
além das colunas diárias geradas a cada dia de operação:
    <dia_operacao> - Quantidade
    <dia_operacao> - Preço Pago
    <dia_operacao> - Rendimento
- Lógica geral:
1) Se houver aumento de posição no mesmo dia (quantidade final > anterior),
    recalculamos o preço médio (ponderado).
2) A coluna "Preco_Fechamento_Atual" vem do CSV de preços B3 para a
    última data disponível.
3) Tratamento especial da linha "PL":
    - Se não existir, criamos com quantidade definida (ex.: 1.0).
    - Armazenamos o PL do dia em "Preco_Fechamento_Atual".
"""
# ------------------------------------------------------------------
# 1) Carregar (ou processar) DF de preços de fechamento
# ------------------------------------------------------------------
# Supondo que o arquivo local seja "df_preco_de_ajuste_atual.csv"

# ------------------------------------------------------------------
# 2) Iterar cada fundo (linha) em df_current
# ------------------------------------------------------------------
for fundo, row_fundo in df_current.iterrows():
    df_fundo = pd.DataFrame(columns=["Ativo",
                                        "Preco_Compra",
                                        "Preco_Fechamento_Atual"])

    # 2.2) Garante que "Ativo" seja índice (mas mantendo a coluna)
    if "Ativo" in df_fundo.columns:
        df_fundo.set_index("Ativo", inplace=True, drop=False)

    # ----------------------------------------------------------------
    # 3) Verifica se existe coluna "PL" em df_current
    # ----------------------------------------------------------------
    valor_pl = None
    if "PL" in df_current.columns:
        valor_pl = row_fundo["PL"]  # PL atual do fundo

    # ----------------------------------------------------------------
    # 4) Identificar colunas de CONTRATOS no df_current
    # ----------------------------------------------------------------
    colunas_contratos = [
        c for c in df_current.columns
        if c.startswith("Contratos ")
        ]
    # Exemplo: {"Contratos WDO1": 10, "Contratos DI_33": -25, ...}
    serie_contratos = row_fundo[colunas_contratos]

    # ----------------------------------------------------------------
    # 5) Para cada ativo do df_current, precisamos garantir 3 colunas novas:
    #    <dia_operacao> - Quantidade
    #    <dia_operacao> - Preço Pago
    #    <dia_operacao> - Rendimento
    # ----------------------------------------------------------------
    col_qtd = f"{dia_operacao} - Quantidade"
    col_preco_pago = f"{dia_operacao} - Preço Pago"
    col_rendimento = f"{dia_operacao} - Rendimento"

    for c_ in [col_qtd, col_preco_pago, col_rendimento]:
        if c_ not in df_fundo.columns:
            df_fundo[c_] = 0.0

    # ----------------------------------------------------------------
    # 6) Se existir PL, criar/atualizar linha "PL"
    # ----------------------------------------------------------------
    if valor_pl is not None:
        if "PL" not in df_fundo.index:
            # Linha PL não existe: criamos com alguma quantidade específica
            df_fundo.loc["PL", "Ativo"] = "PL"
            df_fundo.loc["PL", "Preco_Compra"] = np.nan
            # Aqui, assumimos que você queira dar "1.0" de quantidade para PL,
            # mas pode alterar para outro valor, se preferir.
            df_fundo.loc["PL", col_qtd] = 1.0
        # Sempre que tiver PL, jogamos esse valor em Preco_Fechamento_Atual
        df_fundo.loc["PL", "Preco_Fechamento_Atual"] = valor_pl
        # Se quiser calcular "rendimento" do PL, defina a lógica.
        # Por default, deixaremos 0.0
        df_fundo.loc["PL", col_rendimento] = 0.0

    # ----------------------------------------------------------------
    # 7) Processar cada ativo (contratos)
    # ----------------------------------------------------------------
    for col_contrato, qtd_dia_raw in serie_contratos.items():
        ativo = col_contrato.replace("Contratos ", "").strip()

        # Converte a quantidade para float
        try:
            qtd_dia_nova = float(qtd_dia_raw)
        except:
            qtd_dia_nova = 0.0

        # Se o ativo ainda não existe no df_fundo, cria a linha
        if ativo not in df_fundo.index:
            df_fundo.loc[ativo, "Ativo"] = ativo
            df_fundo.loc[ativo, "Preco_Compra"] = 0.0
            df_fundo.loc[ativo, "Preco_Fechamento_Atual"] = 0.0

        # Carrega o preço médio atual (se for NaN, vira 0.0)
        preco_medio_atual = df_fundo.loc[ativo, "Preco_Compra"]
        if pd.isna(preco_medio_atual):
            preco_medio_atual = 0.0

        # 7.1) Descobre a quantidade que já estava neste MESMO dia
        qtd_dia_anterior = df_fundo.loc[ativo, col_qtd]
        if pd.isna(qtd_dia_anterior):
            qtd_dia_anterior = 0.0

        diff = qtd_dia_nova - qtd_dia_anterior
        st.table(df_fundo)
        st.table(df_info)
        st.write(ativo)
        # 7.2) Se houve compra adicional (diff > 0), recalcular preço médio
        if diff > 0:
            # Localizar no df_info as linhas para este dia/ativo
            subset = df_info[
                (df_info["Ativo"] == ativo) &
                (df_info["Dia de Compra"] == dia_operacao)
            ]
            if len(subset) == 0:
                # Se não encontrou nada em df_info, mantemos o preço anterior
                preco_compra_dia = preco_medio_atual
            else:
                # Faz soma ponderada das quantidades positivas
                qtd_total_dia = 0.0
                valor_total_dia = 0.0
                for i, r in subset.iterrows():
                    q_linha = float(str(r["Quantidade"]).replace(",", "."))
                    p_linha = float(
                        str(r["Preço de Compra"]).replace(",", "."))
                    if q_linha > 0:
                        qtd_total_dia += q_linha
                        valor_total_dia += (q_linha * p_linha)
                if qtd_total_dia == 0:
                    preco_compra_dia = preco_medio_atual
                else:
                    preco_compra_dia = valor_total_dia / qtd_total_dia
            
            # Novo preço médio = ponderação do que havia até qtd_dia_anterior + diff
            qtd_comprada = diff
            qtd_final = qtd_dia_nova
            novo_preco_medio = (
                (qtd_dia_anterior * preco_medio_atual) +
                (qtd_comprada * preco_compra_dia)
            ) / qtd_final

            df_fundo.loc[ativo, "Preco_Compra"] = novo_preco_medio
            # Também vamos registrar em "<dia> - Preço Pago" a média do dia
            df_fundo.loc[ativo, col_preco_pago] = preco_compra_dia

        elif diff < 0:
            # Se houve venda, normalmente não alteramos o preço médio
            # (a menos que queira zerar posição ou recalcular).
            # No caso de venda, se quiser, pode registrar "Preço Pago" do dia
            # com o mesmo valor do preço médio anterior, ou outro.
            df_fundo.loc[ativo, col_preco_pago] = preco_medio_atual
            subset = df_info[
                (df_info["Ativo"] == ativo) &
                (df_info["Dia de Compra"] == dia_operacao)
            ]
            for i, r in subset.iterrows():
                p_linha = float(
                    str(r["Preço de Compra"]).replace(",", "."))
                df_fundo.loc[ativo, col_preco_pago] = p_linha

        else:
            # Se não houve alteração de posição neste dia, mantemos o Preço Pago
            # para o que já estava (caso já tenha sido setado acima).
            if pd.isna(df_fundo.loc[ativo, col_preco_pago]):
                df_fundo.loc[ativo, col_preco_pago] = 0.0

        # Atualiza a coluna de quantidade do dia
        df_fundo.loc[ativo, col_qtd] = qtd_dia_nova

        # 7.3) Atualizar Preço de Fechamento Atual com base em df_fechamento_b3
        row_fech = df_fechamento_b3[df_fechamento_b3["Assets"] == ativo]
        if not row_fech.empty:
            valor_fechamento_str = str(
                row_fech[ultima_data_fechamento].values[0])
            # Exemplo de conversão "6.081,5680" -> "6081.5680"
            valor_fechamento_str = valor_fechamento_str.replace(
                ".", "").replace(",", ".")
            try:
                valor_fechamento_float = float(valor_fechamento_str)
            except:
                valor_fechamento_float = 0.0
            df_fundo.loc[ativo,
                            "Preco_Fechamento_Atual"] = valor_fechamento_float
        else:
            df_fundo.loc[ativo, "Preco_Fechamento_Atual"] = np.nan

    # ----------------------------------------------------------------
    # 8) Calcular "Rendimento" do dia para cada ativo
    #    (exemplo: (Preco_Fechamento_Atual - Preco_Compra) * Quantidade_dia)
    # ----------------------------------------------------------------
    for ativo_idx in df_fundo.index:
        # Se for "PL", já tratamos lá em cima, mas se quiser,
        # podemos garantir zero ou outro valor aqui
        if ativo_idx == "PL":
            # Se desejar, pode redefinir aqui a fórmula de rendimento do PL
            continue

        preco_fech = df_fundo.loc[ativo_idx, "Preco_Fechamento_Atual"]
        preco_med = df_fundo.loc[ativo_idx, "Preco_Compra"]
        qtd_hoje = df_fundo.loc[ativo_idx, col_qtd]

        if (not pd.isna(preco_fech)) and (not pd.isna(preco_med)) and (not pd.isna(qtd_hoje)):
            rendimento_dia = (preco_fech - p_linha) * qtd_hoje
        else:
            rendimento_dia = 0.0

        df_fundo.loc[ativo_idx, col_rendimento] = rendimento_dia

    # ----------------------------------------------------------------
    # 9) Salvar o CSV do fundo
    # ----------------------------------------------------------------
    df_fundo.reset_index(drop=True, inplace=True)
    df_fundo.to_csv(nome_arquivo_csv, index=False, encoding="utf-8")

    print(f"[{fundo}] -> CSV atualizado: {nome_arquivo_csv}")

# %%
df_global = pd.read_csv('GLOBAL BONDS.csv')
df_global
# Out:
#                 Ativo  Rendimento  Preco_Compra     2025-01-20
# 0                 NaN         NaN           NaN  R$119,184,460
# 1     Contratos DI_33         NaN           NaN             -2
# 2      Contratos WDO1         NaN           NaN              1
# 3  Contratos TREASURY         NaN           NaN              0

# %%
df_jera2026 = pd.read_csv('JERA2026.csv')
df_jera2026
# Out:
#                 Ativo  Rendimento  Preco_Compra     2025-01-20
# 0                 NaN         NaN           NaN  R$382,295,388
# 1     Contratos DI_33         NaN           NaN             -8
# 2      Contratos WDO1         NaN           NaN              3
# 3  Contratos TREASURY         NaN           NaN              1

# %%
df_pregao = pd.read_csv('ajustes_do_pregao.csv')
df_pregao
# Out:
#                                  Mercadoria Vencimento  \
# 0          ABEVO - Contrato Futuro de ABEV3        F25
# 1     AFS - Rande da África do Sul (em USD)        G25
# 2           ARB - Peso Argentino (em Reais)        G25
# 3             ARS - Peso Argentino (em USD)        G25
# 4        AUD - Dólar Australiano (em Reais)        G25
# ..                                      ...        ...
# 82                          WEU - EURO MÍNI        G25
# 83                      WIN - Ibovespa Mini        G25
# 84    WSP - Microcontrato Futuro de S&P 500        H25
# 85                     XFI - Futuro de IFIX        G25
# 86  ZAR - Rande da África do Sul (em Reais)        G25
#
#    Preço de ajuste anterior Preço de ajuste Atual   Variação  \
# 0                     11,21                 11,40       0,19
# 1                18.968,000            18.791,500   -176,500
# 2                    5,7740                5,7520    -0,0220
# 3            1.051.438,0000        1.050.770,1000  -667,9000
# 4                3.756,5650            3.760,4620     3,8970
# ..                      ...                   ...        ...
# 82               6.256,9020            6.224,9770   -31,9250
# 83                  120.272               123.673      3.401
# 84                 5.880,75              5.992,50     111,75
# 85                 3.148,10              3.174,30      26,20
# 86               3.200,5090            3.216,2240    15,7150
#
#    Valor do ajuste por contrato (R$)
# 0                               0,19
# 1                             566,68
# 2                               3,30
# 3                              38,67
# 4                             233,82
# ..                               ...
# 82                            319,25
# 83                            680,20
# 84                          1.683,12
# 85                            262,00
# 86                            550,02
#
# [87 rows x 6 columns]

# %%
file_bbg = 'BBG - ECO DASH.xlsx'
#Pular primeira linha, primeira coluna, e ir até a linha 23
df = pd.read_excel(file_bbg, sheet_name='DIV01',
                skiprows=1, usecols='E:F', nrows=21)
df = df.T
columns = [
    'DI_26', 'DI_27', 'DI_28', 'DI_29', 'DI_30',
    'DI_31', 'DI_32', 'DI_33', 'DI_35', 'DAP25', 'DAP26', 'DAP27',
    'DAP28', 'DAP30', 'DAP32', 'DAP35', 'DAP40', 'WDO1', 'TREASURY', 'IBOV','S&P'
]
df.columns = columns
#dropar a primeira linha
df = df.drop(df.index[0])

df['TREASURY'] = df['TREASURY'] * df_precos['WDO1']

# %%
df = pd.read_csv('df_preco_de_ajuste_atual.csv')
df
# Out:
#       Assets  2025-01-17
# 0      DAP25   98.711,42
# 1      DAP26   88.827,83
# 2      DAP27   84.345,68
# 3      DAP28   76.566,03
# 4      DAP29   72.600,59
# 5      DAP30   66.220,66
# 6      DAP32   57.058,48
# 7      DAP33   54.408,02
# 8      DAP35   47.170,64
# 9      DAP40   33.203,46
# 10     DAP45   23.449,18
# 11     DAP50   16.156,86
# 12     DAP55   11.593,78
# 13     DAP60    7.955,57
# 14    DAP_25         NaN
# 15    DAP_26         NaN
# 16    DAP_27         NaN
# 17    DAP_28         NaN
# 18    DAP_29         NaN
# 19    DAP_30         NaN
# 20    DAP_32         NaN
# 21    DAP_33         NaN
# 22    DAP_35         NaN
# 23    DAP_40         NaN
# 24    DAP_45         NaN
# 25    DAP_50         NaN
# 26    DAP_55         NaN
# 27    DAP_60         NaN
# 28     DI_26   87.508,82
# 29     DI_27   75.941,34
# 30     DI_28   66.059,28
# 31     DI_29   57.656,34
# 32     DI_30   50.287,21
# 33     DI_31   43.811,31
# 34     DI_32   38.199,22
# 35     DI_33   33.425,87
# 36     DI_34   29.350,19
# 37     DI_35   25.734,23
# 38     DI_36   22.648,41
# 39     DI_37   19.940,72
# 40     DI_38   17.601,41
# 41     DI_39   15.197,44
# 42     DI_40   13.274,70
# 43  TREASURY    108,6093
# 44      WDO1  6.081,5680

# %%
import os
import pandas as pd
import datetime
import numpy as np

# %%
def processar_b3_portifolio():
    """
    Exemplo de função que carrega dois dataframes de CSV:
     - df_preco_de_ajuste_atual.csv : preços de fechamento (colunas de datas)
     - df_variacao.csv : variação diária dos ativos (colunas de datas)
    """
    df_b3_fechamento = pd.read_csv("df_preco_de_ajuste_atual.csv")  
    # df_b3_fechamento possui colunas: ['Ativo', '17/01/2025', '18/01/2025', ...]
    
    df_b3_variacao = pd.read_csv("df_variacao.csv")
    # df_b3_variacao possui colunas: ['Ativo', '17/01/2025', '18/01/2025', ...]
    #Tirar o pontos das casas de milhar
    df_b3_fechamento = df_b3_fechamento.replace('\.', '', regex=True)
    df_b3_variacao = df_b3_variacao.replace('\.', '', regex=True)

    #Trocar Virgula por Ponto
    df_b3_fechamento = df_b3_fechamento.replace(',', '.', regex=True)
    df_b3_variacao = df_b3_variacao.replace(',', '.', regex=True)
    print(df_b3_fechamento)
    #Converter para Float menos a primeira coluna
    df_b3_fechamento.iloc[:, 1:] = df_b3_fechamento.iloc[:, 1:].astype(float)
    df_b3_variacao.iloc[:, 1:] = df_b3_variacao.iloc[:, 1:].astype(float)
    #Printar o tipo das colunas
    print(df_b3_fechamento.dtypes)
    print(df_b3_variacao.dtypes)
    
    return df_b3_fechamento, df_b3_variacao

assets = ['DAP28', 'DI_31','WDO1', 'TREASURY']
quantidades = [2, 1, 1, 1]
compra_especifica = {'DAP28': 5.5, 'TREASURY': 105.5}

dia_compra = {'DAP28': '2025-01-17', 'DI_31': '2025-01-17', 'WDO1':'2025-01-17', 'TREASURY': '2025-01-17'}


def checkar_portifolio(assets, 
                       quantidades, 
                       compra_especifica,  # dict { 'PETR4': 200, 'VALE3': 150 } etc.
                       dia_compra,         # pode ser dict { 'PETR4': '17/01/2025', 'VALE3': '16/01/2025' } ou string única
                       df_b3_fechamento, 
                       df_b3_variacao):
    """
    Verifica (ou cria) um CSV de portfólio e atualiza as posições de acordo com:
      1) Lista de ativos (assets) e suas quantidades (quantidades).
      2) Dicionário de compra_especifica (caso o usuário tenha quantidades específicas para algum ativo).
      3) Dia de compra, que pode ser um único valor ou um dicionário.
      4) Atualiza Preço de Compra, Preço de Ajuste Atual, Variação e Rendimento.
    """
    
    nome_arquivo_portifolio = 'portifolio_posições.csv'
    
    # 1) Carrega portfólio existente (se existir)
    if os.path.exists(nome_arquivo_portifolio):
        df_portifolio = pd.read_csv(nome_arquivo_portifolio, index_col=0)
    else:
        # Podemos criar um DataFrame com colunas definidas para evitar problemas de colunas inexistentes
        df_portifolio = pd.DataFrame(columns=[
            'Quantidade', 
            'Dia de Compra', 
            'Preço de Compra', 
            'Preço de Ajuste Atual', 
            'Variação de Taxa', 
            'Rendimento'
        ])
    
    # 2) Remover do DataFrame os ativos que NÃO estão na nova lista de assets
    #    (significa que o usuário removeu aquele ativo do portfólio)
    ativos_existentes = df_portifolio.index.tolist()
    for ativo_em_port in ativos_existentes:
        if ativo_em_port not in assets:
            df_portifolio.drop(index=ativo_em_port, inplace=True)
    # 3) Adicionar ou atualizar as quantidades dos ativos que estão na nova lista
    #    Se há compra_especifica, ela sobrescreve a quantidade
    #    Também atualizamos o 'Dia de Compra' se fornecido
    for asset, qtd_user in zip(assets, quantidades):
        

        qtd_final = qtd_user
        
        # Verifica se o dia_compra é dict ou valor único
        if isinstance(dia_compra, dict):
            dia_de_compra_atual = dia_compra.get(asset, None)
        else:
            # Se dia_compra for apenas uma string (valor único)
            dia_de_compra_atual = dia_compra
        if asset not in df_portifolio.index:
            # Se não existe, cria linha nova
            df_portifolio.loc[asset, 'Quantidade'] = qtd_final
            df_portifolio.loc[asset, 'Dia de Compra'] = dia_de_compra_atual
        else:
            # Se já existe, apenas atualiza
            df_portifolio.loc[asset, 'Quantidade'] = qtd_final
            # Se dia_compra foi passado como dict e existe valor pra esse ativo, atualiza

            if dia_de_compra_atual is not None:
                df_portifolio.loc[asset, 'Dia de Compra'] = dia_de_compra_atual

    # 4) Para cada ativo no DataFrame final, calculamos
    #    - Preço de Compra (com base em df_b3_fechamento na data de compra)
    #    - Preço de Ajuste Atual (com base em df_b3_fechamento na data de hoje)
    #    - Variação de Taxa (com base em df_b3_variacao na data de compra ou acumulada, depende da necessidade)
    #    - Rendimento (Quantidade * (Preço de Ajuste Atual - Preço de Compra)) ou vice-versa
    
    # Monta a string da data de hoje no mesmo formato das colunas do CSV
    # As colunas do CSV podem estar em formato "dd/mm/yyyy" ou "yyyy-mm-dd", dependendo de como foi salvo
    # Ajuste conforme a forma em que foram salvas:

    ############################## ---- PROBLEMA ---- ##############################
    #  
    data_hoje_str = datetime.date.today().strftime('%Y-%m-%d')

    for asset in df_portifolio.index:
        try:
            # Dia de compra que foi salvo
            dia_compra_ativo = df_portifolio.loc[asset, 'Dia de Compra']
            # (Opcional) se for "yyyy-mm-dd", converter para "dd/mm/yyyy" para casar com o CSV
            # Caso já esteja no formato correto, você pode pular esta conversão.
            # Exemplo (caso precise):
            # dia_compra_dt = datetime.datetime.strptime(dia_compra_ativo, '%Y-%m-%d')
            # dia_compra_ativo = dia_compra_dt.strftime('%d/%m/%Y')

            # PREÇO DE COMPRA
            # Localiza a linha do ativo e depois pega o valor na coluna da data de compra
            filtro_ativo = (df_b3_fechamento['Assets'] == asset)

            # Se o usuário informou um valor de compra_especifica para este ativo, sobrescreve
            if compra_especifica and (asset in compra_especifica):
                preco_compra = compra_especifica[asset]
                print(preco_compra)
            else:
                preco_compra = df_b3_fechamento.loc[filtro_ativo, dia_compra_ativo].values[0]
                print(preco_compra)
                print(df_b3_fechamento.loc[filtro_ativo, dia_compra_ativo].values[0])

            df_portifolio.loc[asset, 'Preço de Compra'] = preco_compra

            


            # PREÇO DE AJUSTE ATUAL
            # Usa a data de hoje (coluna de hoje) no df_b3_fechamento
            preco_ajuste_atual = df_b3_fechamento.loc[filtro_ativo, data_hoje_str].values[0]
            df_portifolio.loc[asset, 'Preço de Ajuste Atual'] = preco_ajuste_atual
            
            # VARIAÇÃO DE TAXA
            # Depende se você quer pegar a variação apenas do dia_compra_ativo ou a variação acumulada.
            # Abaixo apenas um exemplo de pegar a variação no dia de compra (ou outro critério)
            filtro_variacao = (df_b3_variacao['Assets'] == asset)
            variacao_taxa = df_b3_variacao.loc[filtro_variacao, dia_compra_ativo].values[0]
            df_portifolio.loc[asset, 'Variação de Taxa'] = variacao_taxa
            
            # RENDIMENTO
            # De acordo com seu snippet original, mas usualmente seria (Preço Atual - Preço Compra).
            df_portifolio.loc[asset, 'Rendimento'] = (
                df_portifolio.loc[asset, 'Quantidade'] * 
                (df_portifolio.loc[asset, 'Preço de Ajuste Atual'] - df_portifolio.loc[asset, 'Preço de Compra'])
            )
            
        except Exception as e:
            # Caso alguma coluna não seja encontrada ou dê erro, você pode tratar aqui
            print(f"[*] Erro ao calcular valores para o ativo {asset}: {e}")

    
    # 5) Salva o DataFrame atualizado de volta no CSV
    df_portifolio.to_csv(nome_arquivo_portifolio)
    
    return df_portifolio

df_b3_fechamento, df_b3_variacao = processar_b3_portifolio()
df_portifolio = checkar_portifolio(assets, quantidades, compra_especifica, dia_compra, df_b3_fechamento, df_b3_variacao)
df_portifolio
# Out:
#       Assets 2025-01-17
# 0      DAP25   98711.42
# 1      DAP26   88827.83
# 2      DAP27   84345.68
# 3      DAP28   76566.03
# 4      DAP29   72600.59
# 5      DAP30   66220.66
# 6      DAP32   57058.48
# 7      DAP33   54408.02
# 8      DAP35   47170.64
# 9      DAP40   33203.46
# 10     DAP45   23449.18
# 11     DAP50   16156.86
# 12     DAP55   11593.78
# 13     DAP60    7955.57
# 14     DI_26   87508.82
# 15     DI_27   75941.34
# 16     DI_28   66059.28
# 17     DI_29   57656.34
# 18     DI_30   50287.21
# 19     DI_31   43811.31
# 20     DI_32   38199.22
# 21     DI_33   33425.87
# 22     DI_34   29350.19
# 23     DI_35   25734.23
# 24     DI_36   22648.41
# 25     DI_37   19940.72
# 26     DI_38   17601.41
# 27     DI_39   15197.44
# 28     DI_40   13274.70
# 29      WDO1  6081.5680
# 30  TREASURY   108.6093
# Assets        object
# 2025-01-17    object
# dtype: object
# Assets        object
# 2025-01-17    object
# dtype: object
# 5.5
# [*] Erro ao calcular valores para o ativo DAP28: '2025-01-20'
# 43811.31
# 43811.31
# [*] Erro ao calcular valores para o ativo DI_31: '2025-01-20'
# 6081.568
# 6081.568
# [*] Erro ao calcular valores para o ativo WDO1: '2025-01-20'
# 105.5
# [*] Erro ao calcular valores para o ativo TREASURY: '2025-01-20'
#          Quantidade Dia de Compra Preço de Compra Preço de Ajuste Atual  \
# DAP28             2    2025-01-17             5.5                   NaN
# DI_31             1    2025-01-17        43811.31                   NaN
# WDO1              1    2025-01-17        6081.568                   NaN
# TREASURY          1    2025-01-17           105.5                   NaN
#
#          Variação de Taxa Rendimento
# DAP28                 NaN        NaN
# DI_31                 NaN        NaN
# WDO1                  NaN        NaN
# TREASURY              NaN        NaN

# %%
df_posi = pd.read_csv('portifolio_posições.csv')
df_posi
# Out:
#     Ativo  Quantidade Dia de Compra  Preço de Compra  Preço de Ajuste Atual  \
# 0   DI_26           1    2025-01-19              NaN              87508.820
# 1   DI_28           2    2025-01-19              NaN              66059.280
# 2   DI_30           1    2025-01-19              NaN              50287.210
# 3   DI_32           1    2025-01-19              NaN              38199.220
# 4   DI_26           1    2025-01-17          100.000              87508.820
# 5   DI_28           2    2025-01-17          100.000              66059.280
# 6   DI_30           1    2025-01-17          100.000              50287.210
# 7   DI_32           1    2025-01-17           98.500              38199.220
# 8   DI_28           2    2025-01-17        66059.280              66059.280
# 9   DI_32           1    2025-01-17        38199.220              38199.220
# 10  DAP25           1    2025-01-17          100.000              98711.420
# 11  DAP25           1    2025-01-17          200.000              98711.420
# 12  DI_26           2    2025-01-17        87508.820              87508.820
# 13  DI_28           6    2025-01-17        66059.280              66059.280
# 14  DI_30           2    2025-01-17        50287.210              50287.210
# 15  DI_32           3    2025-01-17        38199.220              38199.220
# 16   WDO1           1    2025-01-17         6081.568               6081.568
#
#     Variação de Taxa  Rendimento
# 0                NaN         NaN
# 1                NaN         NaN
# 2                NaN         NaN
# 3                NaN         NaN
# 4            -49.620    87408.82
# 5           -320.730   131918.56
# 6           -486.210    50187.21
# 7           -611.400    38100.72
# 8           -320.730        0.00
# 9           -611.400        0.00
# 10           -33.330    98611.42
# 11           -33.330    98511.42
# 12           -49.620        0.00
# 13          -320.730        0.00
# 14          -486.210        0.00
# 15          -611.400        0.00
# 16            37.801        0.00

# %%
df_resumo_port = df_posi.copy()
#Agrupar por Ativo
df_resumo_port = df_resumo_port.groupby('Ativo').sum()
df_resumo_port['Preço de Compra'] = df_resumo_port['Preço de Compra'] / df_resumo_port['Quantidade']
# Out:
#        Quantidade                             Dia de Compra  Preço de Compra  \
# Ativo
# DAP25           2                      2025-01-172025-01-17          300.000
# DI_26           4            2025-01-192025-01-172025-01-17        87608.820
# DI_28          12  2025-01-192025-01-172025-01-172025-01-17       132218.560
# DI_30           4            2025-01-192025-01-172025-01-17        50387.210
# DI_32           6  2025-01-192025-01-172025-01-172025-01-17        76496.940
# WDO1            1                                2025-01-17         6081.568
#
#        Preço de Ajuste Atual  Variação de Taxa  Rendimento
# Ativo
# DAP25             197422.840           -66.660   197122.84
# DI_26             262526.460           -99.240    87408.82
# DI_28             264237.120          -962.190   131918.56
# DI_30             150861.630          -972.420    50187.21
# DI_32             152796.880         -1834.200    38100.72
# WDO1                6081.568            37.801        0.00

# %%
df_b3_fechamento
# Out:
#       Assets  2025-01-17
# 0     DAP_25   98.711,42
# 1     DAP_26   88.827,83
# 2     DAP_27   84.345,68
# 3     DAP_28   76.566,03
# 4     DAP_29   72.600,59
# 5     DAP_30   66.220,66
# 6     DAP_32   57.058,48
# 7     DAP_33   54.408,02
# 8     DAP_35   47.170,64
# 9     DAP_40   33.203,46
# 10    DAP_45   23.449,18
# 11    DAP_50   16.156,86
# 12    DAP_55   11.593,78
# 13    DAP_60    7.955,57
# 14     DI_26   87.508,82
# 15     DI_27   75.941,34
# 16     DI_28   66.059,28
# 17     DI_29   57.656,34
# 18     DI_30   50.287,21
# 19     DI_31   43.811,31
# 20     DI_32   38.199,22
# 21     DI_33   33.425,87
# 22     DI_34   29.350,19
# 23     DI_35   25.734,23
# 24     DI_36   22.648,41
# 25     DI_37   19.940,72
# 26     DI_38   17.601,41
# 27     DI_39   15.197,44
# 28     DI_40   13.274,70
# 29      WDO1  6.081,5680
# 30  TREASURY    108,6093

# %%
df_port = pd.read_csv('portifolio_posições.csv')
df_port
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_port = pd.read_csv('portifolio_posições.csv')
#       2 df_port
#
# NameError: name 'pd' is not defined

# %%
import os
import pandas as pd
import datetime
import numpy as np

def processar_b3_portifolio():
    """
    Exemplo de função que carrega dois dataframes de CSV:
     - df_preco_de_ajuste_atual.csv : preços de fechamento (colunas de datas)
     - df_variacao.csv : variação diária dos ativos (colunas de datas)
    """
    df_b3_fechamento = pd.read_csv("df_preco_de_ajuste_atual.csv")  
    # df_b3_fechamento possui colunas: ['Ativo', '17/01/2025', '18/01/2025', ...]
    
    df_b3_variacao = pd.read_csv("df_variacao.csv")
    # df_b3_variacao possui colunas: ['Ativo', '17/01/2025', '18/01/2025', ...]
    #Tirar o pontos das casas de milhar
    df_b3_fechamento = df_b3_fechamento.replace('\.', '', regex=True)
    df_b3_variacao = df_b3_variacao.replace('\.', '', regex=True)

    #Trocar Virgula por Ponto
    df_b3_fechamento = df_b3_fechamento.replace(',', '.', regex=True)
    df_b3_variacao = df_b3_variacao.replace(',', '.', regex=True)
    print(df_b3_fechamento)
    #Converter para Float menos a primeira coluna
    df_b3_fechamento.iloc[:, 1:] = df_b3_fechamento.iloc[:, 1:].astype(float)
    df_b3_variacao.iloc[:, 1:] = df_b3_variacao.iloc[:, 1:].astype(float)
    #Printar o tipo das colunas
    print(df_b3_fechamento.dtypes)
    print(df_b3_variacao.dtypes)
    
    return df_b3_fechamento, df_b3_variacao


################ DEIXAR ESSA FUNÇÃO ATUALIZADA COM A LISTA DE ASSETS DEFAUTL DO PORTIFÓLIO E SUAS QUANTIDADES ################
def processar_dados_port():
    df_assets = pd.read_csv("portifolio_posições.csv")
    df_assets.rename(columns={'Unnamed: 0': 'Ativo'}, inplace=True)
    assets_iniciais = df_assets['Ativo'].tolist()
    # Criar uma lista com as quantidades, convertendo para inteiros e ignorando valores nulos
    quantidades_iniciais = (
        df_assets['Quantidade']
        .apply(lambda x: int(x) if x == x else 0)  # Converte para inteiro, garantindo valores válidos
        .tolist()
    )
    #Criar um dicionário com os ativos e suas quantidades
    assets_quantidades = dict(zip(assets_iniciais, quantidades_iniciais))

    return assets_iniciais, assets_quantidades

#NA SEGUNDA PÁGINA TEM QUE CRIAR UM CAMPO PARA O USUÁRIO INSERIR A DATA QUE ELE COMPROU DETERMINADO ATIVO E SE ELE QUER INSERIR UM VALOR DE COMPRA ESPECÍFICO
#ATUALIZAR PRA ESSA LISTA DE QUANTIDADES LER O PORTIFÓLIO_POSIÇÕES E PEGAR AS QUANTIDADES DE LÁ, MAS PERMITIR O USUÁRIO ALTERAR TANTO AS QUANTIDADES QUANTO OS ATIVOS SELECIONADOS. OU SEJA, QUERO QUE OS INPUTS DO USUÁRIO NA TELA PRINCIPAL ATUALIZEM O PORTIFÓLIO_POSIÇÕES
assets = processar_dados_port()
quantidades = {'DAP28': 10, 'TREASURY': 20}
compra_especifica = {'DAP28': 5.5, 'TREASURY': 105.5}
dia_compra = {'DAP28': '2025-01-17', 'DI_31': '2025-01-17', 'WDO1':'2025-01-17', 'TREASURY': '2025-01-17'}


def checkar_portifolio(assets, 
                       quantidades, 
                       compra_especifica,  # dict { 'PETR4': 200, 'VALE3': 150 } etc.
                       dia_compra,         # pode ser dict { 'PETR4': '17/01/2025', 'VALE3': '16/01/2025' } ou string única
                       df_b3_fechamento, 
                       df_b3_variacao):
    """
    Verifica (ou cria) um CSV de portfólio e atualiza as posições de acordo com:
      1) Lista de ativos (assets) e suas quantidades (quantidades).
      2) Dicionário de compra_especifica (caso o usuário tenha quantidades específicas para algum ativo).
      3) Dia de compra, que pode ser um único valor ou um dicionário.
      4) Atualiza Preço de Compra, Preço de Ajuste Atual, Variação e Rendimento.
    """
    
    nome_arquivo_portifolio = 'portifolio_posições.csv'
    
    # 1) Carrega portfólio existente (se existir)
    if os.path.exists(nome_arquivo_portifolio):
        df_portifolio = pd.read_csv(nome_arquivo_portifolio, index_col=0)
    else:
        # Podemos criar um DataFrame com colunas definidas para evitar problemas de colunas inexistentes
        df_portifolio = pd.DataFrame(columns=[
            'Quantidade', 
            'Dia de Compra', 
            'Preço de Compra', 
            'Preço de Ajuste Atual', 
            'Variação de Taxa', 
            'Rendimento'
        ])
    
    # 2) Remover do DataFrame os ativos que NÃO estão na nova lista de assets
    #    (significa que o usuário removeu aquele ativo do portfólio)
    ativos_existentes = df_portifolio.index.tolist()
    for ativo_em_port in ativos_existentes:
        if ativo_em_port not in assets:
            df_portifolio.drop(index=ativo_em_port, inplace=True)
    # 3) Adicionar ou atualizar as quantidades dos ativos que estão na nova lista
    #    Se há compra_especifica, ela sobrescreve a quantidade
    #    Também atualizamos o 'Dia de Compra' se fornecido
    for asset in assets:
        

        qtd_final = quantidades.get(asset, 0)
        
        # Verifica se o dia_compra é dict ou valor único
        if isinstance(dia_compra, dict):
            dia_de_compra_atual = dia_compra.get(asset, None)
        else:
            # Se dia_compra for apenas uma string (valor único)
            dia_de_compra_atual = dia_compra
        if asset not in df_portifolio.index:
            # Se não existe, cria linha nova
            df_portifolio.loc[asset, 'Quantidade'] = qtd_final
            df_portifolio.loc[asset, 'Dia de Compra'] = dia_de_compra_atual
        else:
            # Se já existe, apenas atualiza
            df_portifolio.loc[asset, 'Quantidade'] = qtd_final
            # Se dia_compra foi passado como dict e existe valor pra esse ativo, atualiza

            if dia_de_compra_atual is not None:
                df_portifolio.loc[asset, 'Dia de Compra'] = dia_de_compra_atual

    # 4) Para cada ativo no DataFrame final, calculamos
    #    - Preço de Compra (com base em df_b3_fechamento na data de compra)
    #    - Preço de Ajuste Atual (com base em df_b3_fechamento na data de hoje)
    #    - Variação de Taxa (com base em df_b3_variacao na data de compra ou acumulada, depende da necessidade)
    #    - Rendimento (Quantidade * (Preço de Ajuste Atual - Preço de Compra)) ou vice-versa
    
    # Monta a string da data de hoje no mesmo formato das colunas do CSV
    # As colunas do CSV podem estar em formato "dd/mm/yyyy" ou "yyyy-mm-dd", dependendo de como foi salvo
    # Ajuste conforme a forma em que foram salvas:

    ############################## ---- PROBLEMA ---- ##############################
    #  
    data_hoje_str = datetime.date.today().strftime('%Y-%m-%d')

    for asset in df_portifolio.index:
        try:
            # Dia de compra que foi salvo
            dia_compra_ativo = df_portifolio.loc[asset, 'Dia de Compra']
            # (Opcional) se for "yyyy-mm-dd", converter para "dd/mm/yyyy" para casar com o CSV
            # Caso já esteja no formato correto, você pode pular esta conversão.
            # Exemplo (caso precise):
            # dia_compra_dt = datetime.datetime.strptime(dia_compra_ativo, '%Y-%m-%d')
            # dia_compra_ativo = dia_compra_dt.strftime('%d/%m/%Y')

            # PREÇO DE COMPRA
            # Localiza a linha do ativo e depois pega o valor na coluna da data de compra
            filtro_ativo = (df_b3_fechamento['Assets'] == asset)

            # Se o usuário informou um valor de compra_especifica para este ativo, sobrescreve
            if compra_especifica and (asset in compra_especifica):
                preco_compra = compra_especifica[asset]
                print(preco_compra)
            else:
                preco_compra = df_b3_fechamento.loc[filtro_ativo, dia_compra_ativo].values[0]
                print(preco_compra)
                print(df_b3_fechamento.loc[filtro_ativo, dia_compra_ativo].values[0])

            df_portifolio.loc[asset, 'Preço de Compra'] = preco_compra

            


            # PREÇO DE AJUSTE ATUAL
            # Usa a data de hoje (coluna de hoje) no df_b3_fechamento
            preco_ajuste_atual = df_b3_fechamento.loc[filtro_ativo, data_hoje_str].values[0]
            df_portifolio.loc[asset, 'Preço de Ajuste Atual'] = preco_ajuste_atual
            
            # VARIAÇÃO DE TAXA
            # Depende se você quer pegar a variação apenas do dia_compra_ativo ou a variação acumulada.
            # Abaixo apenas um exemplo de pegar a variação no dia de compra (ou outro critério)
            filtro_variacao = (df_b3_variacao['Assets'] == asset)
            variacao_taxa = df_b3_variacao.loc[filtro_variacao, dia_compra_ativo].values[0]
            df_portifolio.loc[asset, 'Variação de Taxa'] = variacao_taxa
            
            # RENDIMENTO
            # De acordo com seu snippet original, mas usualmente seria (Preço Atual - Preço Compra).
            df_portifolio.loc[asset, 'Rendimento'] = (
                df_portifolio.loc[asset, 'Quantidade'] * 
                (df_portifolio.loc[asset, 'Preço de Ajuste Atual'] - df_portifolio.loc[asset, 'Preço de Compra'])
            )
            
        except Exception as e:
            # Caso alguma coluna não seja encontrada ou dê erro, você pode tratar aqui
            print(f"[*] Erro ao calcular valores para o ativo {asset}: {e}")
    
    # 5) Salva o DataFrame atualizado de volta no CSV
    df_portifolio.to_csv(nome_arquivo_portifolio)
    
    return df_portifolio

df_b3_fechamento, df_b3_variacao = processar_b3_portifolio()
df_portifolio = checkar_portifolio(assets, quantidades, compra_especifica, dia_compra, df_b3_fechamento, df_b3_variacao)
df_portifolio
# Out:
# <>:18: SyntaxWarning: invalid escape sequence '\.'
# <>:19: SyntaxWarning: invalid escape sequence '\.'
# <>:18: SyntaxWarning: invalid escape sequence '\.'
# <>:19: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\emanuel.cabral\AppData\Local\Temp\ipykernel_19080\3055066535.py:18: SyntaxWarning: invalid escape sequence '\.'
#   df_b3_fechamento = df_b3_fechamento.replace('\.', '', regex=True)
# C:\Users\emanuel.cabral\AppData\Local\Temp\ipykernel_19080\3055066535.py:19: SyntaxWarning: invalid escape sequence '\.'
#   df_b3_variacao = df_b3_variacao.replace('\.', '', regex=True)
# C:\Users\emanuel.cabral\AppData\Local\Temp\ipykernel_19080\3055066535.py:18: SyntaxWarning: invalid escape sequence '\.'
#   df_b3_fechamento = df_b3_fechamento.replace('\.', '', regex=True)
# C:\Users\emanuel.cabral\AppData\Local\Temp\ipykernel_19080\3055066535.py:19: SyntaxWarning: invalid escape sequence '\.'
#   df_b3_variacao = df_b3_variacao.replace('\.', '', regex=True)
#       Assets 2025-01-17
# 0      DAP25   98711.42
# 1      DAP26   88827.83
# 2      DAP27   84345.68
# 3      DAP28   76566.03
# 4      DAP29   72600.59
# 5      DAP30   66220.66
# 6      DAP32   57058.48
# 7      DAP33   54408.02
# 8      DAP35   47170.64
# 9      DAP40   33203.46
# 10     DAP45   23449.18
# 11     DAP50   16156.86
# 12     DAP55   11593.78
# 13     DAP60    7955.57
# 14     DI_26   87508.82
# 15     DI_27   75941.34
# 16     DI_28   66059.28
# 17     DI_29   57656.34
# 18     DI_30   50287.21
# 19     DI_31   43811.31
# 20     DI_32   38199.22
# 21     DI_33   33425.87
# 22     DI_34   29350.19
# 23     DI_35   25734.23
# 24     DI_36   22648.41
# 25     DI_37   19940.72
# 26     DI_38   17601.41
# 27     DI_39   15197.44
# 28     DI_40   13274.70
# 29      WDO1  6081.5680
# 30  TREASURY   108.6093
# Assets        object
# 2025-01-17    object
# dtype: object
# Assets        object
# 2025-01-17    object
# dtype: object
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 192
#     189     return df_portifolio
#     191 df_b3_fechamento, df_b3_variacao = processar_b3_portifolio()
# --> 192 df_portifolio = checkar_portifolio(assets, quantidades, compra_especifica, dia_compra, df_b3_fechamento, df_b3_variacao)
#     193 df_portifolio
#
# Cell In[38], line 101, in checkar_portifolio(assets, quantidades, compra_especifica, dia_compra, df_b3_fechamento, df_b3_variacao)
#      95 # 3) Adicionar ou atualizar as quantidades dos ativos que estão na nova lista
#      96 #    Se há compra_especifica, ela sobrescreve a quantidade
#      97 #    Também atualizamos o 'Dia de Compra' se fornecido
#      98 for asset, qtd_user in zip(assets, quantidades):
# --> 101     qtd_final = qtd_user[asset]
#     103     # Verifica se o dia_compra é dict ou valor único
#     104     if isinstance(dia_compra, dict):
#
# TypeError: string indices must be integers, not 'list'

# %%
 # Converter para DataFrame
    columns = ['Mercadoria', 'Vencimento', 'Preço de ajuste anterior',
               'Preço de ajuste Atual', 'Variação', 'Valor do ajuste por contrato (R$)']
    df = pd.DataFrame(processed_data, columns=columns)

    #preciso criar um novo nome para mercadoria, vai ser as 3 primeiras letras do nome da mercadoria + as duas ultimas do vencimento
    df['Mercadoria'] = df['Mercadoria'].str[:3] + '_' + df['Vencimento'].str[-2:]

    #Tirar o 1 do nome da DI1
    df.loc[df['Mercadoria'].str.startswith('DI1'), 'Mercadoria'] = 'DI' + '_' + df['Vencimento'].str[-2:]
    #Preciso mudar o nome da mercadoria dol e t10
    df.loc[df['Mercadoria'].str.startswith('DOL_') , 'Mercadoria'] = 'WDO1'
    df.loc[df['Mercadoria'].str.startswith('T10_'), 'Mercadoria'] = 'TREASURY'
    df.drop('Vencimento', axis=1, inplace=True)
    df_preco_fechamento = df.copy()
    df_preco_fechamento.drop(['Preço de ajuste anterior', 'Variação', 'Valor do ajuste por contrato (R$)'], axis=1, inplace=True)
    df_preco_fechamento.rename(columns={'Mercadoria': 'Ativo', 'Preço de ajuste Atual': 'Preço de Fechamento'+ datetime.today()}, inplace=True)
