# %%
import pandas as pd

# %%
file_pl = "Dados/pl_fundos_teste.parquet"
df_pl = pd.read_parquet(file_pl)
df_pl
# Out:
#      Fundos/Carteiras Adm 2025-01-01         2025-01-02         2025-01-03  \
# 0     AF DEB INCENTIVADAS         --   R$ 12.864.022,41   R$ 11.725.635,32
# 1   AF INVEST GERAES PREV         --                 --    R$ 4.425.384,80
# 2               AF TÁTICO         --                 --   R$ 44.409.219,12
# 3        ALFA HORIZON FIA         --   R$ 11.225.821,02   R$ 10.744.593,60
# 4             AYA NMK FIM         --                 --                 --
# 5     BBRASIL FIM CP RESP         --  R$ 127.865.817,65   R$ 98.097.976,50
# 6                  BH FIM         --                 --                 --
# 7           BH FIRF INFRA         --  R$ 208.307.983,83  R$ 117.906.205,46
# 8                 BMG SEG         --  R$ 125.891.320,48  R$ 115.821.667,94
# 9            BORDEAUX FIM         --    R$ 1.804.744,99    R$ 1.659.108,46
# 10         BORDEAUX INFRA         --   R$ 50.717.917,43   R$ 45.484.436,95
# ...

# %%
{
 'FIRF GERAES': 487653973.0,
 'FIRF GERAES 30': 334283724.0,
 'BORDEAUX FIM': 1803463.0,
 'GLOBAL BONDS': 30863794.0,
 'AF TÁTICO': 50245681.0,
 'ROMEU FC FIM CP IE': 233654393.0,
 'HORIZONTE': 331380996.0,
 'JERA2026': 208959123.0,
 'REAL FIM': 39865977.0,
 'AF INVEST GERAES PREV': 792822.0,
 'BBRASIL FIM CP RESP': 127865818.0,
 'BMG SEG': 125891320.0,
 'BH FIRF INFRA': 208056498.0,
 'BORDEAUX INFRA': 50717917.0,
 'TOPAZIO INFRA': 35885760.0,
 'MANACA INFRA FIRF': 44659017.0,
 'RIO INFRA': None,
 'FIA MINAS': 39168398.0,
 'ALFA HORIZON FIA': 11225821.0,
 'MINAS O.N.E. FIA': 3503855.0,
 'MINAS DIVIDENDOS': 662969.0,
 'AF DEB INCENTIVADAS': 12864022.0,
 'CDI': None,
 'IBOV': None,
 'IMA-B': None
}
# Atualizar os valores da coluna PL corretamente
df_pl.loc[df_pl['Fundos/Carteiras Adm'] == 'FIRF GERAES', 'PL'] = 'R$ 487.653.973'
df_pl.loc[df_pl['Fundos/Carteiras Adm'] == 'FIRF GERAES 30', 'PL'] = 'R$ 334.283.724'
df_pl.loc[df_pl['Fundos/Carteiras Adm'] == 'BORDEAUX FIM', 'PL'] = 'R$ 1.803.463'
df_pl.loc[df_pl['Fundos/Carteiras Adm'] == 'GLOBAL BONDS', 'PL'] = 'R$ 30.863.794'
df_pl.loc[df_pl['Fundos/Carteiras Adm'] == 'AF TÁTICO', 'PL'] = 'R$ 50.245.681'
df_pl.loc[df_pl['Fundos/Carteiras Adm'] == 'ROMEU FC FIM CP IE', 'PL'] = 'R$ 233.654.393'
df_pl.loc[df_pl['Fundos/Carteiras Adm'] == 'HORIZONTE', 'PL'] = 'R$ 331.380.996'
df_pl.loc[df_pl['Fundos/Carteiras Adm'] == 'JERA2026', 'PL'] = 'R$ 208.959.123'
df_pl.loc[df_pl['Fundos/Carteiras Adm'] == 'REAL FIM', 'PL'] = 'R$ 39.865.977'
df_pl.loc[df_pl['Fundos/Carteiras Adm'] == 'AF INVEST GERAES PREV', 'PL'] = 'R$ 792.822'
df_pl.loc[df_pl['Fundos/Carteiras Adm'] == 'BBRASIL FIM CP RESP', 'PL'] = 'R$ 127.865.818'
df_pl.loc[df_pl['Fundos/Carteiras Adm'] == 'BMG SEG', 'PL'] = 'R$ 125.891.320'
df_pl.loc[df_pl['Fundos/Carteiras Adm'] == 'BH FIRF INFRA', 'PL'] = 'R$ 208.056.498'
df_pl.loc[df_pl['Fundos/Carteiras Adm'] == 'BORDEAUX INFRA', 'PL'] = 'R$ 50.717.917'
df_pl.loc[df_pl['Fundos/Carteiras Adm'] == 'TOPAZIO INFRA', 'PL'] = 'R$ 35.885.760'
df_pl.loc[df_pl['Fundos/Carteiras Adm'] == 'MANACA INFRA FIRF', 'PL'] = 'R$ 44.659.017'
df_pl.loc[df_pl['Fundos/Carteiras Adm'] == 'RIO INFRA', 'PL'] = 'R$ 0'
df_pl.loc[df_pl['Fundos/Carteiras Adm'] == 'FIA MINAS', 'PL'] = 'R$ 39.168.398'
df_pl.loc[df_pl['Fundos/Carteiras Adm'] == 'ALFA HORIZON FIA', 'PL'] = 'R$ 11.225.821'
df_pl.loc[df_pl['Fundos/Carteiras Adm'] == 'MINAS O.N.E. FIA', 'PL'] = 'R$ 3.503.855'
df_pl.loc[df_pl['Fundos/Carteiras Adm'] == 'MINAS DIVIDENDOS', 'PL'] = 'R$ 662.969'
df_pl.loc[df_pl['Fundos/Carteiras Adm'] == 'AF DEB INCENTIVADAS', 'PL'] = 'R$ 12.864.022'
df_pl.loc[df_pl['Fundos/Carteiras Adm'] == 'IMA-B', 'PL'] = '--'

df_pl.to_parquet('Dados/pl_fundos.parquet')

# %%
df = pd.read_parquet('Dados/df_inicial.parquet')
df
# Out:
#            Date     DI_26     DI_27     DI_28     DI_29     DI_30     DI_31  \
# 1    2020-07-26       NaN       NaN       NaN       NaN       NaN       NaN
# 2    2020-07-27  73516.07  67764.62  62578.62  57676.81  53298.49  49171.88
# 3    2020-07-28  73476.20  67740.11  62529.16  57601.30  53219.32  49090.04
# 4    2020-07-29  73398.92  67674.89  62479.81  57571.15  53186.93  49055.88
# 5    2020-07-30  74094.32  68429.18  63237.58  58313.93  53952.19  49835.50
# ...         ...       ...       ...       ...       ...       ...       ...
# 1797 2025-06-26  92917.73  81791.20  72860.17  64590.60  56894.96  49943.58
# 1798 2025-06-27  92969.91  81829.91  72901.46  64622.65  56948.10  50012.13
# 1799 2025-06-28       NaN       NaN       NaN       NaN       NaN       NaN
# 1800 2025-06-29       NaN       NaN       NaN       NaN       NaN       NaN
# 1801 2025-06-30  93022.53  81971.49  73228.55  65150.72  57599.17  50750.68
#
# ...

# %%
dados = pd.read_parquet('Dados/df_valor_ajuste_contrato.parquet')
#Dropar 2025-05-02
dados
# Out:
#       Assets  2025-01-02 2025-01-03 2025-01-06 2025-01-07 2025-01-08  \
# 0      DAP25      100,19     175,57      19,91      36,78     -61,50
# 1      DAP26      435,81     276,05     299,17      -6,91     110,39
# 2      DAP27      711,74     340,01     469,84     -16,50      48,31
# 3      DAP28      569,66     240,30     510,95    -120,18      60,26
# 4      DAP29    1.002,80      65,74     374,91    -449,25     219,93
# 5      DAP30      813,89      12,54     378,22    -414,13    -108,90
# 6      DAP32      805,99    -560,23     653,54    -560,76    -131,38
# 7      DAP33    1.204,93    -435,82     754,87    -214,07      10,07
# 8      DAP35      497,29    -231,73     490,26    -553,03     329,17
# 9      DAP40    1.090,33      14,17     505,74    -477,63     653,75
# 10     DAP45      322,49      11,97     345,07     155,70    -298,81
# 11     DAP50      186,04      90,15     368,67     249,53    -257,64
# 12     DAP55      218,75      87,46     260,69     322,95    -272,68
# ...

# %%
dados2 = dados.iloc[[12,13,25]]
dados2.to_csv('Dados/df_fundos_teste.csv', index=False, sep=';')

# %%
dados3 = pd.read_parquet('Dados/pl_fundos_teste.parquet')
dados3
# Out:
#      Fundos/Carteiras Adm 2025-01-01         2025-01-02         2025-01-03  \
# 0     AF DEB INCENTIVADAS         --   R$ 12.864.022,41   R$ 11.725.635,32
# 1   AF INVEST GERAES PREV         --                 --    R$ 4.425.384,80
# 2               AF TÁTICO         --                 --   R$ 44.409.219,12
# 3        ALFA HORIZON FIA         --   R$ 11.225.821,02   R$ 10.744.593,60
# 4             AYA NMK FIM         --                 --                 --
# 5     BBRASIL FIM CP RESP         --  R$ 127.865.817,65   R$ 98.097.976,50
# 6                  BH FIM         --                 --                 --
# 7           BH FIRF INFRA         --  R$ 208.307.983,83  R$ 117.906.205,46
# 8                 BMG SEG         --  R$ 125.891.320,48  R$ 115.821.667,94
# 9            BORDEAUX FIM         --    R$ 1.804.744,99    R$ 1.659.108,46
# 10         BORDEAUX INFRA         --   R$ 50.717.917,43   R$ 45.484.436,95
# ...

# %%
dados3
# Out:
#      Fundos/Carteiras Adm 2025-01-01         2025-01-02         2025-01-03  \
# 0     AF DEB INCENTIVADAS         --   R$ 11.703.717,60   R$ 11.725.635,32
# 1   AF INVEST GERAES PREV         --    R$ 4.423.740,40    R$ 4.425.384,80
# 2               AF TÁTICO         --   R$ 44.412.138,51   R$ 44.409.219,12
# 3        ALFA HORIZON FIA         --   R$ 10.881.126,26   R$ 10.744.593,60
# 4             AYA NMK FIM         --    R$ 1.486.446,82    R$ 1.487.215,66
# 5     BBRASIL FIM CP RESP         --   R$ 98.044.971,94   R$ 98.097.976,50
# 6                  BH FIM         --      R$ 503.659,05      R$ 502.433,38
# 7           BH FIRF INFRA         --  R$ 117.842.340,86  R$ 117.906.205,46
# 8                 BMG SEG         --  R$ 115.757.838,53  R$ 115.821.667,94
# 9            BORDEAUX FIM         --    R$ 1.658.989,06    R$ 1.659.108,46
# 10         BORDEAUX INFRA         --   R$ 45.464.008,80   R$ 45.484.436,95
# ...

# %%
0, 7, 10, 14, 15, 16, 17, 20, 25         

dict_pesos = {
            'GLOBAL BONDS': 4,
            'HORIZONTE': 1,
            'JERA2026': 1,
            'REAL FIM': 1,
            'BH FIRF INFRA': 1,
            'BORDEAUX INFRA': 1,
            'TOPAZIO INFRA': 1,
            'MANACA INFRA FIRF': 1,
            'AF DEB INCENTIVADAS': 3
        }

# %%
dados = pd.read_parquet('Dados/df_preco_de_ajuste_atual.parquet')
#Dropar 2025-05-02 coluna
dados
# Out:
#       Assets  2025-01-02  2025-01-03  2025-01-06  2025-01-07  2025-01-08  \
# 0      DAP25   98.420,08   98.537,44   98.566,96   98.606,00   98.589,62
# 1      DAP26   88.536,62   88.708,86   88.894,14   88.906,74   88.985,51
# 2      DAP27   83.678,70   83.886,14   84.166,83   84.173,14   84.216,02
# 3      DAP28   75.982,66   76.132,39   76.434,84   76.381,23   76.429,40
# 4      DAP29   72.298,68   72.349,20   72.574,18   72.334,21   72.471,68
# 5      DAP30   66.333,67   66.353,05   66.578,79   66.357,52   66.308,42
# 6      DAP32   57.412,89   57.107,32   57.486,70   57.181,02   57.117,54
# 7      DAP33   54.417,48   54.181,57   54.617,59   54.506,96   54.522,76
# 8      DAP35   47.304,65   47.182,63   47.468,03   47.164,85   47.359,26
# 9      DAP40   33.461,41   33.475,62   33.767,22   33.504,04   33.878,97
# 10     DAP45   23.630,53   23.641,67   23.840,78   23.933,04   23.768,95
# 11     DAP50   15.974,11   16.027,96   16.238,97   16.382,75   16.240,48
# ...

# %%
dados2 = pd.read_parquet('Dados/df_valor_ajuste_contrato.parquet')
dados2
# Out:
#       Assets  2025-01-02 2025-01-03 2025-01-06 2025-01-07 2025-01-08  \
# 0      DAP25      100,19     175,57      19,91      36,78     -61,50
# 1      DAP26      435,81     276,05     299,17      -6,91     110,39
# 2      DAP27      711,74     340,01     469,84     -16,50      48,31
# 3      DAP28      569,66     240,30     510,95    -120,18      60,26
# 4      DAP29    1.002,80      65,74     374,91    -449,25     219,93
# 5      DAP30      813,89      12,54     378,22    -414,13    -108,90
# 6      DAP32      805,99    -560,23     653,54    -560,76    -131,38
# 7      DAP33    1.204,93    -435,82     754,87    -214,07      10,07
# 8      DAP35      497,29    -231,73     490,26    -553,03     329,17
# 9      DAP40    1.090,33      14,17     505,74    -477,63     653,75
# 10     DAP45      322,49      11,97     345,07     155,70    -298,81
# 11     DAP50      186,04      90,15     368,67     249,53    -257,64
# 12     DAP55      218,75      87,46     260,69     322,95    -272,68
# ...

# %%
dados_2 = pd.read_parquet('Dados/df_valor_ajuste_contrato.parquet')
dados_2
# Out:
#       Assets  2025-01-02 2025-01-03 2025-01-06 2025-01-07 2025-01-08  \
# 0      DAP25      100,19     175,57      19,91      36,78     -61,50
# 1      DAP26      435,81     276,05     299,17      -6,91     110,39
# 2      DAP27      711,74     340,01     469,84     -16,50      48,31
# 3      DAP28      569,66     240,30     510,95    -120,18      60,26
# 4      DAP29    1.002,80      65,74     374,91    -449,25     219,93
# 5      DAP30      813,89      12,54     378,22    -414,13    -108,90
# 6      DAP32      805,99    -560,23     653,54    -560,76    -131,38
# 7      DAP33    1.204,93    -435,82     754,87    -214,07      10,07
# 8      DAP35      497,29    -231,73     490,26    -553,03     329,17
# 9      DAP40    1.090,33      14,17     505,74    -477,63     653,75
# 10     DAP45      322,49      11,97     345,07     155,70    -298,81
# 11     DAP50      186,04      90,15     368,67     249,53    -257,64
# 12     DAP55      218,75      87,46     260,69     322,95    -272,68
# ...

# %%
dados =pd.read_parquet('Dados/df_valor_ajuste_contrato.parquet')
#Exportar para Excel
dados.to_excel('Dap.xlsx', index=False, engine='openpyxl')
