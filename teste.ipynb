# %%
import pandas as pd
import os
import numpy as np
import pandas_market_calendars as mcal
#Biblioteca para pegar o dia de hoje
from datetime import date
from datetime import datetime
from supabase import create_client
import psycopg2
from psycopg2 import sql
import supabase

# %%
import pandas as pd
teste = pd.read_parquet("df_valor_ajuste_contrato.parquet")
#Dropar ultima coluna
teste
# Out:
#       Assets  2025-01-02 2025-01-03 2025-01-06 2025-01-07 2025-01-08  \
# 0      DAP25      100,19     175,57      19,91      36,78     -61,50
# 1      DAP26      435,81     276,05     299,17      -6,91     110,39
# 2      DAP27      711,74     340,01     469,84     -16,50      48,31
# 3      DAP28      569,66     240,30     510,95    -120,18      60,26
# 4      DAP29    1.002,80      65,74     374,91    -449,25     219,93
# 5      DAP30      813,89      12,54     378,22    -414,13    -108,90
# 6      DAP32      805,99    -560,23     653,54    -560,76    -131,38
# 7      DAP33    1.204,93    -435,82     754,87    -214,07      10,07
# 8      DAP35      497,29    -231,73     490,26    -553,03     329,17
# 9      DAP40    1.090,33      14,17     505,74    -477,63     653,75
# 10     DAP45      322,49      11,97     345,07     155,70    -298,81
# 11     DAP50      186,04      90,15     368,67     249,53    -257,64
# 12     DAP55      218,75      87,46     260,69     322,95    -272,68
# 13     DAP60      202,76     102,56     229,54     295,68    -283,65
# 14     DI_25        0,03       None       None       None       None
# 15     DI_26      194,27      98,69      67,43     -16,04      40,08
# 16     DI_27      314,47     277,03     175,33     -61,22      34,36
# 17     DI_28      366,28     376,58     321,12     -99,21     -51,67
# 18     DI_29      405,22     436,27     426,01    -147,42    -146,71
# 19     DI_30      404,44     485,19     479,59    -165,19    -247,71
# 20     DI_31      428,83     464,42     538,14    -232,02    -270,82
# 21     DI_32      436,46     444,72     543,77    -227,09    -322,07
# 22     DI_33      417,65     493,79     527,74    -243,10    -347,28
# 23     DI_34      405,71     498,30     528,70    -256,19    -347,62
# 24     DI_35      379,47     506,22     542,40    -269,64    -362,84
# 25     DI_36      366,29     489,97     526,10    -262,06    -352,14
# 26     DI_37      351,36     471,26     507,10    -253,05    -339,56
# 27     DI_38      335,17     450,64     485,93    -242,86    -325,44
# 28     DI_39      127,08     418,71     452,42    -226,28    -302,87
# 29     DI_40  -74.212,05     391,88     424,30    -212,44    -283,97
# 30  TREASURY     -969,78  -1.058,26    -668,64  -2.183,03    -191,32
# 31      WDO1        0,00     995,65  -3.499,65    -605,50     771,70
#
#    2025-01-09 2025-01-10 2025-01-13 2025-01-14  ... 2025-04-08 2025-04-09  \
# 0       -3,60     -72,34     122,34      37,40  ...     -15,15       2,08
# 1     -287,45    -172,47      39,15     -30,41  ...     -16,04    -303,01
# 2     -113,33    -234,70      14,99     143,49  ...     -21,95    -493,15
# 3      -29,81    -232,39    -165,16     193,45  ...    -190,30    -535,32
# 4      -88,58    -315,12    -242,28     371,29  ...    -348,88    -372,31
# 5      -48,02    -370,43    -410,24     373,54  ...    -509,37    -356,60
# 6       82,08    -502,90    -342,90     434,11  ...    -823,65    -282,59
# 7      234,19    -454,08    -287,91     306,46  ...    -901,03    -259,03
# 8        8,65    -166,05    -312,06     327,88  ...    -732,41    -322,05
# 9     -124,78    -857,20    -352,78      90,11  ...    -560,18    -256,01
# 10     -11,81    -539,54    -425,02     299,56  ...    -479,82    -221,52
# 11      64,29    -301,51    -340,55     332,28  ...    -421,99    -120,11
# 12     -15,41    -249,53    -226,22     229,96  ...    -306,48     -11,81
# 13     -40,88    -247,49    -181,90     170,66  ...    -210,11      -4,74
# 14       None       None       None       None  ...       None       None
# 15      41,36     -86,27     100,41      40,93  ...     -46,03     -32,78
# 16     156,73    -167,93     194,87     113,75  ...    -142,64    -191,74
# 17     256,90    -312,83     182,15     200,99  ...    -235,27    -269,99
# 18     288,54    -440,05     129,11     262,45  ...    -297,62    -226,51
# 19     260,10    -522,05      66,97     314,33  ...    -323,24    -220,97
# 20     207,09    -569,34       6,83     350,82  ...    -326,41    -182,26
# 21     155,72    -570,81     -50,50     354,62  ...    -305,11    -183,73
# 22     120,97    -579,25     -51,11     363,59  ...    -302,82    -132,45
# 23      89,71    -576,54     -71,23     345,58  ...    -231,59    -149,24
# 24      60,44    -562,54     -82,79     351,76  ...    -251,73    -146,88
# 25      58,32    -544,98     -80,35     340,11  ...    -242,58    -141,46
# 26      55,95    -524,57     -77,44     326,76  ...    -230,45    -134,29
# 27      53,39    -501,91     -74,15     312,14  ...    -220,83    -128,62
# 28      49,62    -466,36     -68,85     289,76  ...    -209,48    -121,94
# 29      46,41    -436,57     -64,44     270,92  ...    -197,14    -114,69
# 30     475,59  -5.048,51    -954,66     758,38  ...  -3.525,27  -6.912,60
# 31  -3.336,45   2.195,20    -637,85  -2.002,25  ...   3.393,75  -6.217,30
#
#    2025-04-10 2025-04-11 2025-04-14 2025-04-15 2025-04-16 2025-04-17  \
# 0      -41,82     139,29      22,69     -66,07      51,23      29,84
# 1     -182,25     236,36     143,13      -4,36     202,98     280,75
# 2     -269,85     257,15     273,00      52,98     220,85     235,25
# 3     -338,44     363,27     373,23      27,89     301,69     258,57
# 4     -495,29     567,30     381,74     -20,06     325,27     224,77
# 5     -593,65     553,02     574,96     -86,02     329,33     178,89
# 6     -671,81     652,51     647,61    -104,13     105,76      -1,92
# 7     -814,94     643,62     789,60    -184,68     185,92    -152,32
# 8     -882,72     693,58     610,58    -322,18     323,15    -205,06
# 9     -662,38     971,23     738,10    -778,47     257,32    -320,72
# 10    -432,63     997,55     323,99    -402,37     -57,25     -33,14
# 11    -302,51     285,23     725,21    -389,14    -151,13      41,96
# 12    -163,52     678,36      94,29    -354,42    -227,98      -0,65
# 13    -153,17     487,23      97,31    -274,03    -225,37     -15,31
# 14       None       None       None       None       None       None
# 15      23,37      18,01      41,24     -24,43       2,96      -6,61
# 16     -13,34     168,62     226,97    -103,56      66,84     -14,11
# 17     -55,66     286,31     368,84    -150,12      94,42      92,70
# 18     -95,74     347,05     444,55    -198,99      49,57     174,77
# 19    -146,28     414,88     488,74    -199,74      24,35     208,85
# 20    -224,37     461,64     513,17    -192,10      25,84     248,63
# 21    -263,61     524,67     522,76    -146,92       2,78     242,98
# 22    -314,53     557,00     535,84    -137,93      19,42     232,06
# 23    -341,95     583,40     539,02    -124,79      30,93     225,10
# 24    -317,90     628,44     529,45    -112,48      16,34     237,98
# 25    -305,86     604,85     510,72    -108,62      15,75     229,82
# 26    -266,06     578,89     486,55    -103,56      17,12     242,77
# 27    -254,56     553,94     466,63     -99,49      16,36     233,08
# 28    -241,07     524,81     443,11     -94,61      15,52     221,58
# 29    -226,51     493,35     417,50     -89,23      14,60     209,03
# 30   1.570,09  -5.047,85   5.934,22   1.926,17   2.021,23  -1.463,97
# 31   1.534,55  -1.005,30  -1.167,00   1.934,00  -1.794,45  -2.873,20
#
#    2025-04-22 2025-04-23
# 0        3,19       3,19
# 1       54,64      54,64
# 2      -58,41     -58,41
# 3     -282,91    -282,91
# 4     -430,20    -430,20
# 5     -604,65    -604,65
# 6     -752,66    -752,66
# 7     -712,48    -712,48
# 8   -1.050,26  -1.050,26
# 9     -880,80    -880,80
# 10    -897,33    -897,33
# 11    -651,49    -651,49
# 12    -597,51    -597,51
# 13    -435,23    -435,23
# 14       None       None
# 15      11,36      11,36
# 16      22,68      22,68
# 17     -23,76     -23,76
# 18     -73,81     -73,81
# 19    -125,19    -125,19
# 20    -166,98    -166,98
# 21    -213,83    -213,83
# 22    -229,05    -229,05
# 23    -264,67    -264,67
# 24    -290,35    -290,35
# 25    -287,07    -287,07
# 26    -261,50    -261,50
# 27    -251,20    -251,20
# 28    -238,88    -238,88
# 29    -225,37    -225,37
# 30  -2.156,10  -2.156,10
# 31  -4.140,65  -4.140,65
#
# [32 rows x 77 columns]

# %%
teste = pd.read_parquet("df_preco_de_ajuste_atual.parquet")
teste
# Out:
#       Assets  2025-01-02  2025-01-03  2025-01-06  2025-01-07  2025-01-08  \
# 0      DAP25   98.420,08   98.537,44   98.566,96   98.606,00   98.589,62
# 1      DAP26   88.536,62   88.708,86   88.894,14   88.906,74   88.985,51
# 2      DAP27   83.678,70   83.886,14   84.166,83   84.173,14   84.216,02
# 3      DAP28   75.982,66   76.132,39   76.434,84   76.381,23   76.429,40
# 4      DAP29   72.298,68   72.349,20   72.574,18   72.334,21   72.471,68
# 5      DAP30   66.333,67   66.353,05   66.578,79   66.357,52   66.308,42
# 6      DAP32   57.412,89   57.107,32   57.486,70   57.181,02   57.117,54
# 7      DAP33   54.417,48   54.181,57   54.617,59   54.506,96   54.522,76
# 8      DAP35   47.304,65   47.182,63   47.468,03   47.164,85   47.359,26
# 9      DAP40   33.461,41   33.475,62   33.767,22   33.504,04   33.878,97
# 10     DAP45   23.630,53   23.641,67   23.840,78   23.933,04   23.768,95
# 11     DAP50   15.974,11   16.027,96   16.238,97   16.382,75   16.240,48
# 12     DAP55   11.422,13   11.473,62   11.622,86   11.807,21   11.655,61
# 13     DAP60    7.847,20    7.906,55    8.037,55    8.205,85    8.047,39
# 14     DI_26   86.812,34   86.950,54   87.057,54   87.081,12   87.160,83
# 15     DI_27   74.824,27   75.135,35   75.344,87   75.317,94   75.386,58
# 16     DI_28   64.753,44   65.159,49   65.510,26   65.440,86   65.418,97
# 17     DI_29   56.356,33   56.818,25   57.270,12   57.148,76   57.028,06
# 3    77.955,62   77.823,70   77.823,70
# 4    74.218,21   74.003,87   74.003,87
# 5    67.880,14   67.567,58   67.567,58
# 6    58.525,19   58.128,07   58.128,07
# 7    55.541,57   55.165,70   55.165,70
# 8    48.154,27   47.589,75   47.589,75
# 9    33.460,67   32.985,08   32.985,08
# 10   23.825,12   23.337,43   23.337,43
# 11   16.823,44   16.469,22   16.469,22
# 12   12.112,42   11.786,51   11.786,51
# 13    8.360,26    8.122,72    8.122,72
# 14   90.693,91   90.752,91   90.752,91
# 15   79.797,28   79.861,88   79.861,88
# 16   70.347,39   70.360,58   70.360,58
# 17   61.699,14   61.657,74   61.657,74
# 18   53.855,34   53.758,44   53.758,44
# 19   46.935,56   46.793,24   46.793,24
# 20   40.927,20   40.734,87   40.734,87
# 21   35.758,32   35.548,05   35.548,05
# 22   31.355,04   31.106,84   31.106,84
# 23   27.482,02   27.206,11   27.206,11
# 24   24.087,63   23.813,21   23.813,21
# 25   21.033,09   20.782,64   20.782,64
# 26   18.613,78   18.372,36   18.372,36
# 27   16.405,28   16.175,02   16.175,02
# 28   14.425,97   14.208,18   14.208,18
# 29    111,1718    110,7968    110,7968
# 30  5.812,3060  5.729,4930  5.729,4930
#
# [31 rows x 77 columns]

# %%
teste = pd.read_parquet("portifolio_posições.parquet")
teste

#Fazer um Groupby por Ativo e Rendimento
teste.groupby(['Ativo'])['Rendimento'].sum().reset_index()
# Out:
#    Ativo  Rendimento
# 0  DAP35   -10669.88
# 1  DI_27     6673.20
# 2   WDO1    -4550.01

# %%
teste = pd.read_parquet("df_preco_de_ajuste_atual.parquet")
teste
# Out:
#       Assets  2025-01-02  2025-01-03  2025-01-06  2025-01-07  2025-01-08  \
# 0      DAP25   98.420,08   98.537,44   98.566,96   98.606,00   98.589,62
# 1      DAP26   88.536,62   88.708,86   88.894,14   88.906,74   88.985,51
# 2      DAP27   83.678,70   83.886,14   84.166,83   84.173,14   84.216,02
# 3      DAP28   75.982,66   76.132,39   76.434,84   76.381,23   76.429,40
# 4      DAP29   72.298,68   72.349,20   72.574,18   72.334,21   72.471,68
# 5      DAP30   66.333,67   66.353,05   66.578,79   66.357,52   66.308,42
# 6      DAP32   57.412,89   57.107,32   57.486,70   57.181,02   57.117,54
# 7      DAP33   54.417,48   54.181,57   54.617,59   54.506,96   54.522,76
# 8      DAP35   47.304,65   47.182,63   47.468,03   47.164,85   47.359,26
# 9      DAP40   33.461,41   33.475,62   33.767,22   33.504,04   33.878,97
# 10     DAP45   23.630,53   23.641,67   23.840,78   23.933,04   23.768,95
# 11     DAP50   15.974,11   16.027,96   16.238,97   16.382,75   16.240,48
# 12     DAP55   11.422,13   11.473,62   11.622,86   11.807,21   11.655,61
# 13     DAP60    7.847,20    7.906,55    8.037,55    8.205,85    8.047,39
# 14     DI_26   86.812,34   86.950,54   87.057,54   87.081,12   87.160,83
# 15     DI_27   74.824,27   75.135,35   75.344,87   75.317,94   75.386,58
# 16     DI_28   64.753,44   65.159,49   65.510,26   65.440,86   65.418,97
# 17     DI_29   56.356,33   56.818,25   57.270,12   57.148,76   57.028,06
# 4    74.071,21   74.218,21   74.218,21
# 5    67.760,41   67.880,14   67.880,14
# 6    58.508,11   58.525,19   58.525,19
# 7    55.608,39   55.541,57   55.541,57
# 8    48.252,47   48.154,27   48.154,27
# 9    33.627,24   33.460,67   33.460,67
# 10   23.836,02   23.825,12   23.825,12
# 11   16.795,07   16.823,44   16.823,44
# 12   12.109,03   12.112,42   12.112,42
# 13    8.366,12    8.360,26    8.360,26
# 14   90.652,90   90.693,91   90.693,91
# 15   79.769,49   79.797,28   79.797,28
# 16   70.217,80   70.347,39   70.347,39
# 17   61.492,07   61.699,14   61.699,14
# 18   53.618,32   53.855,34   53.855,34
# 19   46.662,42   46.935,56   46.935,56
# 20   40.662,86   40.927,20   40.927,20
# 21   35.507,61   35.758,32   35.758,32
# 22   31.113,60   31.355,04   31.355,04
# 23   27.229,74   27.482,02   27.482,02
# 24   23.845,28   24.087,63   24.087,63
# 25   20.779,40   21.033,09   21.033,09
# 26   18.371,05   18.613,78   18.613,78
# 27   16.175,20   16.405,28   16.405,28
# 28   14.209,48   14.425,97   14.425,97
# 29    111,4218    111,1718    111,1718
# 30  5.869,7700  5.812,3060  5.812,3060
#
# [31 rows x 76 columns]

# %%
dia_operacao = "2025-04-10"
df_current = pd.read_parquet("df_current.parquet")
df_info = pd.read_parquet("df_info.parquet")
df_info
# Out:
#     Ativo  Quantidade Dia de Compra  Preço de Compra  Preço de Ajuste Atual  \
# 0   DAP35          16    2025-03-12         47658.30               47958.70
# 1   DAP35           1    2025-03-18         47848.28               47958.70
# 2    WDO1          15    2025-03-31         57530.50               58797.34
# 3   DAP35           1    2025-04-03         48738.41               47958.70
# 4   DI_27          13    2025-04-03         79336.35               79215.25
# 5    WDO1         -15    2025-04-03         56525.00               58797.34
# 6   DI_27           7    2025-04-04         79336.35               79215.25
# 7    WDO1           6    2025-04-04         57265.00               58797.34
# 10  DAP35          15    2025-04-07         48516.11               47958.70
# 9    WDO1           5    2025-04-07         59100.00               58797.34
# 8   DI_27         -20    2025-04-07         79324.32               79215.25
# 11  DI_27          18    2025-04-09         79276.70               79215.25
# 12  DI_27           1    2025-04-10             0.00               79215.25
# 13  DAP35           6    2025-04-10         45000.00               47958.70
# 14  DI_27           6    2025-04-10         79000.00               79215.25
# 15  DAP35           1    2025-04-10             0.00               47958.70
# 16   WDO1           1    2025-04-10             0.00               58797.34
# 17  DAP35           1    2025-04-10             0.00               47958.70
# 18  DI_27           1    2025-04-10             0.00               79215.25
# 19   WDO1           1    2025-04-10             0.00               58797.34
#
#     Rendimento   Id
# 0      4806.40   98
# 1       110.42   99
# 2     19002.60  106
# 3      -779.71  100
# 4     -1574.30  102
# 5    -34085.10  107
# 6      -847.70  103
# 7      9194.04  108
# 10    -8361.15  101
# 9     -1513.30  109
# 8      2181.40  104
# 11    -1106.10  105
# 12    79215.25  112
# 13    17752.20  110
# 14     1291.50  111
# 15    47958.70  113
# 16    58797.34  114
# 17    47958.70  115
# 18    79215.25  116
# 19    58797.34  117

# %%
# Adicione a seguinte linha "20	DI28	1	2025-04-10	0.0	58797.340000000004	58797.340000000004	118" em df_info
# Cria a nova linha como DataFrame
# Nova linha com as colunas corretas
nova_linha = pd.DataFrame([{
    "Ativo": "DI_28",
    "Quantidade": 1,
    "Dia de Compra": dia_operacao,
    "Preço de Compra": 0.0,
    "Preço de Ajuste Atual": 58797.34,
    "Rendimento": 0.0,  # Você pode ajustar isso se tiver o rendimento
    "Id": 118
}])

# Adiciona ao DataFrame original
df_info = pd.concat([df_info, nova_linha], ignore_index=True)
df_info
# Out:
#     Ativo  Quantidade Dia de Compra  Preço de Compra  Preço de Ajuste Atual  \
# 0   DAP35          16    2025-03-12         47658.30               47958.70
# 1   DAP35           1    2025-03-18         47848.28               47958.70
# 2    WDO1          15    2025-03-31         57530.50               58797.34
# 3   DAP35           1    2025-04-03         48738.41               47958.70
# 4   DI_27          13    2025-04-03         79336.35               79215.25
# 5    WDO1         -15    2025-04-03         56525.00               58797.34
# 6   DI_27           7    2025-04-04         79336.35               79215.25
# 7    WDO1           6    2025-04-04         57265.00               58797.34
# 8   DAP35          15    2025-04-07         48516.11               47958.70
# 9    WDO1           5    2025-04-07         59100.00               58797.34
# 10  DI_27         -20    2025-04-07         79324.32               79215.25
# 11  DI_27          18    2025-04-09         79276.70               79215.25
# 12  DI_27           1    2025-04-10             0.00               79215.25
# 13  DAP35           6    2025-04-10         45000.00               47958.70
# 14  DI_27           6    2025-04-10         79000.00               79215.25
# 15  DAP35           1    2025-04-10             0.00               47958.70
# 16   WDO1           1    2025-04-10             0.00               58797.34
# 17  DAP35           1    2025-04-10             0.00               47958.70
# 18  DI_27           1    2025-04-10             0.00               79215.25
# 19   WDO1           1    2025-04-10             0.00               58797.34
# 20  DI_28           1    2025-04-10             0.00               58797.34
#
#     Rendimento   Id
# 0      4806.40   98
# 1       110.42   99
# 2     19002.60  106
# 3      -779.71  100
# 4     -1574.30  102
# 5    -34085.10  107
# 6      -847.70  103
# 7      9194.04  108
# 8     -8361.15  101
# 9     -1513.30  109
# 10     2181.40  104
# 11    -1106.10  105
# 12    79215.25  112
# 13    17752.20  110
# 14     1291.50  111
# 15    47958.70  113
# 16    58797.34  114
# 17    47958.70  115
# 18    79215.25  116
# 19    58797.34  117
# 20        0.00  118

# %%
def atualizar_parquet_fundos(
    df_current,         # DataFrame do dia atual (1 linha por Fundo)
    dia_operacao,       # Exemplo: "2025-01-20"
    # DF de transações: [Ativo, Quantidade, Dia de Compra, Preço de Compra, ...]
    df_info,
    # DF de preços de fechamento B3: colunas ["Assets", <data1>, <data2>, ...]
):

    df_fechamento_b3 = pd.read_parquet("df_preco_de_ajuste_atual_completo.parquet")
    df_fechamento_b3 = df_fechamento_b3.replace('\.', '', regex=True)
    df_fechamento_b3 = df_fechamento_b3.replace({',': '.'}, regex=True)
    # Converter para float todas as colunas menos a primeira
    df_fechamento_b3.iloc[:, 2:] = df_fechamento_b3.iloc[:, 2:].astype(float)

    # Multiplicar a linha que tem o Ativo TREASURY por 1000
    # Multiplicar a linha da treasury por 1000
    df_fechamento_b3.loc[df_fechamento_b3['Assets'] == 'TREASURY', df_fechamento_b3.columns !=
                         'Assets'] = df_fechamento_b3.loc[df_fechamento_b3['Assets'] == 'TREASURY', df_fechamento_b3.columns != 'Assets'] * 1000

    df_fechamento_b3.loc[df_fechamento_b3['Assets'] == 'WDO1', df_fechamento_b3.columns !=
                         'Assets'] = df_fechamento_b3.loc[df_fechamento_b3['Assets'] == 'WDO1', df_fechamento_b3.columns != 'Assets'] * 10

    ultimo_fechamento = df_fechamento_b3.columns[-1]
    dolar = df_fechamento_b3.loc[df_fechamento_b3['Assets']
                                 == 'WDO1', ultimo_fechamento].values[0]

    pl_dias = pd.read_parquet("pl_fundos_teste.parquet")
    pl_dias = pl_dias.replace('\.', '', regex=True)
    pl_dias = pl_dias.replace({',': '.'}, regex=True)
    for col in pl_dias.columns:
        pl_dias[col] = pl_dias[col].astype(str)
        if col != 'Fundos/Carteiras Adm':
            pl_dias[col] = pl_dias[col].str.replace('R$', '')
            pl_dias[col] = pl_dias[col].replace('--', np.nan)
            pl_dias[col] = pl_dias[col].astype(float, errors='ignore')

    # Atualizar todas as colunas para float menos a primeira
    pl_dias = pl_dias.set_index("Fundos/Carteiras Adm")
    pl_dias_vetor =[]
    # Criar uma barra de progresso
    # Placeholder para exibir os elementos carregados na mesma linha
    status_container = st.empty()
    # Mensagem inicial
    mensagens = ["⏳ Aguarde até o Total ser concluído..."]
    status_container.markdown(" | ".join(mensagens))  # Exibe a mensagem inicial
    for fundo, row_fundo in df_current.iterrows():
        # Caminho do parquet do Fundo
        nome_arquivo_parquet = os.path.join("BaseFundos", f"{fundo}.parquet")
        # 2.1) Carregar (ou criar) o DataFrame histórico do Fundo (df_fundo)
        if os.path.exists(nome_arquivo_parquet):
            df_fundo = pd.read_parquet(nome_arquivo_parquet)
            # Conferir se já existem dados para o dia de operação
            # 2.2) Garante que "Ativo" seja índice (mas mantendo a coluna)
            if "Ativo" in df_fundo.columns:
                df_fundo.set_index("Ativo", inplace=True, drop=False)
            # Coleta dados antigos do dia, se existirem
            cols_dia = df_fundo.columns[df_fundo.columns.str.startswith(dia_operacao)]
            df_existente_dia = df_fundo[cols_dia].copy() if len(cols_dia) > 0 else pd.DataFrame()
        else:
            df_fundo = pd.DataFrame(columns=["Ativo",
                                             "Preco_Fechamento_Atual"])
            df_existente_dia = pd.DataFrame()
            # 2.2) Garante que "Ativo" seja índice (mas mantendo a coluna)
            if "Ativo" in df_fundo.columns:
                df_fundo.set_index("Ativo", inplace=True, drop=False)
        df_novo_dia = pd.DataFrame(index=df_fundo.index)
        subset = df_info[df_info["Dia de Compra"] == dia_operacao]
        lista_assets = subset["Ativo"].unique()
        for asset in lista_assets:
            # Se o ativo ainda não existe no df_fundo, cria a linha
            if asset not in df_fundo.index:
                df_fundo.loc[asset, "Ativo"] = asset
                if fundo == "Total":
                    soma_pl = sum(pl_dias_vetor)
                    df_fundo.loc[asset,
                                 f"{dia_operacao} - PL"] = soma_pl
                else:
                    df_fundo.loc[asset,
                                 f"{dia_operacao} - PL"] = pl_dias.loc[fundo, dia_operacao]
                    pl_dias_vetor.append(pl_dias.loc[fundo, dia_operacao])

                # Garantir que o valor seja numérico
                preco_fechamento_atual = df_fechamento_b3.loc[df_fechamento_b3["Assets"]
                                                              == asset, ultimo_fechamento].values[0]
                preco_fechamento_atual = pd.to_numeric(
                    preco_fechamento_atual, errors='coerce')
                preco_fechamento_dia = df_fechamento_b3.loc[df_fechamento_b3["Assets"]
                                                            == asset, dia_operacao].values[0]
                preco_fechamento_dia = pd.to_numeric(
                    preco_fechamento_dia, errors='coerce')

                df_fundo.loc[asset,
                             f"{dia_operacao} - Preco_Fechamento"] = preco_fechamento_dia

                df_fundo.loc[asset,
                             "Preco_Fechamento_Atual"] = preco_fechamento_atual

                preco_compra = df_info.loc[(df_info["Ativo"] == asset) & (
                    df_info["Dia de Compra"] == dia_operacao), "Preço de Compra"].values[0]
                preco_compra = pd.to_numeric(preco_compra, errors='coerce')
                df_fundo.loc[asset,
                             f"{dia_operacao} - Preco_Compra"] = preco_compra

                quantidade = row_fundo[f'Contratos {asset}']
                quantidade = pd.to_numeric(quantidade, errors='coerce')
                df_fundo.loc[asset,
                             f'{dia_operacao} - Quantidade'] = quantidade

                # Calcular o rendimento
                if asset == 'TREASURY':
                    rendimento = preco_fechamento_dia - preco_compra
                    df_fundo.loc[asset,
                                 f'{dia_operacao} - Rendimento'] = quantidade * rendimento * dolar / 10000
                else:
                    rendimento = preco_fechamento_dia - preco_compra
                    df_fundo.loc[asset,
                                 f'{dia_operacao} - Rendimento'] = quantidade * rendimento

            else:
                if fundo == "Total":
                    df_fundo.loc[asset,
                                 f"{dia_operacao} - PL"] = pl_dias.loc['TOTAL', dia_operacao]
                else:
                    df_fundo.loc[asset,
                                 f"{dia_operacao} - PL"] = pl_dias.loc[fundo, dia_operacao]
                
                # Garantir que o valor seja numérico
                preco_fechamento_atual = df_fechamento_b3.loc[df_fechamento_b3["Assets"]
                                                              == asset, ultimo_fechamento].values[0]
                preco_fechamento_atual = pd.to_numeric(
                    preco_fechamento_atual, errors='coerce')

                preco_fechamento_dia = df_fechamento_b3.loc[df_fechamento_b3["Assets"]
                                                            == asset, dia_operacao].values[0]
                preco_fechamento_dia = pd.to_numeric(
                    preco_fechamento_dia, errors='coerce')

                df_fundo.loc[asset,
                             f"{dia_operacao} - Preco_Fechamento"] = preco_fechamento_dia

                df_fundo.loc[asset,
                             "Preco_Fechamento_Atual"] = preco_fechamento_atual

                preco_compra = df_info.loc[(df_info["Ativo"] == asset) & (
                    df_info["Dia de Compra"] == dia_operacao), "Preço de Compra"].values[0]
                preco_compra = pd.to_numeric(preco_compra, errors='coerce')
                df_fundo.loc[asset,
                             f"{dia_operacao} - Preco_Compra"] = preco_compra

                quantidade = row_fundo[f'Contratos {asset}']
                quantidade = pd.to_numeric(quantidade, errors='coerce')
                df_fundo.loc[asset,
                             f'{dia_operacao} - Quantidade'] = quantidade

                # Calcular o rendimento
                if asset == 'TREASURY':
                    rendimento = preco_fechamento_dia - preco_compra
                    df_fundo.loc[asset,
                                 f'{dia_operacao} - Rendimento'] = quantidade * rendimento * dolar / 10000
                else:
                    rendimento = preco_fechamento_dia - preco_compra
                    df_fundo.loc[asset,
                                 f'{dia_operacao} - Rendimento'] = quantidade * rendimento

        # Pegar o Preco de compra de cada ativo
        df_fundo.reset_index(drop=True, inplace=True)
        df_fundo.to_parquet(nome_arquivo_parquet, index=False)
        table_name = nome_arquivo_parquet.replace(".parquet", "")
        #table_name = table_name.replace("BaseFundos\\", "")
        table_name = table_name.replace("BaseFundos/", "")
        # Exibe o nome do elemento que foi carregado
        mensagens.append(f"✅ {table_name} carregado!")
        status_container.markdown(" | ".join(mensagens))
        add_data_2(df_fundo,table_name)
        print(f"[{fundo}] -> parquet atualizado: {nome_arquivo_parquet}")

# %%
df_current['Contratos DI_28'] = [i % 2 for i in range(len(df_current))]
df_current
#Adicionar alguns valores a coluna DI_28
# Out:
#                                  PL Weights     PL_atualizado        Adm  \
# Fundos/Carteiras Adm
# GLOBAL BONDS           R$29,724,903       4  R$118,899,612.00  SANTANDER
# HORIZONTE             R$249,201,896       1  R$249,201,896.00        BTG
# JERA2026              R$198,848,279       1  R$198,848,279.00  SANTANDER
# REAL FIM               R$37,956,814       1   R$37,956,814.00  SANTANDER
# BH FIRF INFRA         R$122,471,460       1  R$122,471,460.00        BTG
# BORDEAUX INFRA         R$47,571,955       1   R$47,571,955.00        BTG
# TOPAZIO INFRA          R$31,712,857       1   R$31,712,857.00        BTG
# MANACA INFRA FIRF      R$41,890,656       1   R$41,890,656.00        BTG
# AF DEB INCENTIVADAS    R$12,257,503       3   R$36,772,509.00        BTG
# Total                 R$771,636,323      14  R$885,326,038.00
#
#                       Max Contratos DAP35  Max Contratos DI_27  \
# Fundos/Carteiras Adm
# GLOBAL BONDS                    13.564337            20.950857
# HORIZONTE                       28.429517            43.910937
# JERA2026                        22.685062            35.038314
# REAL FIM                         4.330199             6.688229
# BH FIRF INFRA                   13.971822            21.580239
# BORDEAUX INFRA                   5.427116             8.382477
# TOPAZIO INFRA                    3.617875             5.588004
# MANACA INFRA FIRF                4.778981             7.381396
# AF DEB INCENTIVADAS              4.195091             6.479547
# Total                          101.000000           156.000000
#
#                       Max Contratos WDO1 Contratos DAP35 Contratos DI_27  \
# Fundos/Carteiras Adm
# GLOBAL BONDS                   14.907341               0               0
# HORIZONTE                      31.244320               0               0
# JERA2026                       24.931108               0               0
# REAL FIM                        4.758932               0               0
# BH FIRF INFRA                  15.355170               1               1
# BORDEAUX INFRA                  5.964455               0               0
# TOPAZIO INFRA                   3.976080               0               0
# MANACA INFRA FIRF               5.252147               0               0
# AF DEB INCENTIVADAS             4.610447               0               0
# Total                         111.000000               1               1
#
#                      Contratos WDO1  Contratos DI_28
# Fundos/Carteiras Adm
# GLOBAL BONDS                      0                0
# HORIZONTE                         1                1
# JERA2026                          1                0
# REAL FIM                         -1                1
# BH FIRF INFRA                     1                0
# BORDEAUX INFRA                    0                1
# TOPAZIO INFRA                    -1                0
# MANACA INFRA FIRF                 0                1
# AF DEB INCENTIVADAS               0                0
# Total                             1                1

# %%
#Dia 10-04-2025
df_agrupado = pd.DataFrame()
df_fechamento_b3 = pd.read_parquet("df_preco_de_ajuste_atual_completo.parquet")
df_fechamento_b3 = df_fechamento_b3.replace('\.', '', regex=True)
df_fechamento_b3 = df_fechamento_b3.replace({',': '.'}, regex=True)
# Converter para float todas as colunas menos a primeira
df_fechamento_b3.iloc[:, 2:] = df_fechamento_b3.iloc[:, 2:].astype(float)

# Multiplicar a linha que tem o Ativo TREASURY por 1000
# Multiplicar a linha da treasury por 1000
df_fechamento_b3.loc[df_fechamento_b3['Assets'] == 'TREASURY', df_fechamento_b3.columns !=
                        'Assets'] = df_fechamento_b3.loc[df_fechamento_b3['Assets'] == 'TREASURY', df_fechamento_b3.columns != 'Assets'] * 1000

df_fechamento_b3.loc[df_fechamento_b3['Assets'] == 'WDO1', df_fechamento_b3.columns !=
                        'Assets'] = df_fechamento_b3.loc[df_fechamento_b3['Assets'] == 'WDO1', df_fechamento_b3.columns != 'Assets'] * 10

ultimo_fechamento = df_fechamento_b3.columns[-1]
dolar = df_fechamento_b3.loc[df_fechamento_b3['Assets']
                                == 'WDO1', ultimo_fechamento].values[0]

pl_dias = pd.read_parquet("pl_fundos_teste.parquet")
pl_dias = pl_dias.replace('\.', '', regex=True)
pl_dias = pl_dias.replace({',': '.'}, regex=True)
for col in pl_dias.columns:
    pl_dias[col] = pl_dias[col].astype(str)
    if col != 'Fundos/Carteiras Adm':
        pl_dias[col] = pl_dias[col].str.replace('R$', '')
        pl_dias[col] = pl_dias[col].replace('--', np.nan)
        pl_dias[col] = pl_dias[col].astype(float, errors='ignore')

# Atualizar todas as colunas para float menos a primeira
pl_dias = pl_dias.set_index("Fundos/Carteiras Adm")
pl_dias_vetor =[]
# Criar uma barra de progresso
# Placeholder para exibir os elementos carregados na mesma linha
# Mensagem inicial

for fundo, row_fundo in df_current.iterrows():
    nome_arquivo_parquet = os.path.join("BaseFundos", f"{fundo}.parquet")
    
    # Carrega ou cria o df_fundo
    if os.path.exists(nome_arquivo_parquet):
        df_fundo = pd.read_parquet(nome_arquivo_parquet)
        if "Ativo" in df_fundo.columns:
            df_fundo.set_index("Ativo", inplace=True, drop=False)
        # Coleta dados antigos do dia, se existirem
        cols_dia = df_fundo.columns[df_fundo.columns.str.startswith(dia_operacao)]
        df_existente_dia = df_fundo[cols_dia].copy() if len(cols_dia) > 0 else pd.DataFrame()
    else:
        df_fundo = pd.DataFrame(columns=["Ativo","Preco_Fechamento_Atual"])
        df_fundo.set_index("Ativo", inplace=True, drop=False)
        df_existente_dia = pd.DataFrame()

    # Cria df_novo_dia em branco (mesmo índice do df_fundo)
    df_novo_dia = pd.DataFrame(index=df_fundo.index)

    # Se houver ativos novos (que não estavam em df_fundo), adicionaremos também
    subset = df_info[df_info["Dia de Compra"] == dia_operacao]
    lista_assets = subset["Ativo"].unique()

    for asset in lista_assets:
        # Se não existe, cria uma linha vazia
        if asset not in df_novo_dia.index:
            df_novo_dia.loc[asset, :] = pd.NA

        # -------------------------
        # Preenche as colunas novas
        # -------------------------
        if fundo == "Total":
            pl_valor = sum(pl_dias_vetor)
        else:
            pl_valor = pl_dias.loc[fundo, dia_operacao]
            pl_dias_vetor.append(pl_valor)

        df_novo_dia.loc[asset, f"{dia_operacao} - PL"] = pl_valor

        preco_fechamento_atual = df_fechamento_b3.loc[
            df_fechamento_b3["Assets"] == asset, ultimo_fechamento
        ].values[0]
        preco_fechamento_atual = pd.to_numeric(preco_fechamento_atual, errors='coerce')
        df_fundo.loc[asset, "Preco_Fechamento_Atual"] = preco_fechamento_atual

        preco_fechamento_dia = df_fechamento_b3.loc[
            df_fechamento_b3["Assets"] == asset, dia_operacao
        ].values[0]
        preco_fechamento_dia = pd.to_numeric(preco_fechamento_dia, errors='coerce')
        df_novo_dia.loc[asset, f"{dia_operacao} - Preco_Fechamento"] = preco_fechamento_dia

        preco_compra = df_info.loc[
            (df_info["Ativo"] == asset) & (df_info["Dia de Compra"] == dia_operacao),
            "Preço de Compra"
        ].values[0]
        preco_compra = pd.to_numeric(preco_compra, errors='coerce')
        df_novo_dia.loc[asset, f"{dia_operacao} - Preco_Compra"] = preco_compra
        quantidade = row_fundo[f'Contratos {asset}']
        quantidade = pd.to_numeric(quantidade, errors='coerce')
        df_novo_dia.loc[asset, f"{dia_operacao} - Quantidade"] = quantidade

        if asset == 'TREASURY':
            rendimento = (preco_fechamento_dia - preco_compra) * dolar / 10000
        else:
            rendimento = (preco_fechamento_dia - preco_compra)
        df_novo_dia.loc[asset, f'{dia_operacao} - Rendimento'] = quantidade * rendimento
        df_novo_dia.reset_index(df)


    # --------------------------------------------------------------------
    # 7) Salvar ao final
    # --------------------------------------------------------------------
    # Redefine o índice antes de salvar, se for sua convenção
    df_fundo = pd.concat([df_fundo, df_novo_dia], axis=1)
    df_fundo.reset_index(drop=True, inplace=True)
    
    df_agrupado = pd.concat([df_agrupado, df_fundo], axis=0)
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\.'
# <>:22: SyntaxWarning: invalid escape sequence '\.'
# <>:4: SyntaxWarning: invalid escape sequence '\.'
# <>:22: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\emanuel.cabral\AppData\Local\Temp\ipykernel_17448\1352681985.py:4: SyntaxWarning: invalid escape sequence '\.'
#   df_fechamento_b3 = df_fechamento_b3.replace('\.', '', regex=True)
# C:\Users\emanuel.cabral\AppData\Local\Temp\ipykernel_17448\1352681985.py:22: SyntaxWarning: invalid escape sequence '\.'
#   pl_dias = pl_dias.replace('\.', '', regex=True)
# C:\Users\emanuel.cabral\AppData\Local\Temp\ipykernel_17448\1352681985.py:28: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   pl_dias[col] = pl_dias[col].replace('--', np.nan)
# C:\Users\emanuel.cabral\AppData\Local\Temp\ipykernel_17448\1352681985.py:114: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_agrupado = pd.concat([df_agrupado, df_fundo], axis=0)
# C:\Users\emanuel.cabral\AppData\Local\Temp\ipykernel_17448\1352681985.py:114: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_agrupado = pd.concat([df_agrupado, df_fundo], axis=0)
# C:\Users\emanuel.cabral\AppData\Local\Temp\ipykernel_17448\1352681985.py:114: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_agrupado = pd.concat([df_agrupado, df_fundo], axis=0)
# C:\Users\emanuel.cabral\AppData\Local\Temp\ipykernel_17448\1352681985.py:114: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_agrupado = pd.concat([df_agrupado, df_fundo], axis=0)

# %%
df_agrupado.columns
# Out:
# Index(['Ativo', 'Preco_Fechamento_Atual', '2025-03-12 - PL',
#        '2025-03-12 - Preco_Fechamento', '2025-03-12 - Preco_Compra',
#        '2025-03-12 - Quantidade', '2025-03-12 - Rendimento', '2025-03-18 - PL',
#        '2025-03-18 - Preco_Fechamento', '2025-03-18 - Preco_Compra',
#        '2025-03-18 - Quantidade', '2025-03-18 - Rendimento', '2025-03-31 - PL',
#        '2025-03-31 - Preco_Fechamento', '2025-03-31 - Preco_Compra',
#        '2025-03-31 - Quantidade', '2025-03-31 - Rendimento', '2025-04-03 - PL',
#        '2025-04-03 - Preco_Fechamento', '2025-04-03 - Preco_Compra',
#        '2025-04-03 - Quantidade', '2025-04-03 - Rendimento', '2025-04-04 - PL',
#        '2025-04-04 - Preco_Fechamento', '2025-04-04 - Preco_Compra',
#        '2025-04-04 - Quantidade', '2025-04-04 - Rendimento', '2025-04-07 - PL',
#        '2025-04-07 - Preco_Fechamento', '2025-04-07 - Preco_Compra',
#        '2025-04-07 - Quantidade', '2025-04-07 - Rendimento', '2025-04-09 - PL',
#        '2025-04-09 - Preco_Fechamento', '2025-04-09 - Preco_Compra',
#        '2025-04-09 - Quantidade', '2025-04-09 - Rendimento', '2025-04-10 - PL',
#        '2025-04-10 - Preco_Fechamento', '2025-04-10 - Preco_Compra',
#        '2025-04-10 - Quantidade', '2025-04-10 - Rendimento'],
#       dtype='object')

# %%
#Dia 10-04-2025,
base_fundos_dir="BaseFundos"

df_agrupado = pd.DataFrame()
df_fechamento_b3 = pd.read_parquet("df_preco_de_ajuste_atual_completo.parquet")
df_fechamento_b3 = df_fechamento_b3.replace('\.', '', regex=True)
df_fechamento_b3 = df_fechamento_b3.replace({',': '.'}, regex=True)
# Converter para float todas as colunas menos a primeira
df_fechamento_b3.iloc[:, 2:] = df_fechamento_b3.iloc[:, 2:].astype(float)

# Multiplicar a linha que tem o Ativo TREASURY por 1000
# Multiplicar a linha da treasury por 1000
df_fechamento_b3.loc[df_fechamento_b3['Assets'] == 'TREASURY', df_fechamento_b3.columns !=
                        'Assets'] = df_fechamento_b3.loc[df_fechamento_b3['Assets'] == 'TREASURY', df_fechamento_b3.columns != 'Assets'] * 1000

df_fechamento_b3.loc[df_fechamento_b3['Assets'] == 'WDO1', df_fechamento_b3.columns !=
                        'Assets'] = df_fechamento_b3.loc[df_fechamento_b3['Assets'] == 'WDO1', df_fechamento_b3.columns != 'Assets'] * 10

ultimo_fechamento = df_fechamento_b3.columns[-1]
dolar = df_fechamento_b3.loc[df_fechamento_b3['Assets']
                                == 'WDO1', ultimo_fechamento].values[0]

pl_dias = pd.read_parquet("pl_fundos_teste.parquet")
pl_dias = pl_dias.replace('\.', '', regex=True)
pl_dias = pl_dias.replace({',': '.'}, regex=True)
for col in pl_dias.columns:
    pl_dias[col] = pl_dias[col].astype(str)
    if col != 'Fundos/Carteiras Adm':
        pl_dias[col] = pl_dias[col].str.replace('R$', '')
        pl_dias[col] = pl_dias[col].replace('--', np.nan)
        pl_dias[col] = pl_dias[col].astype(float, errors='ignore')

# Atualizar todas as colunas para float menos a primeira
pl_dias = pl_dias.set_index("Fundos/Carteiras Adm")
pl_dias_vetor =[]
# Criar uma barra de progresso
# Placeholder para exibir os elementos carregados na mesma linha
# Mensagem inicial

# Itera sobre cada Fundo do df_current
for fundo, row_fundo in df_current.iterrows():
    # Exemplo: arquivo "BaseFundos\GLOBAL BONDS.parquet"
    nome_arquivo_parquet = os.path.join(base_fundos_dir, f"{fundo}.parquet")

    # Carrega ou cria o df_fundo
    if os.path.exists(nome_arquivo_parquet):
        df_fundo = pd.read_parquet(nome_arquivo_parquet)
    else:
        df_fundo = pd.DataFrame()

    # Se não há coluna "Fundo", cria (para identificar a linha do fundo)
    if 'Fundo' not in df_fundo.columns:
        df_fundo['Fundo'] = fundo

    # Garante que a linha de índice seja "Fundo"
    if df_fundo.index.name != 'Fundo':
        df_fundo.set_index('Fundo', inplace=True, drop=True)

    # Se ainda não existe a linha desse Fundo, cria
    if fundo not in df_fundo.index:
        df_fundo.loc[fundo, :] = np.nan

    # Filtra em df_info só as transações desse dia
    subset = df_info[df_info["Dia de Compra"] == dia_operacao]
    lista_assets = subset["Ativo"].unique()
    print(lista_assets)
    # Para cada ativo do dia, cria (ou atualiza) as colunas
    for asset in lista_assets:
        # Exemplos de nomes de colunas que você vai criar
        col_pl   = f"{dia_operacao} - PL"
        col_qtd  = f"{dia_operacao} - Quantidade"
        col_pc   = f"{dia_operacao} - Preco_Compra"
        col_pf   = f"{dia_operacao} - Preco_Fechamento"
        col_rend = f"{dia_operacao} - Rendimento"

        # Se as colunas não existem ainda, cria com valores NaN
        for col in [col_pl, col_qtd, col_pc, col_pf, col_rend]:
            if col not in df_fundo.columns:
                df_fundo[col] = np.nan

        # ----------------------------------------------------------
        # 1) PL (depende se é "Total" ou fundo específico)
        # ----------------------------------------------------------
        if fundo == "Total":
            pl_valor = df_current['PL'].sum()  # ou sum(pl_dias_vetor), etc.
        else:
            # Exemplo de como buscar no pl_dias
            pl_valor = pl_dias.loc[fundo, dia_operacao]

        df_fundo.loc[fundo, col_pl] = pl_valor

        # ----------------------------------------------------------
        # 2) Preço de Fechamento (Atual + do dia)
        # ----------------------------------------------------------
        # Preço de Fechamento "atual" (ultima coluna do df_fechamento_b3)
        preco_fechamento_atual = df_fechamento_b3.loc[
            df_fechamento_b3["Assets"] == asset, ultimo_fechamento
        ].values[0]
        preco_fechamento_atual = pd.to_numeric(preco_fechamento_atual, errors='coerce')

        # Preço de Fechamento do dia_operacao
        preco_fechamento_dia = df_fechamento_b3.loc[
            df_fechamento_b3["Assets"] == asset, dia_operacao
        ].values[0]
        preco_fechamento_dia = pd.to_numeric(preco_fechamento_dia, errors='coerce')
        df_fundo.loc[fundo, col_pf] = preco_fechamento_dia

        # ----------------------------------------------------------
        # 3) Preço de Compra
        # ----------------------------------------------------------
        preco_compra = df_info.loc[
            (df_info["Ativo"] == asset) & (df_info["Dia de Compra"] == dia_operacao),
            "Preço de Compra"
        ].values[0]
        preco_compra = pd.to_numeric(preco_compra, errors='coerce')
        df_fundo.loc[fundo, col_pc] = preco_compra

        # ----------------------------------------------------------
        # 4) Quantidade
        # ----------------------------------------------------------
        # Depende de como sua coluna se chama em df_current
        col_contratos = f"Contratos {asset}"
        quantidade = row_fundo.get(col_contratos, 0)  # se não achar, 0
        quantidade = pd.to_numeric(quantidade, errors='coerce')
        df_fundo.loc[fundo, col_qtd] = quantidade

        # ----------------------------------------------------------
        # 5) Rendimento
        # ----------------------------------------------------------
        if asset == 'TREASURY':
            rendimento_unit = (preco_fechamento_dia - preco_compra) * dolar / 10000
        else:
            rendimento_unit = (preco_fechamento_dia - preco_compra)

        df_fundo.loc[fundo, col_rend] = quantidade * rendimento_unit
  
    df_agrupado = pd.concat([df_agrupado, df_fundo], axis=0)
df_agrupado
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\.'
# <>:24: SyntaxWarning: invalid escape sequence '\.'
# <>:6: SyntaxWarning: invalid escape sequence '\.'
# <>:24: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\emanuel.cabral\AppData\Local\Temp\ipykernel_17448\572020372.py:6: SyntaxWarning: invalid escape sequence '\.'
#   df_fechamento_b3 = df_fechamento_b3.replace('\.', '', regex=True)
# C:\Users\emanuel.cabral\AppData\Local\Temp\ipykernel_17448\572020372.py:24: SyntaxWarning: invalid escape sequence '\.'
#   pl_dias = pl_dias.replace('\.', '', regex=True)
# C:\Users\emanuel.cabral\AppData\Local\Temp\ipykernel_17448\572020372.py:30: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   pl_dias[col] = pl_dias[col].replace('--', np.nan)
# ['DI_27' 'DAP35' 'WDO1' 'DI_28']
# ['DI_27' 'DAP35' 'WDO1' 'DI_28']
# ['DI_27' 'DAP35' 'WDO1' 'DI_28']
# ['DI_27' 'DAP35' 'WDO1' 'DI_28']
# ['DI_27' 'DAP35' 'WDO1' 'DI_28']
# ['DI_27' 'DAP35' 'WDO1' 'DI_28']
# ['DI_27' 'DAP35' 'WDO1' 'DI_28']
# ['DI_27' 'DAP35' 'WDO1' 'DI_28']
# C:\Users\emanuel.cabral\AppData\Local\Temp\ipykernel_17448\572020372.py:137: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_agrupado = pd.concat([df_agrupado, df_fundo], axis=0)
# C:\Users\emanuel.cabral\AppData\Local\Temp\ipykernel_17448\572020372.py:137: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_agrupado = pd.concat([df_agrupado, df_fundo], axis=0)
# C:\Users\emanuel.cabral\AppData\Local\Temp\ipykernel_17448\572020372.py:137: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_agrupado = pd.concat([df_agrupado, df_fundo], axis=0)
# C:\Users\emanuel.cabral\AppData\Local\Temp\ipykernel_17448\572020372.py:137: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_agrupado = pd.concat([df_agrupado, df_fundo], axis=0)
# ['DI_27' 'DAP35' 'WDO1' 'DI_28']
# ['DI_27' 'DAP35' 'WDO1' 'DI_28']
# C:\Users\emanuel.cabral\AppData\Local\Temp\ipykernel_17448\572020372.py:90: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'R$29,724,903R$249,201,896R$198,848,279R$37,956,814R$122,471,460R$47,571,955R$31,712,857R$41,890,656R$12,257,503R$771,636,323' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_fundo.loc[fundo, col_pl] = pl_valor
#                      Ativo  Preco_Fechamento_Atual  2025-03-12 - PL  \
# Fundo
# GLOBAL BONDS         DAP35                47958.70     2.952013e+07
# GLOBAL BONDS         DI_27                79215.25              NaN
# GLOBAL BONDS          WDO1                58797.34              NaN
# HORIZONTE            DAP35                47958.70     2.469614e+08
# HORIZONTE            DI_27                79215.25              NaN
# HORIZONTE             WDO1                58797.34              NaN
# JERA2026             DAP35                47958.70     1.966826e+08
# JERA2026             DI_27                79215.25              NaN
# JERA2026              WDO1                58797.34              NaN
# REAL FIM             DAP35                47958.70     3.751419e+07
# REAL FIM             DI_27                79215.25              NaN
# REAL FIM              WDO1                58797.34              NaN
# BH FIRF INFRA        DAP35                47958.70     1.209188e+08
# BH FIRF INFRA        DI_27                79215.25              NaN
# BH FIRF INFRA         WDO1                58797.34              NaN
# BORDEAUX INFRA       DAP35                47958.70     4.651603e+07
# BORDEAUX INFRA       DI_27                79215.25              NaN
# BORDEAUX INFRA        WDO1                58797.34              NaN
# TOPAZIO INFRA        DAP35                47958.70     3.142537e+07
# TOPAZIO INFRA        DI_27                79215.25              NaN
# TOPAZIO INFRA         WDO1                58797.34              NaN
# MANACA INFRA FIRF    DI_27                79215.25              NaN
# MANACA INFRA FIRF     WDO1                58797.34              NaN
# MANACA INFRA FIRF    DAP35                47958.70     4.149414e+07
# AF DEB INCENTIVADAS  DAP35                47958.70     1.204817e+07
# AF DEB INCENTIVADAS  DI_27                79215.25              NaN
# AF DEB INCENTIVADAS   WDO1                58797.34              NaN
# Total                DAP35                47958.70     2.185097e+09
# Total                DI_27                79215.25              NaN
# Total                 WDO1                58797.34              NaN
#
#                      2025-03-12 - Preco_Fechamento  2025-03-12 - Preco_Compra  \
# Fundo
# GLOBAL BONDS                               47658.3                    47658.3
# GLOBAL BONDS                                   NaN                        NaN
# GLOBAL BONDS                                   NaN                        NaN
# HORIZONTE                                  47658.3                    47658.3
# HORIZONTE                                      NaN                        NaN
# HORIZONTE                                      NaN                        NaN
# JERA2026                                   47658.3                    47658.3
# JERA2026                                       NaN                        NaN
# JERA2026                                       NaN                        NaN
# REAL FIM                                   47658.3                    47658.3
# REAL FIM                                       NaN                        NaN
# REAL FIM                                       NaN                        NaN
# BH FIRF INFRA                              47658.3                    47658.3
# BH FIRF INFRA                                  NaN                        NaN
# BH FIRF INFRA                                  NaN                        NaN
# BORDEAUX INFRA                             47658.3                    47658.3
# BORDEAUX INFRA                                 NaN                        NaN
# BORDEAUX INFRA                                 NaN                        NaN
# TOPAZIO INFRA                              47658.3                    47658.3
# TOPAZIO INFRA                                  NaN                        NaN
# TOPAZIO INFRA                                  NaN                        NaN
# MANACA INFRA FIRF                              NaN                        NaN
# MANACA INFRA FIRF                              NaN                        NaN
# MANACA INFRA FIRF                          47658.3                    47658.3
# AF DEB INCENTIVADAS                        47658.3                    47658.3
# AF DEB INCENTIVADAS                            NaN                        NaN
# AF DEB INCENTIVADAS                            NaN                        NaN
# Total                                      47658.3                    47658.3
# Total                                          NaN                        NaN
# Total                                          NaN                        NaN
#
#                      2025-03-12 - Quantidade  2025-03-12 - Rendimento  \
# Fundo
# GLOBAL BONDS                             0.0                      0.0
# GLOBAL BONDS                             NaN                      NaN
# GLOBAL BONDS                             NaN                      NaN
# HORIZONTE                                5.0                      0.0
# HORIZONTE                                NaN                      NaN
# HORIZONTE                                NaN                      NaN
# JERA2026                                 4.0                      0.0
# JERA2026                                 NaN                      NaN
# JERA2026                                 NaN                      NaN
# REAL FIM                                 1.0                      0.0
# REAL FIM                                 NaN                      NaN
# REAL FIM                                 NaN                      NaN
# BH FIRF INFRA                            2.0                      0.0
# BH FIRF INFRA                            NaN                      NaN
# BH FIRF INFRA                            NaN                      NaN
# BORDEAUX INFRA                           1.0                      0.0
# BORDEAUX INFRA                           NaN                      NaN
# BORDEAUX INFRA                           NaN                      NaN
# TOPAZIO INFRA                            1.0                      0.0
# TOPAZIO INFRA                            NaN                      NaN
# TOPAZIO INFRA                            NaN                      NaN
# MANACA INFRA FIRF                        NaN                      NaN
# MANACA INFRA FIRF                        NaN                      NaN
# MANACA INFRA FIRF                        1.0                      0.0
# AF DEB INCENTIVADAS                      1.0                      0.0
# AF DEB INCENTIVADAS                      NaN                      NaN
# AF DEB INCENTIVADAS                      NaN                      NaN
# Total                                   16.0                      0.0
# Total                                    NaN                      NaN
# Total                                    NaN                      NaN
#
#                      2025-03-18 - PL  2025-03-18 - Preco_Fechamento  \
# Fundo
# GLOBAL BONDS            2.954396e+07                       47848.28
# GLOBAL BONDS                     NaN                            NaN
# GLOBAL BONDS                     NaN                            NaN
# HORIZONTE               2.473902e+08                       47848.28
# HORIZONTE                        NaN                            NaN
# HORIZONTE                        NaN                            NaN
# JERA2026                         NaN                       47848.28
# JERA2026                         NaN                            NaN
# JERA2026                         NaN                            NaN
# REAL FIM                         NaN                       47848.28
# REAL FIM                         NaN                            NaN
# REAL FIM                         NaN                            NaN
# BH FIRF INFRA           1.212707e+08                       47848.28
# BH FIRF INFRA                    NaN                            NaN
# BH FIRF INFRA                    NaN                            NaN
# BORDEAUX INFRA                   NaN                       47848.28
# BORDEAUX INFRA                   NaN                            NaN
# BORDEAUX INFRA                   NaN                            NaN
# TOPAZIO INFRA                    NaN                       47848.28
# TOPAZIO INFRA                    NaN                            NaN
# TOPAZIO INFRA                    NaN                            NaN
# MANACA INFRA FIRF                NaN                            NaN
# MANACA INFRA FIRF                NaN                            NaN
# MANACA INFRA FIRF       4.159281e+07                       47848.28
# AF DEB INCENTIVADAS     1.210352e+07                       47848.28
# AF DEB INCENTIVADAS              NaN                            NaN
# AF DEB INCENTIVADAS              NaN                            NaN
# Total                   1.497952e+09                       47848.28
# Total                            NaN                            NaN
# Total                            NaN                            NaN
#
#                      2025-03-18 - Preco_Compra  ...  2025-04-09 - PL  \
# Fundo                                           ...
# GLOBAL BONDS                          47848.28  ...              NaN
# GLOBAL BONDS                               NaN  ...     2.967671e+07
# GLOBAL BONDS                               NaN  ...              NaN
# HORIZONTE                             47848.28  ...              NaN
# HORIZONTE                                  NaN  ...     2.495259e+08
# HORIZONTE                                  NaN  ...              NaN
# JERA2026                              47848.28  ...              NaN
# JERA2026                                   NaN  ...     1.990115e+08
# JERA2026                                   NaN  ...              NaN
# REAL FIM                              47848.28  ...              NaN
# REAL FIM                                   NaN  ...     3.797748e+07
# REAL FIM                                   NaN  ...              NaN
# BH FIRF INFRA                         47848.28  ...              NaN
# BH FIRF INFRA                              NaN  ...     1.226404e+08
# BH FIRF INFRA                              NaN  ...              NaN
# BORDEAUX INFRA                        47848.28  ...              NaN
# BORDEAUX INFRA                             NaN  ...     4.764104e+07
# BORDEAUX INFRA                             NaN  ...              NaN
# TOPAZIO INFRA                         47848.28  ...              NaN
# TOPAZIO INFRA                              NaN  ...     3.174415e+07
# TOPAZIO INFRA                              NaN  ...              NaN
# MANACA INFRA FIRF                          NaN  ...     4.195741e+07
# MANACA INFRA FIRF                          NaN  ...              NaN
# MANACA INFRA FIRF                     47848.28  ...              NaN
# AF DEB INCENTIVADAS                   47848.28  ...              NaN
# AF DEB INCENTIVADAS                        NaN  ...     1.222439e+07
# AF DEB INCENTIVADAS                        NaN  ...              NaN
# Total                                 47848.28  ...              NaN
# Total                                      NaN  ...     1.881084e+09
# Total                                      NaN  ...              NaN
#
#                      2025-04-09 - Preco_Fechamento  2025-04-09 - Preco_Compra  \
# Fundo
# GLOBAL BONDS                                   NaN                        NaN
# GLOBAL BONDS                               79365.3                    79276.7
# GLOBAL BONDS                                   NaN                        NaN
# HORIZONTE                                      NaN                        NaN
# HORIZONTE                                  79365.3                    79276.7
# HORIZONTE                                      NaN                        NaN
# JERA2026                                       NaN                        NaN
# JERA2026                                   79365.3                    79276.7
# JERA2026                                       NaN                        NaN
# REAL FIM                                       NaN                        NaN
# REAL FIM                                   79365.3                    79276.7
# REAL FIM                                       NaN                        NaN
# BH FIRF INFRA                                  NaN                        NaN
# BH FIRF INFRA                              79365.3                    79276.7
# BH FIRF INFRA                                  NaN                        NaN
# BORDEAUX INFRA                                 NaN                        NaN
# BORDEAUX INFRA                             79365.3                    79276.7
# BORDEAUX INFRA                                 NaN                        NaN
# TOPAZIO INFRA                                  NaN                        NaN
# TOPAZIO INFRA                              79365.3                    79276.7
# TOPAZIO INFRA                                  NaN                        NaN
# MANACA INFRA FIRF                          79365.3                    79276.7
# MANACA INFRA FIRF                              NaN                        NaN
# MANACA INFRA FIRF                              NaN                        NaN
# AF DEB INCENTIVADAS                            NaN                        NaN
# AF DEB INCENTIVADAS                        79365.3                    79276.7
# AF DEB INCENTIVADAS                            NaN                        NaN
# Total                                          NaN                        NaN
# Total                                      79365.3                    79276.7
# Total                                          NaN                        NaN
#
#                      2025-04-09 - Quantidade  2025-04-09 - Rendimento  \
# Fundo
# GLOBAL BONDS                             NaN                      NaN
# GLOBAL BONDS                             0.0                      0.0
# GLOBAL BONDS                             NaN                      NaN
# HORIZONTE                                NaN                      NaN
# HORIZONTE                                6.0                    531.6
# HORIZONTE                                NaN                      NaN
# JERA2026                                 NaN                      NaN
# JERA2026                                 5.0                    443.0
# JERA2026                                 NaN                      NaN
# REAL FIM                                 NaN                      NaN
# REAL FIM                                 1.0                     88.6
# REAL FIM                                 NaN                      NaN
# BH FIRF INFRA                            NaN                      NaN
# BH FIRF INFRA                            3.0                    265.8
# BH FIRF INFRA                            NaN                      NaN
# BORDEAUX INFRA                           NaN                      NaN
# BORDEAUX INFRA                           1.0                     88.6
# BORDEAUX INFRA                           NaN                      NaN
# TOPAZIO INFRA                            NaN                      NaN
# TOPAZIO INFRA                            1.0                     88.6
# TOPAZIO INFRA                            NaN                      NaN
# MANACA INFRA FIRF                        1.0                     88.6
# MANACA INFRA FIRF                        NaN                      NaN
# MANACA INFRA FIRF                        NaN                      NaN
# AF DEB INCENTIVADAS                      NaN                      NaN
# AF DEB INCENTIVADAS                      0.0                      0.0
# AF DEB INCENTIVADAS                      NaN                      NaN
# Total                                    NaN                      NaN
# Total                                   18.0                   1594.8
# Total                                    NaN                      NaN
#
#                                                        2025-04-10 - PL  \
# Fundo
# GLOBAL BONDS                                                29676714.6
# GLOBAL BONDS                                                29676714.6
# GLOBAL BONDS                                                29676714.6
# HORIZONTE                                                 249782820.07
# HORIZONTE                                                 249782820.07
# HORIZONTE                                                 249782820.07
# JERA2026                                                  199011450.67
# JERA2026                                                  199011450.67
# JERA2026                                                  199011450.67
# REAL FIM                                                   37977475.72
# REAL FIM                                                   37977475.72
# REAL FIM                                                   37977475.72
# BH FIRF INFRA                                             122729011.06
# BH FIRF INFRA                                             122729011.06
# BH FIRF INFRA                                             122729011.06
# BORDEAUX INFRA                                             47660514.26
# BORDEAUX INFRA                                             47660514.26
# BORDEAUX INFRA                                             47660514.26
# TOPAZIO INFRA                                              31774790.64
# TOPAZIO INFRA                                              31774790.64
# TOPAZIO INFRA                                              31774790.64
# MANACA INFRA FIRF                                          41995143.79
# MANACA INFRA FIRF                                          41995143.79
# MANACA INFRA FIRF                                          41995143.79
# AF DEB INCENTIVADAS                                        12135289.55
# AF DEB INCENTIVADAS                                        12135289.55
# AF DEB INCENTIVADAS                                        12135289.55
# Total                R$29,724,903R$249,201,896R$198,848,279R$37,956...
# Total                R$29,724,903R$249,201,896R$198,848,279R$37,956...
# Total                R$29,724,903R$249,201,896R$198,848,279R$37,956...
#
#                      2025-04-10 - Preco_Fechamento  2025-04-10 - Preco_Compra  \
# Fundo
# GLOBAL BONDS                              69490.66                        0.0
# GLOBAL BONDS                              69490.66                        0.0
# GLOBAL BONDS                              69490.66                        0.0
# HORIZONTE                                 69490.66                        0.0
# HORIZONTE                                 69490.66                        0.0
# HORIZONTE                                 69490.66                        0.0
# JERA2026                                  69490.66                        0.0
# JERA2026                                  69490.66                        0.0
# JERA2026                                  69490.66                        0.0
# REAL FIM                                  69490.66                        0.0
# REAL FIM                                  69490.66                        0.0
# REAL FIM                                  69490.66                        0.0
# BH FIRF INFRA                             69490.66                        0.0
# BH FIRF INFRA                             69490.66                        0.0
# BH FIRF INFRA                             69490.66                        0.0
# BORDEAUX INFRA                            69490.66                        0.0
# BORDEAUX INFRA                            69490.66                        0.0
# BORDEAUX INFRA                            69490.66                        0.0
# TOPAZIO INFRA                             69490.66                        0.0
# TOPAZIO INFRA                             69490.66                        0.0
# TOPAZIO INFRA                             69490.66                        0.0
# MANACA INFRA FIRF                         69490.66                        0.0
# MANACA INFRA FIRF                         69490.66                        0.0
# MANACA INFRA FIRF                         69490.66                        0.0
# AF DEB INCENTIVADAS                       69490.66                        0.0
# AF DEB INCENTIVADAS                       69490.66                        0.0
# AF DEB INCENTIVADAS                       69490.66                        0.0
# Total                                     69490.66                        0.0
# Total                                     69490.66                        0.0
# Total                                     69490.66                        0.0
#
#                      2025-04-10 - Quantidade  2025-04-10 - Rendimento
# Fundo
# GLOBAL BONDS                             0.0                     0.00
# GLOBAL BONDS                             0.0                     0.00
# GLOBAL BONDS                             0.0                     0.00
# HORIZONTE                                1.0                 69490.66
# HORIZONTE                                1.0                 69490.66
# HORIZONTE                                1.0                 69490.66
# JERA2026                                 0.0                     0.00
# JERA2026                                 0.0                     0.00
# JERA2026                                 0.0                     0.00
# REAL FIM                                 1.0                 69490.66
# REAL FIM                                 1.0                 69490.66
# REAL FIM                                 1.0                 69490.66
# BH FIRF INFRA                            0.0                     0.00
# BH FIRF INFRA                            0.0                     0.00
# BH FIRF INFRA                            0.0                     0.00
# BORDEAUX INFRA                           1.0                 69490.66
# BORDEAUX INFRA                           1.0                 69490.66
# BORDEAUX INFRA                           1.0                 69490.66
# TOPAZIO INFRA                            0.0                     0.00
# TOPAZIO INFRA                            0.0                     0.00
# TOPAZIO INFRA                            0.0                     0.00
# MANACA INFRA FIRF                        1.0                 69490.66
# MANACA INFRA FIRF                        1.0                 69490.66
# MANACA INFRA FIRF                        1.0                 69490.66
# AF DEB INCENTIVADAS                      0.0                     0.00
# AF DEB INCENTIVADAS                      0.0                     0.00
# AF DEB INCENTIVADAS                      0.0                     0.00
# Total                                    1.0                 69490.66
# Total                                    1.0                 69490.66
# Total                                    1.0                 69490.66
#
# [30 rows x 42 columns]

# %%
df_novo_dia
# Out:
#    2025-04-10 - PL  2025-04-10 - Preco_Fechamento  2025-04-10 - Preco_Compra  \
# 0              NaN                            NaN                        NaN
# 1     3.090973e+09                       79215.25                        0.0
# 2              NaN                            NaN                        NaN
# 3     3.090973e+09                       47958.70                    45000.0
# 4     3.090973e+09                       58797.34                        0.0
# 5     3.090973e+09                       69490.66                        0.0
#
#    2025-04-10 - Quantidade  2025-04-10 - Rendimento
# 0                      NaN                      NaN
# 1                      1.0                 79215.25
# 2                      NaN                      NaN
# 3                      1.0                  2958.70
# 4                      1.0                 58797.34
# 5                      1.0                 69490.66

# %%
df_agrupado
# Out:
#     Ativo  Preco_Fechamento_Atual  2025-03-12 - PL  \
# 0   DAP35                47958.70       29520130.7
# 1   DI_27                79215.25              NaN
# 2    WDO1                58797.34              NaN
# 3     NaN                69490.66              NaN
# 4     NaN                     NaN              NaN
# ..    ...                     ...              ...
# 5     NaN                     NaN              NaN
# 6     NaN                     NaN              NaN
# 7     NaN                     NaN              NaN
# 8     NaN                     NaN              NaN
# 9     NaN                     NaN              NaN
#
#     2025-03-12 - Preco_Fechamento  2025-03-12 - Preco_Compra  \
# 0                         47658.3                    47658.3
# 1                             NaN                        NaN
# 2                             NaN                        NaN
# 3                             NaN                        NaN
# 4                             NaN                        NaN
# ..                            ...                        ...
# 5                             NaN                        NaN
# 6                             NaN                        NaN
# 7                             NaN                        NaN
# 8                             NaN                        NaN
# 9                             NaN                        NaN
#
#     2025-03-12 - Quantidade  2025-03-12 - Rendimento  2025-03-18 - PL  \
# 0                       0.0                      0.0      29543957.37
# 1                       NaN                      NaN              NaN
# 2                       NaN                      NaN              NaN
# 3                       NaN                      NaN              NaN
# 4                       NaN                      NaN              NaN
# ..                      ...                      ...              ...
# 5                       NaN                      NaN              NaN
# 6                       NaN                      NaN              NaN
# 7                       NaN                      NaN              NaN
# 8                       NaN                      NaN              NaN
# 9                       NaN                      NaN              NaN
#
#     2025-03-18 - Preco_Fechamento  2025-03-18 - Preco_Compra  ...  \
# 0                        47848.28                   47848.28  ...
# 1                             NaN                        NaN  ...
# 2                             NaN                        NaN  ...
# 3                             NaN                        NaN  ...
# 4                             NaN                        NaN  ...
# ..                            ...                        ...  ...
# 5                             NaN                        NaN  ...
# 6                             NaN                        NaN  ...
# 7                             NaN                        NaN  ...
# 8                             NaN                        NaN  ...
# 9                             NaN                        NaN  ...
#
#     2025-04-10 - PL  2025-04-10 - Preco_Fechamento  2025-04-10 - Preco_Compra  \
# 0        29676714.6                       47958.70                    47000.0
# 1        29676714.6                       79215.25                    79000.0
# 2               NaN                            NaN                        NaN
# 3               NaN                            NaN                        NaN
# 4               NaN                            NaN                        NaN
# ..              ...                            ...                        ...
# 5               NaN                            NaN                        NaN
# 6               NaN                            NaN                        NaN
# 7               NaN                            NaN                        NaN
# 8               NaN                            NaN                        NaN
# 9               NaN                            NaN                        NaN
#
#     2025-04-10 - Quantidade  2025-04-10 - Rendimento  2025-04-10 - PL  \
# 0                       5.0                  4793.50              NaN
# 1                       3.0                   645.75              NaN
# 2                       NaN                      NaN              NaN
# 3                       NaN                      NaN              NaN
# 4                       NaN                      NaN              NaN
# ..                      ...                      ...              ...
# 5                       NaN                      NaN     3.090973e+09
# 6                       NaN                      NaN              NaN
# 7                       NaN                      NaN     3.090973e+09
# 8                       NaN                      NaN     3.090973e+09
# 9                       NaN                      NaN     3.090973e+09
#
#     2025-04-10 - Preco_Fechamento  2025-04-10 - Preco_Compra  \
# 0                             NaN                        NaN
# 1                             NaN                        NaN
# 2                             NaN                        NaN
# 3                             NaN                        NaN
# 4                             NaN                        NaN
# ..                            ...                        ...
# 5                        79215.25                        0.0
# 6                             NaN                        NaN
# 7                        47958.70                    45000.0
# 8                        58797.34                        0.0
# 9                        69490.66                        0.0
#
#     2025-04-10 - Quantidade  2025-04-10 - Rendimento
# 0                       NaN                      NaN
# 1                       NaN                      NaN
# 2                       NaN                      NaN
# 3                       NaN                      NaN
# 4                       NaN                      NaN
# ..                      ...                      ...
# 5                       1.0                 79215.25
# 6                       NaN                      NaN
# 7                       1.0                  2958.70
# 8                       1.0                 58797.34
# 9                       1.0                 69490.66
#
# [100 rows x 47 columns]

# %%
teste = pd.read_parquet('pl_fundos_teste.parquet')

teste
# Out:
#      Fundos/Carteiras Adm 2025-01-01           2025-01-02  \
# 0     AF DEB INCENTIVADAS         --     R$ 11.703.717,60
# 1   AF INVEST GERAES PREV         --      R$ 4.423.740,40
# 2               AF TÁTICO         --     R$ 44.412.138,51
# 3        ALFA HORIZON FIA         --     R$ 10.881.126,26
# 4             AYA NMK FIM         --      R$ 1.486.446,82
# 5     BBRASIL FIM CP RESP         --     R$ 98.044.971,94
# 6                  BH FIM         --        R$ 503.659,05
# 7           BH FIRF INFRA         --    R$ 117.842.340,86
# 8                 BMG SEG         --    R$ 115.757.838,53
# 9            BORDEAUX FIM         --      R$ 1.658.989,06
# 10         BORDEAUX INFRA         --     R$ 45.464.008,80
# 11              FIA MINAS         --     R$ 30.067.094,34
# 12            FIRF GERAES         --    R$ 532.581.975,13
# 13         FIRF GERAES 30         --    R$ 284.142.345,38
# 14           GLOBAL BONDS         --     R$ 29.643.177,08
# 15              HORIZONTE         --    R$ 241.046.347,17
# 16               JERA2026         --    R$ 191.971.605,94
# 17      MANACA INFRA FIRF         --     R$ 40.533.299,13
# 18       MINAS O.N.E. FIA         --      R$ 1.913.337,53
# 19               REAL FIM         --     R$ 36.542.514,01
# 20     ROMEU FC FIM CP IE         --    R$ 213.403.883,60
# 21           SANKALPA FIM         --        R$ 610.380,57
# 22                SANTANA         --     R$ 31.912.190,20
# 23            TOPAZIO FIM         --      R$ 1.754.887,20
# 24          TOPAZIO INFRA         --     R$ 30.695.865,66
# 25                  TOTAL         --  R$ 2.118.997.880,77
#
#              2025-01-03           2025-01-04           2025-01-05  \
# 0      R$ 11.725.635,32     R$ 11.725.635,32     R$ 11.725.635,32
# 1       R$ 4.425.384,80      R$ 4.425.384,80      R$ 4.425.384,80
# 2      R$ 44.409.219,12     R$ 44.409.219,12     R$ 44.409.219,12
# 3      R$ 10.744.593,60     R$ 10.744.593,60     R$ 10.744.593,60
# 4       R$ 1.487.215,66      R$ 1.487.215,66      R$ 1.487.215,66
# 5      R$ 98.097.976,50     R$ 98.097.976,50     R$ 98.097.976,50
# 6         R$ 502.433,38        R$ 502.433,38        R$ 502.433,38
# 7     R$ 117.906.205,46    R$ 117.906.205,46    R$ 117.906.205,46
# 8     R$ 115.821.667,94    R$ 115.821.667,94    R$ 115.821.667,94
# 9       R$ 1.659.108,46      R$ 1.659.108,46      R$ 1.659.108,46
# 10     R$ 45.484.436,95     R$ 45.484.436,95     R$ 45.484.436,95
# 11     R$ 29.777.428,70     R$ 29.777.428,70     R$ 29.777.428,70
# 12    R$ 533.614.898,36    R$ 533.614.898,36    R$ 533.614.898,36
# 13    R$ 284.147.223,41    R$ 284.147.223,41    R$ 284.147.223,41
# 14     R$ 29.620.615,16     R$ 29.620.615,16     R$ 29.620.615,16
# 15    R$ 241.153.684,76    R$ 241.153.684,76    R$ 241.153.684,76
# 16    R$ 192.044.706,29    R$ 192.044.706,29    R$ 192.044.706,29
# 17     R$ 40.548.790,65     R$ 40.548.790,65     R$ 40.548.790,65
# 18      R$ 1.908.139,55      R$ 1.908.139,55      R$ 1.908.139,55
# 19     R$ 36.554.942,54     R$ 36.554.942,54     R$ 36.554.942,54
# 20    R$ 213.514.261,34    R$ 213.514.261,34    R$ 213.514.261,34
# 21        R$ 610.135,30        R$ 610.135,30        R$ 610.135,30
# 5      R$ 98.328.817,35     R$ 98.044.971,94
# 6         R$ 552.718,95        R$ 503.659,05
# 7     R$ 122.729.011,06    R$ 117.842.340,86
# 8     R$ 119.688.772,44    R$ 115.757.838,53
# 9       R$ 1.730.659,24      R$ 1.658.989,06
# 10     R$ 47.660.514,26     R$ 45.464.008,80
# 11     R$ 35.710.216,52     R$ 30.067.094,34
# 12    R$ 501.862.879,36    R$ 532.581.975,13
# 13    R$ 276.701.648,37    R$ 284.142.345,38
# 14     R$ 29.676.714,60     R$ 29.643.177,08
# 15    R$ 249.782.820,07    R$ 241.046.347,17
# 16    R$ 199.011.450,67    R$ 191.971.605,94
# 17     R$ 41.995.143,79     R$ 40.533.299,13
# 18      R$ 2.804.980,67      R$ 1.913.337,53
# 19     R$ 37.977.475,72     R$ 36.542.514,01
# 20    R$ 221.331.245,07    R$ 213.403.883,60
# 21        R$ 608.053,84        R$ 610.380,57
# 22     R$ 32.911.693,62     R$ 31.912.190,20
# 23      R$ 1.988.125,60      R$ 1.754.887,20
# 24     R$ 31.774.790,64     R$ 30.695.865,66
# 25  R$ 1.851.890.570,70  R$ 2.118.997.880,77
#
# [26 rows x 103 columns]

# %%
# Configuração do Supabase (substitua pelas suas credenciais)
SUPABASE_URL = 'https://obgwfekirteetqzjydry.supabase.co'
SUPABASE_KEY = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6Im9iZ3dmZWtpcnRlZXRxemp5ZHJ5Iiwicm9sZSI6InNlcnZpY2Vfcm9sZSIsImlhdCI6MTczODk2MDc1MCwiZXhwIjoyMDU0NTM2NzUwfQ.k7-Haw1txbCEwb_MzkynOeEuRJpfgt3msePdvQavWAc'
supabase = create_client(SUPABASE_URL, SUPABASE_KEY)

# %%
teste = pd.read_parquet('teste.parquet')
teste['Dia de Compra'] = pd.to_datetime(teste['Dia de Compra'], format='%Y-%m-%d')
teste
# Out:
#     Ativo  Quantidade Dia de Compra  Preço de Compra  Preço de Ajuste Atual  \
# 0   DAP35          16    2025-03-12         47658.30               47958.70
# 1   DAP35           1    2025-03-18         47848.28               47958.70
# 2    WDO1          15    2025-03-31         57530.50               58797.34
# 3   DAP35           1    2025-04-03         48738.41               47958.70
# 4   DI_27          13    2025-04-03         79336.35               79215.25
# 5    WDO1         -15    2025-04-03         56525.00               58797.34
# 6   DI_27           7    2025-04-04         79336.35               79215.25
# 7    WDO1           6    2025-04-04         57265.00               58797.34
# 8   DAP35          15    2025-04-07         48516.11               47958.70
# 9   DI_27         -20    2025-04-07         79324.32               79215.25
# 10   WDO1           5    2025-04-07         59100.00               58797.34
# 11  DAP35           2    2025-04-09         47908.70               47958.70
# 12  DAP35           1    2025-04-10             0.00               47958.70
# 13  DI_27           1    2025-04-10             0.00               79215.25
# 14   WDO1           1    2025-04-10             0.00               58797.34
#
#     Rendimento  Id
# 0      4806.40   1
# 1       110.42   2
# 2     19002.60   8
# 3      -779.71   3
# 4     -1574.30   5
# 5    -34085.10   9
# 6      -847.70   6
# 7      9194.04  10
# 8     -8361.15   4
# 9      2181.40   7
# 10    -1513.30  11
# 11      100.00  12
# 12    47958.70  13
# 13    79215.25  14
# 14    58797.34  15

# %%
#Adicionar um novo registro no Supabase
def add_data(data):
    try:
        # 1. Deleta todos os registros da tabela
        supabase.table('portfolio_posicoes').delete().neq('Ativo', 0).execute()

        # 2. Insere os dados novos
        response = supabase.table('portfolio_posicoes').insert(data).execute()
        print("Resposta do Supabase:", response)
        return response.data
    
    except Exception as e:
        print(f"Erro detalhado: {e}")
        return None

# %%
df = pd.read_parquet('portifolio_posições.parquet')
# encontrar o maior valor atual na coluna 'Id' ignorando os NaNs
max_id = df['Id'].max()

# se estiver totalmente nula, defina como 0
if pd.isna(max_id):
    max_id = 0

# contar quantos NaNs existem
num_missing = df['Id'].isna().sum()

# criar novos IDs sequenciais a partir do max_id
new_ids = range(int(max_id) + 1, int(max_id) + 1 + num_missing)

# substituir os NaNs com esses novos valores
df.loc[df['Id'].isna(), 'Id'] = list(new_ids)

# garantir que a coluna seja inteira, se quiser
df['Id'] = df['Id'].astype(int)
df
# Out:
#     Ativo  Quantidade Dia de Compra  Preço de Compra  Preço de Ajuste Atual  \
# 0   DAP35          16    2025-03-12         47658.30               47958.70
# 1   DAP35           1    2025-03-18         47848.28               47958.70
# 2   DAP35           1    2025-04-03         48738.41               47958.70
# 3   DAP35          15    2025-04-07         48516.11               47958.70
# 4   DI_27          13    2025-04-03         79336.35               79215.25
# 5   DI_27           7    2025-04-04         79336.35               79215.25
# 6   DI_27         -20    2025-04-07         79324.32               79215.25
# 7    WDO1          15    2025-03-31         57530.50               58797.34
# 8    WDO1         -15    2025-04-03         56525.00               58797.34
# 9    WDO1           6    2025-04-04         57265.00               58797.34
# 10   WDO1           5    2025-04-07         59100.00               58797.34
# 11  DAP35           2    2025-04-09         47908.70               47958.70
#
#     Rendimento  Id
# 0      4806.40   1
# 1       110.42   2
# 2      -779.71   3
# 3     -8361.15   4
# 4     -1574.30   5
# 5      -847.70   6
# 6      2181.40   7
# 7     19002.60   8
# 8    -34085.10   9
# 9      9194.04  10
# 10    -1513.30  11
# 11      100.00  12

# %%
add_data(df.to_dict(orient='records'))
# Out:
# Resposta do Supabase: data=[{'Ativo': 'DAP35', 'Quantidade': 16, 'Dia de Compra': '2025-03-12', 'Preço de Compra': 47658.3, 'Preço de Ajuste Atual': 47958.7, 'Rendimento': 4806.39999999991, 'Id': 1}, {'Ativo': 'DAP35', 'Quantidade': 1, 'Dia de Compra': '2025-03-18', 'Preço de Compra': 47848.28, 'Preço de Ajuste Atual': 47958.7, 'Rendimento': 110.419999999998, 'Id': 2}, {'Ativo': 'DAP35', 'Quantidade': 1, 'Dia de Compra': '2025-04-03', 'Preço de Compra': 48738.41, 'Preço de Ajuste Atual': 47958.7, 'Rendimento': -779.710000000006, 'Id': 3}, {'Ativo': 'DAP35', 'Quantidade': 15, 'Dia de Compra': '2025-04-07', 'Preço de Compra': 48516.11, 'Preço de Ajuste Atual': 47958.7, 'Rendimento': -8361.15000000005, 'Id': 4}, {'Ativo': 'DI_27', 'Quantidade': 13, 'Dia de Compra': '2025-04-03', 'Preço de Compra': 79336.35, 'Preço de Ajuste Atual': 79215.25, 'Rendimento': -1574.30000000008, 'Id': 5}, {'Ativo': 'DI_27', 'Quantidade': 7, 'Dia de Compra': '2025-04-04', 'Preço de Compra': 79336.35, 'Preço de Ajuste Atual': 79215.25, 'Rendimento': -847.700000000041, 'Id': 6}, {'Ativo': 'DI_27', 'Quantidade': -20, 'Dia de Compra': '2025-04-07', 'Preço de Compra': 79324.32, 'Preço de Ajuste Atual': 79215.25, 'Rendimento': 2181.40000000014, 'Id': 7}, {'Ativo': 'WDO1', 'Quantidade': 15, 'Dia de Compra': '2025-03-31', 'Preço de Compra': 57530.5, 'Preço de Ajuste Atual': 58797.34, 'Rendimento': 19002.6000000001, 'Id': 8}, {'Ativo': 'WDO1', 'Quantidade': -15, 'Dia de Compra': '2025-04-03', 'Preço de Compra': 56525, 'Preço de Ajuste Atual': 58797.34, 'Rendimento': -34085.1000000001, 'Id': 9}, {'Ativo': 'WDO1', 'Quantidade': 6, 'Dia de Compra': '2025-04-04', 'Preço de Compra': 57265, 'Preço de Ajuste Atual': 58797.34, 'Rendimento': 9194.04000000002, 'Id': 10}, {'Ativo': 'WDO1', 'Quantidade': 5, 'Dia de Compra': '2025-04-07', 'Preço de Compra': 59100, 'Preço de Ajuste Atual': 58797.34, 'Rendimento': -1513.29999999998, 'Id': 11}, {'Ativo': 'DAP35', 'Quantidade': 2, 'Dia de Compra': '2025-04-09', 'Preço de Compra': 47908.7, 'Preço de Ajuste Atual': 47958.7, 'Rendimento': 100, 'Id': 12}] count=None
# [{'Ativo': 'DAP35',
#   'Quantidade': 16,
#   'Dia de Compra': '2025-03-12',
#   'Preço de Compra': 47658.3,
#   'Preço de Ajuste Atual': 47958.7,
#   'Rendimento': 4806.39999999991,
#   'Id': 1},
#  {'Ativo': 'DAP35',
#   'Quantidade': 1,
#   'Dia de Compra': '2025-03-18',
#   'Preço de Compra': 47848.28,
#   'Preço de Ajuste Atual': 47958.7,
#   'Rendimento': 110.419999999998,
#   'Id': 2},
#  {'Ativo': 'DAP35',
#   'Quantidade': 1,
#   'Dia de Compra': '2025-04-03',
#   'Preço de Compra': 48738.41,
#   'Preço de Ajuste Atual': 47958.7,
#   'Rendimento': -779.710000000006,
#   'Id': 3},
#  {'Ativo': 'DAP35',
#   'Quantidade': 15,
#   'Dia de Compra': '2025-04-07',
#   'Preço de Compra': 48516.11,
#   'Preço de Ajuste Atual': 47958.7,
#   'Rendimento': -8361.15000000005,
#   'Id': 4},
#  {'Ativo': 'DI_27',
#   'Quantidade': 13,
#   'Dia de Compra': '2025-04-03',
#   'Preço de Compra': 79336.35,
#   'Preço de Ajuste Atual': 79215.25,
#   'Rendimento': -1574.30000000008,
#   'Id': 5},
#  {'Ativo': 'DI_27',
#   'Quantidade': 7,
#   'Dia de Compra': '2025-04-04',
#   'Preço de Compra': 79336.35,
#   'Preço de Ajuste Atual': 79215.25,
#   'Rendimento': -847.700000000041,
#   'Id': 6},
#  {'Ativo': 'DI_27',
#   'Quantidade': -20,
#   'Dia de Compra': '2025-04-07',
#   'Preço de Compra': 79324.32,
#   'Preço de Ajuste Atual': 79215.25,
#   'Rendimento': 2181.40000000014,
#   'Id': 7},
#  {'Ativo': 'WDO1',
#   'Quantidade': 15,
#   'Dia de Compra': '2025-03-31',
#   'Preço de Compra': 57530.5,
#   'Preço de Ajuste Atual': 58797.34,
#   'Rendimento': 19002.6000000001,
#   'Id': 8},
#  {'Ativo': 'WDO1',
#   'Quantidade': -15,
#   'Dia de Compra': '2025-04-03',
#   'Preço de Compra': 56525,
#   'Preço de Ajuste Atual': 58797.34,
#   'Rendimento': -34085.1000000001,
#   'Id': 9},
#  {'Ativo': 'WDO1',
#   'Quantidade': 6,
#   'Dia de Compra': '2025-04-04',
#   'Preço de Compra': 57265,
#   'Preço de Ajuste Atual': 58797.34,
#   'Rendimento': 9194.04000000002,
#   'Id': 10},
#  {'Ativo': 'WDO1',
#   'Quantidade': 5,
#   'Dia de Compra': '2025-04-07',
#   'Preço de Compra': 59100,
#   'Preço de Ajuste Atual': 58797.34,
#   'Rendimento': -1513.29999999998,
#   'Id': 11},
#  {'Ativo': 'DAP35',
#   'Quantidade': 2,
#   'Dia de Compra': '2025-04-09',
#   'Preço de Compra': 47908.7,
#   'Preço de Ajuste Atual': 47958.7,
#   'Rendimento': 100,
#   'Id': 12}]

# %%
df = pd.read_parquet('portifolio_posições.parquet')
#Preciso adicionar uma coluna de 12 linhas chamada 'ID' depois da coluna 'Quantidade' a ordem dos valores é [1,2,3,4,5,6,7,12,8,9,10,11]
df['ID'] = [1,2,3,4,5,6,7,12,8,9,10,11]
#Ordenando a coluna ID
# Lista atual
cols = df.columns.tolist()

# Remover 'ID' da posição original
cols.remove('ID')

# Inserir 'ID' depois de 'Quantidade'
idx = cols.index('Quantidade') + 1
cols.insert(idx, 'ID')

# Reordenar o DataFrame
df = df[cols]
df
# Out:
#     Ativo  Quantidade  ID Dia de Compra  Preço de Compra  \
# 0   DAP35          16   1    2025-03-12         47658.30
# 1   DAP35           1   2    2025-03-18         47848.28
# 2   DAP35           1   3    2025-04-03         48738.41
# 3   DAP35          15   4    2025-04-07         48516.11
# 4   DI_27          13   5    2025-04-03         79336.35
# 5   DI_27           7   6    2025-04-04         79336.35
# 6   DI_27         -20   7    2025-04-07         79324.32
# 7    WDO1          15  12    2025-03-31         57530.50
# 8    WDO1         -15   8    2025-04-03         56525.00
# 9    WDO1           6   9    2025-04-04         57265.00
# 10   WDO1           5  10    2025-04-07         59100.00
# 11  DI_27          18  11    2025-04-09         79276.70
#
#     Preço de Ajuste Atual  Rendimento
# 0                47958.70     4806.40
# 1                47958.70      110.42
# 2                47958.70     -779.71
# 3                47958.70    -8361.15
# 4                79215.25    -1574.30
# 5                79215.25     -847.70
# 6                79215.25     2181.40
# 7                58797.34    19002.60
# 8                58797.34   -34085.10
# 9                58797.34     9194.04
# 10               58797.34    -1513.30
# 11               79215.25    -1106.10

# %%
df.to_parquet('portifolio_posições.parquet', index=False)

# %%
df = pd.read_parquet('df_preco_de_ajuste_atual.parquet')
#Dropar penultima coluna
df
# Out:
#       Assets  2025-01-02  2025-01-03  2025-01-06  2025-01-07  2025-01-08  \
# 16   68.568,57   68.785,01   68.830,49   69.644,17   69.912,93   69.922,56
# 17   59.915,14   60.182,03   60.196,99   61.089,22   61.310,63   61.245,02
# 18   52.164,53   52.455,40   52.414,96   53.297,50   53.470,82   53.384,81
# 19   45.310,51   45.600,22   45.527,57   46.364,88   46.491,53   46.416,78
# 20   39.376,51   39.698,85   39.595,33   40.375,06   40.436,97   40.364,07
# 21   34.310,48   34.616,59   34.500,79   35.237,07   35.256,00   35.154,21
# 22   29.981,83   30.284,24   30.165,36   30.813,95   30.853,93   30.695,20
# 23   26.161,84   26.474,19   26.332,44   26.932,08   26.901,03   26.786,20
# 24   22.914,89   23.208,83   23.070,57   23.642,43   23.538,55   23.426,54
# 25   19.944,62   20.223,62   20.099,02   20.635,23   20.463,98   20.356,50
# 26   17.645,97   17.913,22   17.792,52   18.307,56   18.075,62   17.971,69
# 27   15.495,57   15.748,26   15.633,08   16.121,26   15.900,26   15.800,93
# 28   13.576,27   13.813,43   13.704,50   14.163,71   13.954,89   13.860,79
# 29    111,2187    111,7812    111,5000    112,6406    113,0468    112,0625
# 30  5.742,2000  5.742,2000  5.717,7190  5.647,9520  5.865,6460  5.936,2050
#
#     2025-04-08  2025-04-09  2025-04-10
# 0    99.220,83   99.248,17   99.248,17
# 1    88.739,44   88.595,39   88.595,39
# 2    84.774,30   84.524,11   84.524,11
# 3    77.564,53   77.289,13   77.289,13
# 4    73.745,27   73.558,96   73.558,96
# 5    67.425,18   67.245,88   67.245,88
# 6    58.227,49   58.086,67   58.086,67
# 7    55.325,04   55.196,48   55.196,48
# 8    48.124,00   47.958,70   47.958,70
# 9    33.427,21   33.294,53   33.294,53
# 10   23.684,93   23.568,74   23.568,74
# 11   16.743,15   16.681,18   16.681,18
# 12   12.081,94   12.078,60   12.078,60
# 13    8.393,19    8.392,79    8.392,79
# 14   90.339,41   90.354,09   90.354,09
# 15   79.365,30   79.215,25   79.215,25
# 16   69.724,02   69.490,66   69.490,66
# 17   60.979,57   60.785,09   60.785,09
# 18   53.089,61   52.896,53   52.896,53
# 19   46.114,75   45.956,71   45.956,71
# 20   40.080,16   39.917,48   39.917,48
# 21   34.869,86   34.755,73   34.755,73
# 22   30.479,73   30.346,50   30.346,50
# 23   26.548,54   26.415,61   26.415,61
# 24   23.196,27   23.067,00   23.067,00
# 25   20.136,74   20.013,03   20.013,03
# 26   17.760,30   17.641,01   17.641,01
# 27   15.599,75   15.486,00   15.486,00
# 28   13.670,93   13.563,42   13.563,42
# 29    111,4687    110,3281    110,3281
# 30  6.004,0800  5.879,7340  5.879,7340
#
# [31 rows x 70 columns]

# %%
hoje_data = datetime.strptime(hoje_str, '%Y-%m-%d').date()

hoje_data
# Out:
# datetime.date(2025, 4, 8)

# %%
#Comparar para ver se é igual
if hoje == hoje_data:
    print("Data igual")
else:
    print("Data diferente")
# Out:
# Data igual

# %%
df.drop(df.columns[-2], axis=1, inplace=True)
df.to_parquet('df_preco_de_ajuste_atual.parquet')
df
# Out:
#       Assets  2025-01-02  2025-01-03  2025-01-06  2025-01-07  2025-01-08  \
# 4     73.665,63    73.910,85    73.918,64   73.918,64    73.745,27
# 5     67.432,32    67.719,43    67.688,92   67.688,92    67.425,18
# 6     58.513,78    58.790,32    58.667,36   58.667,36    58.227,49
# 7     55.734,56    55.981,09    55.808,45   55.808,45    55.325,04
# 8     48.738,41    48.820,68    48.516,11   48.516,11    48.124,00
# 9     33.805,07    33.915,81    33.728,01   33.728,01    33.427,21
# 10    24.109,14    24.178,88    23.943,88   23.943,88    23.684,93
# 11    17.110,63    17.159,69    16.971,97   16.971,97    16.743,15
# 12    12.371,83    12.406,38    12.248,15   12.248,15    12.081,94
# 13     8.614,58     8.642,43     8.507,10    8.507,10     8.393,19
# 14    90.176,18    90.281,87    90.337,99   90.337,99    90.339,41
# 15    79.147,43    79.391,77    79.466,20   79.466,20    79.365,30
# 16    69.644,17    69.912,93    69.922,56   69.922,56    69.724,02
# 17    61.089,22    61.310,63    61.245,02   61.245,02    60.979,57
# 18    53.297,50    53.470,82    53.384,81   53.384,81    53.089,61
# 19    46.364,88    46.491,53    46.416,78   46.416,78    46.114,75
# 20    40.375,06    40.436,97    40.364,07   40.364,07    40.080,16
# 21    35.237,07    35.256,00    35.154,21   35.154,21    34.869,86
# 22    30.813,95    30.853,93    30.695,20   30.695,20    30.479,73
# 23    26.932,08    26.901,03    26.786,20   26.786,20    26.548,54
# 24    23.642,43    23.538,55    23.426,54   23.426,54    23.196,27
# 25    20.635,23    20.463,98    20.356,50   20.356,50    20.136,74
# 26    18.307,56    18.075,62    17.971,69   17.971,69    17.760,30
# 27    16.121,26    15.900,26    15.800,93   15.800,93    15.599,75
# 28    14.163,71    13.954,89    13.860,79   13.860,79    13.670,93
# 29     112,6406     113,0468     112,0625    112,0625     111,4687
# 30   5.647,9520   5.865,6460   5.936,2050  5.936,2050   6.004,0800
# 0   4571,364307  4573,454188  4575,092381        None  4577,524263
# 1   4333,100637  4336,928722  4339,916293        None  4342,076133
# 2   4387,977444  4395,926847  4401,729758        None  4403,896783
# 3   4268,717999  4274,038593  4280,450288        None  4279,592287
# 4   4202,772697  4210,825997  4214,125578        None   4203,86692
# 5   4132,833424  4142,539016  4136,327881        None   4119,34524
# 6    4144,53773  4143,958768  4130,409952        None  4112,305501
# 7   3973,920829  3979,343565  3968,842869        None  3949,566987
# 8   3957,443459  3965,369971  3945,663939        None  3923,742661
# 9   3876,601361  3883,293024  3864,318172        None  3840,251624
# 10     3912,368  3918,540518  3898,996968        None  3878,089661
# 11  3816,235082  3822,767657  3801,295138        None  3783,646923
#
# [43 rows x 69 columns]

# %%
fundo = 'JERA2026'
# Caminho do parquet do Fundo
nome_arquivo_parquet = os.path.join("BaseFundos", f"{fundo}.parquet")
# 2.1) Carregar (ou criar) o DataFrame histórico do Fundo (df_fundo)
if os.path.exists(nome_arquivo_parquet):
    df_fundo = pd.read_parquet(nome_arquivo_parquet)
    # Conferir se já existem dados para o dia de operação
df_fundo
# Out:
#    Ativo  Preco_Fechamento_Atual  2025-03-12 - PL  \
# 0  DI_27                79391.77              NaN
# 1  DAP35                48820.68     1.966826e+08
# 2   WDO1                58656.46              NaN
#
#    2025-03-12 - Preco_Fechamento  2025-03-12 - Preco_Compra  \
# 0                            NaN                        NaN
# 1                        47658.3                    47658.3
# 2                            NaN                        NaN
#
#    2025-03-12 - Quantidade  2025-03-12 - Rendimento 2025-03-18 - PL  \
# 0                      NaN                      NaN            None
# 1                      4.0                      0.0            None
# 2                      NaN                      NaN            None
#
#    2025-03-18 - Preco_Fechamento  2025-03-18 - Preco_Compra  ...  \
# 0                            NaN                        NaN  ...
# 1                       47848.28                   47848.28  ...
# 2                            NaN                        NaN  ...
#
#    2025-04-04 - PL  2025-04-04 - Preco_Fechamento  2025-04-04 - Preco_Compra  \
# 0     1.969550e+08                       79391.77                   79336.35
# 1              NaN                            NaN                        NaN
# 2     1.969550e+08                       58656.46                   57265.00
#
#    2025-04-04 - Quantidade  2025-04-04 - Rendimento  2025-04-07 - PL  \
# 0                      2.0                   110.84     1.969550e+08
# 1                      NaN                      NaN     1.969550e+08
# 2                      2.0                  2782.92     1.969550e+08
#
#    2025-04-07 - Preco_Fechamento  2025-04-07 - Preco_Compra  \
# 0                       79391.77                   79324.32
# 1                       48820.68                   48516.11
# 2                       58656.46                   59100.00
#
#    2025-04-07 - Quantidade  2025-04-07 - Rendimento
# 0                       -5                  -337.25
# 1                        4                  1218.28
# 2                        0                     0.00
#
# [3 rows x 32 columns]

# %%
df_fundo.to_parquet(nome_arquivo_parquet, index=False)

# %%
pl_dias = pd.read_parquet("pl_fundos_teste.parquet")
pl_dias = pl_dias.replace('\.', '', regex=True)
pl_dias = pl_dias.replace({',': '.'}, regex=True)
for col in pl_dias.columns:
    pl_dias[col] = pl_dias[col].astype(str)
    if col != 'Fundos/Carteiras Adm':
        pl_dias[col] = pl_dias[col].str.replace('R$', '')
        pl_dias[col] = pl_dias[col].replace('--', np.nan)
        pl_dias[col] = pl_dias[col].astype(float, errors='ignore')

# Atualizar todas as colunas para float menos a primeira
pl_dias = pl_dias.set_index("Fundos/Carteiras Adm")
pl_dias
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\.'
# <>:2: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\emanuel.cabral\AppData\Local\Temp\ipykernel_28412\2481886255.py:2: SyntaxWarning: invalid escape sequence '\.'
#   pl_dias = pl_dias.replace('\.', '', regex=True)
# C:\Users\emanuel.cabral\AppData\Local\Temp\ipykernel_28412\2481886255.py:8: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   pl_dias[col] = pl_dias[col].replace('--', np.nan)
#                        2025-01-01    2025-01-02    2025-01-03    2025-01-04  \
# Fundos/Carteiras Adm
# AF DEB INCENTIVADAS           NaN  1.170372e+07  1.172564e+07  1.172564e+07
# AF INVEST GERAES PREV         NaN  4.423740e+06  4.425385e+06  4.425385e+06
# AF TÁTICO                     NaN  4.441214e+07  4.440922e+07  4.440922e+07
# ALFA HORIZON FIA              NaN  1.088113e+07  1.074459e+07  1.074459e+07
# AYA NMK FIM                   NaN  1.486447e+06  1.487216e+06  1.487216e+06
# BBRASIL FIM CP RESP           NaN  9.804497e+07  9.809798e+07  9.809798e+07
# BH FIM                        NaN  5.036590e+05  5.024334e+05  5.024334e+05
# BH FIRF INFRA                 NaN  1.178423e+08  1.179062e+08  1.179062e+08
# FIA MINAS              3.548762e+07  3.462194e+07  3.462194e+07  3.400963e+07
# FIRF GERAES            5.004205e+08  5.009205e+08  5.009205e+08  5.012019e+08
# FIRF GERAES 30         2.757499e+08  2.760853e+08  2.760853e+08  2.763880e+08
# GLOBAL BONDS           2.972490e+07  2.972490e+07  2.972490e+07  2.967671e+07
# HORIZONTE              2.492703e+08  2.494046e+08  2.494046e+08  2.495259e+08
# JERA2026               1.990115e+08  1.990115e+08  1.990115e+08  1.990115e+08
# MANACA INFRA FIRF      4.190835e+07  4.193266e+07  4.193266e+07  4.195741e+07
# MINAS ONE FIA          2.811559e+06  2.690910e+06  2.690910e+06  2.659867e+06
# REAL FIM               3.797748e+07  3.797748e+07  3.797748e+07  3.797748e+07
# ROMEU FC FIM CP IE     2.210219e+08  2.211400e+08  2.211400e+08  2.212039e+08
# SANKALPA FIM           6.037122e+05  6.037122e+05  6.037122e+05  6.080538e+05
# SANTANA                3.291169e+07  3.291169e+07  3.291169e+07  3.291169e+07
# TOPAZIO FIM            2.007381e+06  2.007381e+06  2.007381e+06  1.988126e+06
# TOPAZIO INFRA          3.169231e+07  3.171976e+07  3.171976e+07  3.174415e+07
# TOTAL                  1.997423e+09  1.848078e+09  1.848078e+09  1.881084e+09
#
#                        Último Valor
# Fundos/Carteiras Adm
# AF DEB INCENTIVADAS    1.170372e+07
# AF INVEST GERAES PREV  4.423740e+06
# AF TÁTICO              4.441214e+07
# ALFA HORIZON FIA       1.088113e+07
# AYA NMK FIM            1.486447e+06
# BBRASIL FIM CP RESP    9.804497e+07
# BH FIM                 5.036590e+05
# BH FIRF INFRA          1.178423e+08
# BMG SEG                1.157578e+08
# BORDEAUX FIM           1.658989e+06
# BORDEAUX INFRA         4.546401e+07
# FIA MINAS              3.006709e+07
# FIRF GERAES            5.325820e+08
# FIRF GERAES 30         2.841423e+08
# GLOBAL BONDS           2.964318e+07
# HORIZONTE              2.410463e+08
# JERA2026               1.919716e+08
# MANACA INFRA FIRF      4.053330e+07
# MINAS ONE FIA          1.913338e+06
# REAL FIM               3.654251e+07
# ROMEU FC FIM CP IE     2.134039e+08
# SANKALPA FIM           6.103806e+05
# SANTANA                3.191219e+07
# TOPAZIO FIM            1.754887e+06
# TOPAZIO INFRA          3.069587e+07
# TOTAL                  2.118998e+09
#
# [26 rows x 100 columns]

# %%
if df_fundo.columns.str.startswith(dia_operacao).any():
        df_fundo = df_fundo.drop(
            columns=df_fundo.columns[df_fundo.columns.str.startswith(dia_operacao)])
    # 2.2) Garante que "Ativo" seja índice (mas mantendo a coluna)
    if "Ativo" in df_fundo.columns:
        df_fundo.set_index("Ativo", inplace=True, drop=False)

# %%
df = pd.read_parquet('df_preco_de_ajuste_atual.parquet')
#Dropar a coluna chamada 2025-03-31
#df = df.drop(columns=['2025-03-31'])
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_parquet('df_preco_de_ajuste_atual.parquet')
#       2 #Dropar a coluna chamada 2025-03-31
#       3 #df = df.drop(columns=['2025-03-31'])
#       4 df
#
# NameError: name 'pd' is not defined

# %%
df.to_parquet('df_preco_de_ajuste_atual.parquet')
